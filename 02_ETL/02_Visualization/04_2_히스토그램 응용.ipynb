# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc

import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 넘파이의 random 함수

# %% [markdown]
# ### 1. numpy.random.rand
#  0~1 사이의 값의 uniform distribution 균일 분포, 균등 분포라고 불리는 값을 return 하는 함수

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
DATA_LIMIT = 1000000

# %%
import pandas as pd
import numpy as np

np.random.rand(5)
# Out:
# array([0.62028904, 0.71265585, 0.4937489 , 0.43785116, 0.93758601])

# %%
np.random.rand(2,5)
# Out:
# array([[0.98320252, 0.39361736, 0.20349498, 0.12666317, 0.67572098],
#        [0.48414074, 0.2935225 , 0.25673655, 0.88311787, 0.30593215]])

# %%
rand_data = np.random.rand(DATA_LIMIT)
plt.hist(rand_data)
# Out:
# (array([ 99714., 100061., 100246.,  99691.,  99769., 100191.,  99799.,
#         100025., 100398., 100106.]),
#  array([3.43882185e-07, 1.00000194e-01, 2.00000044e-01, 2.99999894e-01,
#         3.99999744e-01, 4.99999594e-01, 5.99999444e-01, 6.99999294e-01,
#         7.99999144e-01, 8.99998994e-01, 9.99998844e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 2. numpy.random.randn

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  Normal(Gaussian) Distribution 정규 분포, 가우시안 분포라고 불리는 값을 return 하는 함수입니다.
#  평균 0, 분산이 1인 값을 반환

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
randn_data = np.random.randn(DATA_LIMIT)
plt.hist(randn_data, bins=100)
# Out:
# (array([4.0000e+00, 3.0000e+00, 5.0000e+00, 3.0000e+00, 1.4000e+01,
#         1.0000e+01, 1.5000e+01, 3.4000e+01, 4.3000e+01, 5.3000e+01,
#         9.5000e+01, 1.0200e+02, 1.4700e+02, 2.0200e+02, 2.5800e+02,
#         3.4700e+02, 4.5200e+02, 5.5600e+02, 7.7200e+02, 1.0740e+03,
#         1.3080e+03, 1.6500e+03, 2.0670e+03, 2.5640e+03, 3.2170e+03,
#         3.8960e+03, 4.7840e+03, 5.7490e+03, 6.7590e+03, 8.0580e+03,
#         9.4570e+03, 1.1184e+04, 1.2571e+04, 1.4526e+04, 1.6269e+04,
#         1.8539e+04, 2.0701e+04, 2.2574e+04, 2.4886e+04, 2.7344e+04,
#         2.8773e+04, 3.1227e+04, 3.2700e+04, 3.4280e+04, 3.5431e+04,
#         3.6513e+04, 3.7149e+04, 3.7493e+04, 3.7287e+04, 3.7062e+04,
#         3.6552e+04, 3.5716e+04, 3.4759e+04, 3.3092e+04, 3.1255e+04,
#         2.9724e+04, 2.7565e+04, 2.5352e+04, 2.3091e+04, 2.1089e+04,
#         1.9080e+04, 1.6975e+04, 1.5048e+04, 1.3191e+04, 1.1384e+04,
#         9.9820e+03, 8.2790e+03, 7.1320e+03, 6.0390e+03, 4.9190e+03,
#         4.0820e+03, 3.2930e+03, 2.6860e+03, 2.1660e+03, 1.7040e+03,
#         1.3980e+03, 1.0680e+03, 7.7900e+02, 6.1200e+02, 4.7700e+02,
#         3.4900e+02, 2.3100e+02, 2.0500e+02, 1.4600e+02, 9.8000e+01,
#         7.9000e+01, 6.0000e+01, 4.5000e+01, 2.9000e+01, 2.0000e+01,
#         1.3000e+01, 9.0000e+00, 5.0000e+00, 5.0000e+00, 2.0000e+00,
#         2.0000e+00, 1.0000e+00, 2.0000e+00, 0.0000e+00, 3.0000e+00]),
#  array([-4.53590011, -4.44161252, -4.34732493, -4.25303734, -4.15874975,
#         -4.06446216, -3.97017457, -3.87588698, -3.78159939, -3.6873118 ,
#         -3.59302421, -3.49873662, -3.40444903, -3.31016144, -3.21587385,
#         -3.12158626, -3.02729867, -2.93301108, -2.83872349, -2.7444359 ,
#         -2.65014831, -2.55586072, -2.46157313, -2.36728553, -2.27299794,
#         -2.17871035, -2.08442276, -1.99013517, -1.89584758, -1.80155999,
#         -1.7072724 , -1.61298481, -1.51869722, -1.42440963, -1.33012204,
#         -1.23583445, -1.14154686, -1.04725927, -0.95297168, -0.85868409,
#         -0.7643965 , -0.67010891, -0.57582132, -0.48153373, -0.38724614,
#         -0.29295855, -0.19867096, -0.10438337, -0.01009578,  0.08419181,
#          0.1784794 ,  0.27276699,  0.36705458,  0.46134217,  0.55562976,
#          0.64991735,  0.74420494,  0.83849253,  0.93278012,  1.02706771,
#          1.1213553 ,  1.21564289,  1.30993048,  1.40421807,  1.49850566,
#          1.59279325,  1.68708084,  1.78136843,  1.87565602,  1.96994361,
#          2.0642312 ,  2.15851879,  2.25280638,  2.34709397,  2.44138157,
#          2.53566916,  2.62995675,  2.72424434,  2.81853193,  2.91281952,
#          3.00710711,  3.1013947 ,  3.19568229,  3.28996988,  3.38425747,
#          3.47854506,  3.57283265,  3.66712024,  3.76140783,  3.85569542,
#          3.94998301,  4.0442706 ,  4.13855819,  4.23284578,  4.32713337,
#          4.42142096,  4.51570855,  4.60999614,  4.70428373,  4.79857132,
#          4.89285891]),
#  <BarContainer object of 100 artists>)

# %% [markdown]
# ## 3. numpy.random.randint

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [이산균등분포(discrete uniform)](https://ko.wikipedia.org/wiki/%EC%9D%B4%EC%82%B0%EA%B7%A0%EB%93%B1%EB%B6%84%ED%8F%AC)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1) low
# 가장 작은 범주가 어디서부터 시작하는 지를 적습니다. 다만 1개의 hyperparameter를 적으면 그 값은 가장 높은 범주의 값으로 인식하고 0에서부터 그 숫자 사이의 int를 1개 반환합니다.
# 만약 high없이 개수를 늘리고 싶다면 다음과 같이 적으면 됩니다.
#
# ex) numpy.random.randint(3, size=10)
#
# 2) high
# 가장 높은 정수를 적은 곳으로 선택사항 optional입니다.
#
# 3) size
#
# 몇 개의 random 값을 리턴하기 바라는지를 적으면 됩니다. 3개 반환을 받고 싶다면 3개를 적으면 됩니다. 만약 array 형태로 shape을 적고싶다면 다음과 같이 적을 수도 있습니다.
#
# ex) numpy.random.randint(3,10,size=(3,2))
#
# 이렇게 적으면 3~10 사이의 정수를 3x2 행렬에 맞게 반환해주세요 라는 뜻이 됩니다.
#
#
#
# 4) dtype
#
# int를 반환하는 함수이기 때문에 굳이 필요한가 싶지만 이 부분은 int 혹은 int64를 반환할 수 있도록 선택하는 parameter입니다. 선택하지 않아도 무방

# %% [markdown]
# ### high만 지정

# %%
np.random.randint(3, size=10)
# Out:
# array([2, 0, 1, 1, 1, 2, 1, 1, 1, 0])

# %% [markdown]
# ### low, high 지정

# %%
np.random.randint(1,3, size=10)
# Out:
# array([1, 2, 2, 1, 1, 2, 2, 2, 1, 1])

# %%
np.random.randint(1,3, size=10)
# Out:
# array([1, 1, 2, 2, 1, 2, 2, 1, 1, 1])

# %%
randint_data = np.random.randint(1,1000, size=DATA_LIMIT)
plt.hist(randint_data, bins=20)
# Out:
# (array([49858., 50153., 50126., 50080., 50245., 49821., 50210., 49773.,
#         50175., 49405., 50307., 50134., 50193., 49739., 50147., 49680.,
#         50169., 49784., 49981., 50020.]),
#  array([  1. ,  50.9, 100.8, 150.7, 200.6, 250.5, 300.4, 350.3, 400.2,
#         450.1, 500. , 549.9, 599.8, 649.7, 699.6, 749.5, 799.4, 849.3,
#         899.2, 949.1, 999. ]),
#  <BarContainer object of 20 artists>)

# %%
move_right =  172.5
variance_amplication = 5

# %%
height_data = np.round(
    move_right + 
    (np.random.randn(DATA_LIMIT)*variance_amplication),
    1)

# %%
height_data
# Out:
# array([169.7, 171.1, 178.7, ..., 177.9, 177.8, 167.3])

# %%
plt.xlabel('키')
plt.ylabel('누적개수')
plt.hist(height_data, bins=140)
# Out:
# (array([1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 4.0000e+00,
#         5.0000e+00, 4.0000e+00, 3.0000e+00, 1.1000e+01, 8.0000e+00,
#         1.8000e+01, 1.9000e+01, 3.5000e+01, 3.4000e+01, 4.4000e+01,
#         3.2000e+01, 9.7000e+01, 8.4000e+01, 1.5400e+02, 1.2900e+02,
#         2.1200e+02, 1.9900e+02, 3.3400e+02, 3.3600e+02, 3.7300e+02,
#         6.3900e+02, 6.1300e+02, 8.8000e+02, 8.2500e+02, 1.2690e+03,
#         1.1730e+03, 1.8400e+03, 1.6340e+03, 2.5580e+03, 2.1710e+03,
#         3.3650e+03, 3.0430e+03, 4.5640e+03, 3.9920e+03, 5.9700e+03,
#         4.9840e+03, 7.6440e+03, 6.5350e+03, 9.8250e+03, 7.9640e+03,
#         1.2013e+04, 9.8220e+03, 1.4281e+04, 1.1869e+04, 1.6851e+04,
#         1.3666e+04, 1.9546e+04, 1.5549e+04, 2.2356e+04, 1.7671e+04,
#         2.4996e+04, 1.9443e+04, 2.7125e+04, 2.1188e+04, 2.1696e+04,
#         2.9950e+04, 2.2712e+04, 3.1097e+04, 2.3267e+04, 3.1496e+04,
#         2.3754e+04, 3.1886e+04, 2.3616e+04, 3.1209e+04, 2.3022e+04,
#         3.0415e+04, 2.2124e+04, 2.8671e+04, 2.0597e+04, 2.6419e+04,
#         1.9168e+04, 2.4179e+04, 1.7177e+04, 2.1436e+04, 1.5018e+04,
#         1.8878e+04, 1.2964e+04, 1.6155e+04, 1.1116e+04, 1.3543e+04,
#         9.1890e+03, 1.1185e+04, 7.4430e+03, 9.0650e+03, 6.0620e+03,
#         7.2210e+03, 4.7990e+03, 5.5050e+03, 3.6360e+03, 3.3460e+03,
#         3.6610e+03, 2.4480e+03, 2.6800e+03, 1.7480e+03, 2.0500e+03,
#         1.3540e+03, 1.4430e+03, 8.9100e+02, 1.0170e+03, 6.2800e+02,
#         6.7100e+02, 4.3400e+02, 4.0900e+02, 2.6500e+02, 3.2100e+02,
#         1.9200e+02, 1.7400e+02, 1.0700e+02, 1.1800e+02, 8.4000e+01,
#         7.4000e+01, 4.1000e+01, 4.2000e+01, 3.7000e+01, 3.3000e+01,
#         1.1000e+01, 1.8000e+01, 7.0000e+00, 6.0000e+00, 5.0000e+00,
#         7.0000e+00, 1.0000e+00, 2.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([146.1       , 146.44857143, 146.79714286, 147.14571429,
#         147.49428571, 147.84285714, 148.19142857, 148.54      ,
#         148.88857143, 149.23714286, 149.58571429, 149.93428571,
#         150.28285714, 150.63142857, 150.98      , 151.32857143,
#         151.67714286, 152.02571429, 152.37428571, 152.72285714,
#         153.07142857, 153.42      , 153.76857143, 154.11714286,
#         154.46571429, 154.81428571, 155.16285714, 155.51142857,
#         155.86      , 156.20857143, 156.55714286, 156.90571429,
#         157.25428571, 157.60285714, 157.95142857, 158.3       ,
#         158.64857143, 158.99714286, 159.34571429, 159.69428571,
#         160.04285714, 160.39142857, 160.74      , 161.08857143,
#         161.43714286, 161.78571429, 162.13428571, 162.48285714,
#         162.83142857, 163.18      , 163.52857143, 163.87714286,
#         164.22571429, 164.57428571, 164.92285714, 165.27142857,
#         165.62      , 165.96857143, 166.31714286, 166.66571429,
#         167.01428571, 167.36285714, 167.71142857, 168.06      ,
#         168.40857143, 168.75714286, 169.10571429, 169.45428571,
#         169.80285714, 170.15142857, 170.5       , 170.84857143,
#         171.19714286, 171.54571429, 171.89428571, 172.24285714,
#         172.59142857, 172.94      , 173.28857143, 173.63714286,
#         173.98571429, 174.33428571, 174.68285714, 175.03142857,
#         175.38      , 175.72857143, 176.07714286, 176.42571429,
#         176.77428571, 177.12285714, 177.47142857, 177.82      ,
#         178.16857143, 178.51714286, 178.86571429, 179.21428571,
#         179.56285714, 179.91142857, 180.26      , 180.60857143,
#         180.95714286, 181.30571429, 181.65428571, 182.00285714,
#         182.35142857, 182.7       , 183.04857143, 183.39714286,
#         183.74571429, 184.09428571, 184.44285714, 184.79142857,
#         185.14      , 185.48857143, 185.83714286, 186.18571429,
#         186.53428571, 186.88285714, 187.23142857, 187.58      ,
#         187.92857143, 188.27714286, 188.62571429, 188.97428571,
#         189.32285714, 189.67142857, 190.02      , 190.36857143,
#         190.71714286, 191.06571429, 191.41428571, 191.76285714,
#         192.11142857, 192.46      , 192.80857143, 193.15714286,
#         193.50571429, 193.85428571, 194.20285714, 194.55142857,
#         194.9       ]),
#  <BarContainer object of 140 artists>)

# %%
m_move_right =  172.5
w_move_right =  159.6
variance_amplication = 7
m_height_data = np.round(m_move_right + (np.random.randn(DATA_LIMIT)*variance_amplication),1)
w_height_data = np.round(w_move_right + (np.random.randn(DATA_LIMIT)*variance_amplication),1)

plt.xlabel('키')
plt.ylabel('누적개수')
plt.hist((m_height_data,w_height_data), bins=200, label=['성인 남자키','성인 여자키'])

plt.title('전국 성인남녀 키 현황 (2022.3 산업통산자원부 통계자료 시뮬레이션)')
plt.legend()

plt.show()
