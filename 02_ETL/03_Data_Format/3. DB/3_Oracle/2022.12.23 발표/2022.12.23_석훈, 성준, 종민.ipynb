# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager,rc

import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# read_csv 함수로 데이터를 Dataframe 형태로 불러옵니다.
file_path = '전국통합식품영양성분정보(가공식품)표준데이터.csv'
food = pd.read_csv(file_path, encoding = 'MS949')

# %%
object_col = food.select_dtypes(include = ['object'])
object_col
# Out:
#                       식품코드                  식품명 데이터구분코드 데이터구분명 식품기원명  식품대분류명  \
# 0      P123-226020100-0088         샐러드_비프불고기샐러드       P   가공식품  가공식품   즉석식품류
# 1      P123-226020100-0089      샐러드_비프타코샐러드랩의질투       P   가공식품  가공식품   즉석식품류
# 2      P123-226020100-0090         샐러드_샐러드에빠진연어       P   가공식품  가공식품   즉석식품류
# 3      P123-226020100-0091          샐러드_수삼초계샐러드       P   가공식품  가공식품   즉석식품류
# 4      P123-226020100-0092      샐러드_쉬림프크림파스타샐러드       P   가공식품  가공식품   즉석식품류
# ...                    ...                  ...     ...    ...   ...     ...
# 42602  P110-400030000-0017  영·유아용 이유식_후디스하이키드쵸코       P   가공식품  가공식품  특수영양식품
# 42603  P105-001020000-0018            잼_로투스스프레드       P   가공식품  가공식품      잼류
# 42604  P119-900090200-0019           치즈_끼리플레인포션       P   가공식품  가공식품   유가공품류
# 42605  P119-900090200-0020              치즈_래핑카우       P   가공식품  가공식품   유가공품류
# 42606  P119-900090200-0021            치즈_래핑카우체다       P   가공식품  가공식품   유가공품류
#
#            대표식품명        식품중분류명          식품소분류명 식품세분류명  ... 1회 섭취참고량  \
# 0            샐러드    즉석섭취·편의식품류          신선편의식품   해당없음  ...       1식
# 1            샐러드    즉석섭취·편의식품류          신선편의식품   해당없음  ...       1식
# 2            샐러드    즉석섭취·편의식품류          신선편의식품   해당없음  ...       1식
# 3            샐러드    즉석섭취·편의식품류          신선편의식품   해당없음  ...       1식
# 4            샐러드    즉석섭취·편의식품류          신선편의식품   해당없음  ...       1식
# ...          ...           ...             ...    ...  ...      ...
# 42602  영·유아용 이유식     영·유아용 이유식  해당없음(성장기용 조제식)   해당없음  ...      NaN
# 42603          잼         기타가공품     해당없음(기타가공품)   해당없음  ...      NaN
# 42604         치즈  치즈류(*축산물가공품)            가공치즈   해당없음  ...      NaN
# 42605         치즈  치즈류(*축산물가공품)            가공치즈   해당없음  ...      10g
# 42606         치즈  치즈류(*축산물가공품)            가공치즈   해당없음  ...      NaN
#
#                   제조사명    식품중량                       수입업체명 수입여부  원산지국명  \
# 0      농업회사법인(주)정진에프피씨    160g                         NaN    N    NaN
# 1             (주)샐러드판다    263g                         NaN    N    NaN
# 2             (주)샐러드판다    200g                         NaN    N    NaN
# 3              (주)성원푸드    171g                         NaN    N    NaN
# 4               (주)샐푸드    255g                         NaN    N    NaN
# ...                ...     ...                         ...  ...    ...
# 42602         일동후디스(주)    500g                         NaN    N    NaN
# 42603              NaN   2400g    LOTUS BAKERIES BELGIE NV    Y    벨기에
# 42604              NaN   1440g             FROMAGERIES BEL    Y    프랑스
# 42605              NaN  18140g             FROMAGERIES BEL    Y    프랑스
# 42606              NaN    128g  SYRAREN BEL SLOVENSKO A.S.    Y  슬로바키아
#
#       데이터생성방법명     데이터생성일자     데이터기준일자     제공기관명
# 0           수집  2021-06-30  2022-11-23  식품의약품안전처
# 1           수집  2021-06-30  2022-11-23  식품의약품안전처
# 2           수집  2020-06-30  2022-11-23  식품의약품안전처
# 3           수집  2020-06-30  2022-11-23  식품의약품안전처
# 4           수집  2021-06-30  2022-11-23  식품의약품안전처
# ...        ...         ...         ...       ...
# 42602       수집  2019-06-30  2022-11-23  식품의약품안전처
# 42603       수집  2020-06-30  2022-11-23  식품의약품안전처
# 42604       수집  2020-06-30  2022-11-23  식품의약품안전처
# 42605       수집  2020-06-30  2022-11-23  식품의약품안전처
# 42606       수집  2020-06-30  2022-11-23  식품의약품안전처
#
# [42607 rows x 22 columns]

# %%
for col_name in object_col.columns:
    try:
        print(f'{col_name} {max([len(str(content)) for content in object_col[col_name].values])}')  
    except Exception as e:
        print(f'{col_name} {e}')
# Out:
# 식품코드 19
# 식품명 45
# 데이터구분코드 1
# 데이터구분명 4
# 식품기원명 4
# 식품대분류명 15
# 대표식품명 13
# 식품중분류명 29
# 식품소분류명 17
# 식품세분류명 4
# 영양성분함량기준량 5
# 출처명 16
# 1회 섭취참고량 8
# 제조사명 43
# 식품중량 10
# 수입업체명 91
# 수입여부 1
# 원산지국명 10
# 데이터생성방법명 2
# 데이터생성일자 10
# 데이터기준일자 10
# 제공기관명 8

# %%
food.rename(columns={'에너지(kcal)':'에너지','수분(g)':'수분','단백질(g)':'단백질',
                     '탄수화물(g)':'탄수화물','지방(g)':'지방','당류(g)':'당류',
                     '콜레스테롤(mg)':'콜레스테롤','포화지방산(g)':'포화지방산',
                     '트랜스지방산(g)':'트랜스지방산'},inplace=True)

food.columns
# Out:
# Index(['식품코드', '식품명', '데이터구분코드', '데이터구분명', '식품기원코드', '식품기원명', '식품대분류코드',
#        '식품대분류명', '대표식품코드', '대표식품명', '식품중분류코드', '식품중분류명', '식품소분류코드', '식품소분류명',
#        '식품세분류코드', '식품세분류명', '영양성분함량기준량', '에너지', '수분', '단백질', '지방', '회분(g)',
#        '탄수화물', '당류', '식이섬유(g)', '칼슘(mg)', '철(mg)', '인(mg)', '칼륨(mg)',
#        '나트륨(mg)', '비타민 A(μg RAE)', '레티놀(μg)', '베타카로틴(μg)', '티아민(mg)',
#        '리보플라빈(mg)', '니아신(mg)', '비타민 C(mg)', '비타민 D(μg)', '콜레스테롤', '포화지방산',
#        '트랜스지방산', '출처코드', '출처명', '1회 섭취참고량', '제조사명', '식품중량', '수입업체명', '유통업체명',
#        '수입여부', '원산지국코드', '원산지국명', '데이터생성방법코드', '데이터생성방법명', '데이터생성일자',
#        '데이터기준일자', '제공기관코드', '제공기관명'],
#       dtype='object')

# %%
food.columns
# Out:
# Index(['식품코드', '식품명', '데이터구분코드', '데이터구분명', '식품기원코드', '식품기원명', '식품대분류코드',
#        '식품대분류명', '대표식품코드', '대표식품명', '식품중분류코드', '식품중분류명', '식품소분류코드', '식품소분류명',
#        '식품세분류코드', '식품세분류명', '영양성분함량기준량', '에너지', '수분', '단백질', '지방', '회분(g)',
#        '탄수화물', '당류', '식이섬유(g)', '칼슘(mg)', '철(mg)', '인(mg)', '칼륨(mg)',
#        '나트륨(mg)', '비타민 A(μg RAE)', '레티놀(μg)', '베타카로틴(μg)', '티아민(mg)',
#        '리보플라빈(mg)', '니아신(mg)', '비타민 C(mg)', '비타민 D(μg)', '콜레스테롤', '포화지방산',
#        '트랜스지방산', '출처코드', '출처명', '1회 섭취참고량', '제조사명', '식품중량', '수입업체명', '유통업체명',
#        '수입여부', '원산지국코드', '원산지국명', '데이터생성방법코드', '데이터생성방법명', '데이터생성일자',
#        '데이터기준일자', '제공기관코드', '제공기관명'],
#       dtype='object')

# %%
food.to_csv('전국통합식품영양성분정보(가공식품)표준데이터_수정.csv',encoding='MS949',index=False)

# %% [markdown]
# ---
