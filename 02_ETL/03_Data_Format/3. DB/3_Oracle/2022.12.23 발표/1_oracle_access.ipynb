# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager,rc

import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# read_csv 함수로 데이터를 Dataframe 형태로 불러옵니다.
file_path = '전국통합식품영양성분정보(가공식품)표준데이터.csv'
processed_food = pd.read_csv(file_path, encoding = 'MS949')

# %%
processed_food
# Out:
#                       식품코드                  식품명 데이터구분코드 데이터구분명  식품기원코드 식품기원명  \
# 0      P123-226020100-0088         샐러드_비프불고기샐러드       P   가공식품       1  가공식품
# 1      P123-226020100-0089      샐러드_비프타코샐러드랩의질투       P   가공식품       1  가공식품
# 2      P123-226020100-0090         샐러드_샐러드에빠진연어       P   가공식품       1  가공식품
# 3      P123-226020100-0091          샐러드_수삼초계샐러드       P   가공식품       1  가공식품
# 4      P123-226020100-0092      샐러드_쉬림프크림파스타샐러드       P   가공식품       1  가공식품
# ...                    ...                  ...     ...    ...     ...   ...
# 42602  P110-400030000-0017  영·유아용 이유식_후디스하이키드쵸코       P   가공식품       1  가공식품
# 42603  P105-001020000-0018            잼_로투스스프레드       P   가공식품       1  가공식품
# 42604  P119-900090200-0019           치즈_끼리플레인포션       P   가공식품       1  가공식품
# 42605  P119-900090200-0020              치즈_래핑카우       P   가공식품       1  가공식품
# 42606  P119-900090200-0021            치즈_래핑카우체다       P   가공식품       1  가공식품
#
#        식품대분류코드  식품대분류명  대표식품코드      대표식품명  ...  유통업체명 수입여부  원산지국코드  원산지국명  \
# 0           23   즉석식품류   23226        샐러드  ...    NaN    N     NaN    NaN
# 1           23   즉석식품류   23226        샐러드  ...    NaN    N     NaN    NaN
# 2           23   즉석식품류   23226        샐러드  ...    NaN    N     NaN    NaN
# 3           23   즉석식품류   23226        샐러드  ...    NaN    N     NaN    NaN
# 4           23   즉석식품류   23226        샐러드  ...    NaN    N     NaN    NaN
# ...        ...     ...     ...        ...  ...    ...  ...     ...    ...
# 42602       10  특수영양식품   10400  영·유아용 이유식  ...    NaN    N     NaN    NaN
# 42603        5      잼류    5001          잼  ...    NaN    Y    56.0    벨기에
# 42604       19   유가공품류   19900         치즈  ...    NaN    Y   250.0    프랑스
# 42605       19   유가공품류   19900         치즈  ...    NaN    Y   250.0    프랑스
# 42606       19   유가공품류   19900         치즈  ...    NaN    Y   703.0  슬로바키아
#
#        데이터생성방법코드 데이터생성방법명     데이터생성일자     데이터기준일자   제공기관코드     제공기관명
# 0              2       수집  2021-06-30  2022-11-23  1471000  식품의약품안전처
# 1              2       수집  2021-06-30  2022-11-23  1471000  식품의약품안전처
# 2              2       수집  2020-06-30  2022-11-23  1471000  식품의약품안전처
# 3              2       수집  2020-06-30  2022-11-23  1471000  식품의약품안전처
# 4              2       수집  2021-06-30  2022-11-23  1471000  식품의약품안전처
# ...          ...      ...         ...         ...      ...       ...
# 42602          2       수집  2019-06-30  2022-11-23  1471000  식품의약품안전처
# 42603          2       수집  2020-06-30  2022-11-23  1471000  식품의약품안전처
# 42604          2       수집  2020-06-30  2022-11-23  1471000  식품의약품안전처
# 42605          2       수집  2020-06-30  2022-11-23  1471000  식품의약품안전처
# 42606          2       수집  2020-06-30  2022-11-23  1471000  식품의약품안전처
#
# [42607 rows x 57 columns]
