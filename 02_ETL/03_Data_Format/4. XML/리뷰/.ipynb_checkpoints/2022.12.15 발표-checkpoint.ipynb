# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager,rc
from PIL import Image
import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %%
file_path = '전국전통시장표준데이터.csv'
market = pd.read_csv(file_path,encoding='cp949')

# %%
market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1521 entries, 0 to 1520
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시장명        1521 non-null   object
#  1   시장유형       1521 non-null   object
#  2   소재지도로명주소   1518 non-null   object
#  3   소재지지번주소    1521 non-null   object
#  4   시장개설주기     1521 non-null   object
#  5   위도         1521 non-null   float64
#  6   경도         1521 non-null   float64
#  7   점포수        1521 non-null   int64
#  8   취급품목       1521 non-null   object
#  9   사용가능상품권    108 non-null    object
#  10  홈페이지주소     103 non-null    object
#  11  공중화장실보유여부  1521 non-null   object
#  12  주차장보유여부    1521 non-null   object
#  13  개설연도       1502 non-null   object
#  14  전화번호       976 non-null    object
#  15  데이터기준일자    1521 non-null   object
#  16  제공기관코드     1521 non-null   object
#  17  제공기관명      1521 non-null   object
# dtypes: float64(2), int64(1), object(15)
# ...

# %% [markdown]
# * 특이 사항 없음

# %%
market.shape
# Out:
# (1521, 18)

# %% [markdown]
# * size = 1521 x 18 사이즈

# %%
market.isnull().sum()
# Out:
# 시장명             0
# 시장유형            0
# 소재지도로명주소        3
# 소재지지번주소         0
# 시장개설주기          0
# 위도              0
# 경도              0
# 점포수             0
# 취급품목            0
# 사용가능상품권      1413
# 홈페이지주소       1418
# 공중화장실보유여부       0
# 주차장보유여부         0
# 개설연도           19
# 전화번호          545
# 데이터기준일자         0
# 제공기관코드          0
# 제공기관명           0
# dtype: int64

# %% [markdown]
# * 소재지도로명주소, 사용가능상품권, 홈페이지주소, 개설연도, 전화번호 열에 결측치 존재

# %%
market.head()
# Out:
#        시장명     시장유형                   소재지도로명주소                 소재지지번주소 시장개설주기  \
# 0     용궁시장  상설장+5일장       경상북도 예천군 용궁면 용궁시장길 9  경상북도 예천군 용궁면 읍부리 329-3  4일+9일
# 1     풍양시장      5일장    경상북도 예천군 풍양면 낙상2길 37-13  경상북도 예천군 풍양면 낙상리 157-7  3일+8일
# 2  울진바지게시장  상설장+5일장     경상북도 울진군 울진읍 읍내2길 13-6     경상북도 울진군 울진읍 읍내리 63  2일+7일
# 3     죽변시장  상설장+5일장  경상북도 울진군 죽변면 죽변중앙로 168-14   경상북도 울진군 죽변면 죽변리 36-8  3일+8일
# 4     평해시장  상설장+5일장       경상북도 울진군 평해읍 평해6길 12  경상북도 울진군 평해읍 평해리 879-3  2일+7일
#
#           위도          경도  점포수                     취급품목 사용가능상품권 홈페이지주소  \
# 0  36.607018  128.275372   30  농산물+축산물+가공식품+가정용품+기타소매업     NaN    NaN
# 1  36.509273  128.299805   48       농산물+축산물+가공식품+기타소매업     NaN    NaN
# 2  36.991629  129.402070  252              농산물+축산물+수산물     NaN    NaN
# 3  37.058968  129.422254   64              농산물+축산물+수산물     NaN    NaN
# 4  36.726945  129.442436   29              농산물+축산물+수산물     NaN    NaN
#
#   공중화장실보유여부 주차장보유여부  개설연도          전화번호     데이터기준일자   제공기관코드       제공기관명
# ...

# %% [markdown]
# * 결측치 확인

# %%
market.tail()
# Out:
#          시장명 시장유형               소재지도로명주소               소재지지번주소 시장개설주기  \
# 1516  거제고현시장  상설장  경상남도 거제시 거제중앙로 1883-2    경상남도 거제시 고현동 98-27     매일
# 1517    신부시장  상설장       경상남도 거제시 신부로3길 9     경상남도 거제시 장승포동 283     매일
# 1518  옥수동새시장  상설장     경상남도 거제시 능포로 136-2    경상남도 거제시 능포동 680-1     매일
# 1519    옥수시장  상설장      경상남도 거제시 옥수로2길 10  경상남도 거제시 능포동 633-215     매일
# 1520  옥포국제시장  상설장     경상남도 거제시 옥포대첩로3길 8    경상남도 거제시 옥포동 529-1     매일
#
#              위도          경도  점포수                      취급품목 사용가능상품권 홈페이지주소  \
# 1516  34.886258  128.623655  207    농산물+축산물+수산물+가공식품+기타소매업     NaN    NaN
# 1517  34.868113  128.730088   43   축산물+수산물+가공식품+음식점업+기타소매업     NaN    NaN
# 1518  34.875713  128.732108   43            축산물+가공식품+기타소매업     NaN    NaN
# 1519  34.875344  128.730873   43  농산물+수산물+가공식품+의류/신발+기타소매업     NaN    NaN
# 1520  34.893970  128.689238  115    농산물+축산물+수산물+가공식품+기타소매업     NaN    NaN
#
#      공중화장실보유여부 주차장보유여부  개설연도          전화번호     데이터기준일자   제공기관코드       제공기관명
# ...

# %% [markdown]
# * 결측치 확인

# %%
market[market['소재지도로명주소'].isnull()].head(1)
# Out:
#       시장명     시장유형 소재지도로명주소                소재지지번주소 시장개설주기        위도  \
# 267  덕하시장  상설장+5일장      NaN  울산광역시 울주군 청량읍 상남리 578  매일+5일  35.49144
#
#              경도  점포수        취급품목 사용가능상품권 홈페이지주소 공중화장실보유여부 주차장보유여부 개설연도 전화번호  \
# 267  129.305996   14  농산물,식당,잡화류  온누리상품권    NaN         Y       Y  NaN  NaN
#
#         데이터기준일자   제공기관코드  제공기관명
# 267  2020-10-15  6310000  울산광역시

# %%
market[market['사용가능상품권'].isnull()].head(1)
# Out:
#     시장명     시장유형              소재지도로명주소                 소재지지번주소 시장개설주기  \
# 0  용궁시장  상설장+5일장  경상북도 예천군 용궁면 용궁시장길 9  경상북도 예천군 용궁면 읍부리 329-3  4일+9일
#
#           위도          경도  점포수                     취급품목 사용가능상품권 홈페이지주소  \
# 0  36.607018  128.275372   30  농산물+축산물+가공식품+가정용품+기타소매업     NaN    NaN
#
#   공중화장실보유여부 주차장보유여부  개설연도 전화번호     데이터기준일자   제공기관코드       제공기관명
# 0         Y       Y  1999  NaN  2022-07-06  B553077  소상공인시장진흥공단

# %%
market[market['홈페이지주소'].isnull()].head(1)
# Out:
#     시장명     시장유형              소재지도로명주소                 소재지지번주소 시장개설주기  \
# 0  용궁시장  상설장+5일장  경상북도 예천군 용궁면 용궁시장길 9  경상북도 예천군 용궁면 읍부리 329-3  4일+9일
#
#           위도          경도  점포수                     취급품목 사용가능상품권 홈페이지주소  \
# 0  36.607018  128.275372   30  농산물+축산물+가공식품+가정용품+기타소매업     NaN    NaN
#
#   공중화장실보유여부 주차장보유여부  개설연도 전화번호     데이터기준일자   제공기관코드       제공기관명
# 0         Y       Y  1999  NaN  2022-07-06  B553077  소상공인시장진흥공단

# %%
market[market['개설연도'].isnull()].head(1)
# Out:
#       시장명     시장유형 소재지도로명주소                소재지지번주소 시장개설주기        위도  \
# 267  덕하시장  상설장+5일장      NaN  울산광역시 울주군 청량읍 상남리 578  매일+5일  35.49144
#
#              경도  점포수        취급품목 사용가능상품권 홈페이지주소 공중화장실보유여부 주차장보유여부 개설연도 전화번호  \
# 267  129.305996   14  농산물,식당,잡화류  온누리상품권    NaN         Y       Y  NaN  NaN
#
#         데이터기준일자   제공기관코드  제공기관명
# 267  2020-10-15  6310000  울산광역시

# %%
market[market['전화번호'].isnull()].head(1)
# Out:
#     시장명     시장유형              소재지도로명주소                 소재지지번주소 시장개설주기  \
# 0  용궁시장  상설장+5일장  경상북도 예천군 용궁면 용궁시장길 9  경상북도 예천군 용궁면 읍부리 329-3  4일+9일
#
#           위도          경도  점포수                     취급품목 사용가능상품권 홈페이지주소  \
# 0  36.607018  128.275372   30  농산물+축산물+가공식품+가정용품+기타소매업     NaN    NaN
#
#   공중화장실보유여부 주차장보유여부  개설연도 전화번호     데이터기준일자   제공기관코드       제공기관명
# 0         Y       Y  1999  NaN  2022-07-06  B553077  소상공인시장진흥공단

# %%
market.fillna('',inplace=True)

# %%
market.head(1)
# Out:
#     시장명     시장유형              소재지도로명주소                 소재지지번주소 시장개설주기  \
# 0  용궁시장  상설장+5일장  경상북도 예천군 용궁면 용궁시장길 9  경상북도 예천군 용궁면 읍부리 329-3  4일+9일
#
#           위도          경도  점포수                     취급품목 사용가능상품권 홈페이지주소  \
# 0  36.607018  128.275372   30  농산물+축산물+가공식품+가정용품+기타소매업
#
#   공중화장실보유여부 주차장보유여부  개설연도 전화번호     데이터기준일자   제공기관코드       제공기관명
# 0         Y       Y  1999       2022-07-06  B553077  소상공인시장진흥공단

# %% [markdown]
# * 결측치 공백으로 처리

# %%
market_df = market.drop(['제공기관코드','제공기관명','전화번호','데이터기준일자','공중화장실보유여부','주차장보유여부'],axis=1)
market_df.tail()
# Out:
#          시장명 시장유형               소재지도로명주소               소재지지번주소 시장개설주기  \
# 1516  거제고현시장  상설장  경상남도 거제시 거제중앙로 1883-2    경상남도 거제시 고현동 98-27     매일
# 1517    신부시장  상설장       경상남도 거제시 신부로3길 9     경상남도 거제시 장승포동 283     매일
# 1518  옥수동새시장  상설장     경상남도 거제시 능포로 136-2    경상남도 거제시 능포동 680-1     매일
# 1519    옥수시장  상설장      경상남도 거제시 옥수로2길 10  경상남도 거제시 능포동 633-215     매일
# 1520  옥포국제시장  상설장     경상남도 거제시 옥포대첩로3길 8    경상남도 거제시 옥포동 529-1     매일
#
#              위도          경도  점포수                      취급품목 사용가능상품권 홈페이지주소  \
# 1516  34.886258  128.623655  207    농산물+축산물+수산물+가공식품+기타소매업
# 1517  34.868113  128.730088   43   축산물+수산물+가공식품+음식점업+기타소매업
# 1518  34.875713  128.732108   43            축산물+가공식품+기타소매업
# 1519  34.875344  128.730873   43  농산물+수산물+가공식품+의류/신발+기타소매업
# 1520  34.893970  128.689238  115    농산물+축산물+수산물+가공식품+기타소매업
#
#       개설연도
# 1516  1980
# 1517  1997
# 1518  1984
# 1519  2006
# 1520  2006

# %%
market_df
# Out:
#           시장명     시장유형                   소재지도로명주소                 소재지지번주소  \
# 0        용궁시장  상설장+5일장       경상북도 예천군 용궁면 용궁시장길 9  경상북도 예천군 용궁면 읍부리 329-3
# 1        풍양시장      5일장    경상북도 예천군 풍양면 낙상2길 37-13  경상북도 예천군 풍양면 낙상리 157-7
# 2     울진바지게시장  상설장+5일장     경상북도 울진군 울진읍 읍내2길 13-6     경상북도 울진군 울진읍 읍내리 63
# 3        죽변시장  상설장+5일장  경상북도 울진군 죽변면 죽변중앙로 168-14   경상북도 울진군 죽변면 죽변리 36-8
# 4        평해시장  상설장+5일장       경상북도 울진군 평해읍 평해6길 12  경상북도 울진군 평해읍 평해리 879-3
# ...       ...      ...                        ...                     ...
# 1516   거제고현시장      상설장      경상남도 거제시 거제중앙로 1883-2      경상남도 거제시 고현동 98-27
# 1517     신부시장      상설장           경상남도 거제시 신부로3길 9       경상남도 거제시 장승포동 283
# 1518   옥수동새시장      상설장         경상남도 거제시 능포로 136-2      경상남도 거제시 능포동 680-1
# 1519     옥수시장      상설장          경상남도 거제시 옥수로2길 10    경상남도 거제시 능포동 633-215
# 1520   옥포국제시장      상설장         경상남도 거제시 옥포대첩로3길 8      경상남도 거제시 옥포동 529-1
#
#      시장개설주기         위도          경도  점포수                      취급품목 사용가능상품권  \
# ...

# %%
market_df['시도'] = ''

# %%
market_df.columns
# Out:
# Index(['시장명', '시장유형', '소재지도로명주소', '소재지지번주소', '시장개설주기', '위도', '경도', '점포수',
#        '취급품목', '사용가능상품권', '홈페이지주소', '개설연도', '시도'],
#       dtype='object')

# %%
for i in market_df.index:
    market_df.iloc[i,12] = market_df['소재지지번주소'].str.split()[i][0]

# %%
market_df['시도']
# Out:
# 0       경상북도
# 1       경상북도
# 2       경상북도
# 3       경상북도
# 4       경상북도
#         ...
# 1516    경상남도
# 1517    경상남도
# 1518    경상남도
# 1519    경상남도
# 1520    경상남도
# Name: 시도, Length: 1521, dtype: object

# %%
market_df['시도'].value_counts() # 시각화
# Out:
# 서울특별시      215
# 부산광역시      168
# 경상남도       157
# 경기도        156
# 경상북도       150
# 전라남도       114
# 대구광역시      106
# 울산광역시       81
# 강원도         66
# 전라북도        64
# 충청남도        61
# 충청북도        57
# 인천광역시       44
# 대전광역시       28
# 광주광역시       24
# 제주특별자치도     22
# 세종특별자치시      4
# 화성시          4
# Name: 시도, dtype: int64

# %%
market_df['시도'].replace('화성시','경기도',inplace=True)
market_df['시도'].value_counts()
# Out:
# 서울특별시      215
# 부산광역시      168
# 경기도        160
# 경상남도       157
# 경상북도       150
# 전라남도       114
# 대구광역시      106
# 울산광역시       81
# 강원도         66
# 전라북도        64
# 충청남도        61
# 충청북도        57
# 인천광역시       44
# 대전광역시       28
# 광주광역시       24
# 제주특별자치도     22
# 세종특별자치시      4
# Name: 시도, dtype: int64

# %%
city_count = market_df['시도'].value_counts()

# %%
city_count = pd.DataFrame(city_count)
city_count.reset_index(inplace=True)
city_count.columns = ['시도','시장갯수']

# %%
city_count
# Out:
#          시도  시장갯수
# 0     서울특별시   215
# 1     부산광역시   168
# 2       경기도   160
# 3      경상남도   157
# 4      경상북도   150
# 5      전라남도   114
# 6     대구광역시   106
# 7     울산광역시    81
# 8       강원도    66
# 9      전라북도    64
# 10     충청남도    61
# 11     충청북도    57
# 12    인천광역시    44
# 13    대전광역시    28
# 14    광주광역시    24
# 15  제주특별자치도    22
# 16  세종특별자치시     4

# %%
 #city_count2 = city_count.sample(frc=1).reset_index(drop=True)

# %%
plt.figure(figsize=(20,6))
explode = (0, 0, 0, 0, 0, 0,0.2,0,0.2,0,0,0,0,0,0.3,0,0)
wedgeprops={'width': 0.8, 'edgecolor': 'w', 'linewidth': 2}
color=sns.color_palette('summer',len(city_count.index))
plt.subplot(1,2,1)
plt.pie(city_count['시장갯수'], labels=city_count['시도'],autopct='%.1f%%',explode=explode,wedgeprops=wedgeprops, shadow=True)
plt.title('전국 시장 분포도')
plt.subplot(1,2,2)
plt.ylim(100,250)
sns.barplot(data=city_count.head(),x="시도",y="시장갯수")
plt.title('전국 시장 갯수 순위')
plt.show()

# %% [markdown]
# * 처음 예상에는 마트가 많이 들어와있는 서울이 전통시장이 가장 적을꺼라고 생각했지만
# * 데이터 분석 결과 서울특별시에 인구 밀도수가 높아서 그에 비례하여 시장 수 또한 높았다.

# %%
p_count = market_df['사용가능상품권'].value_counts()

# %%
p_count=pd.DataFrame(p_count)
p_count.reset_index(inplace=True)
p_count
# Out:
#                      index  사용가능상품권
# 0                              1413
# 1                   온누리상품권       51
# 2        여수지역사랑상품권, 온누리상품권       16
# 3             온누리상품권+전자상품권       11
# 4                  온누리 상품권       11
# 5         온누리상품권+울산페이+제로페이        9
# 6             지역화폐, 온누리상품권        4
# 7             온누리, 태안사랑상품권        3
# 8          전통시장 상품권+온누리상품권        1
# 9   온누리상품권+화천사랑상품권+화천시장상품권        1
# 10            온누리상품권(일부점포)        1

# %%
p_count.columns = ['상품권','사용갯수']
p_count.iloc[0,0]  = '사용불가'
p_count
# Out:
#                        상품권  사용갯수
# 0                     사용불가  1413
# 1                   온누리상품권    51
# 2        여수지역사랑상품권, 온누리상품권    16
# 3             온누리상품권+전자상품권    11
# 4                  온누리 상품권    11
# 5         온누리상품권+울산페이+제로페이     9
# 6             지역화폐, 온누리상품권     4
# 7             온누리, 태안사랑상품권     3
# 8          전통시장 상품권+온누리상품권     1
# 9   온누리상품권+화천사랑상품권+화천시장상품권     1
# 10            온누리상품권(일부점포)     1

# %%
p_count.drop(0,axis=0,inplace=True)
p_count
# Out:
#                        상품권  사용갯수
# 1                   온누리상품권    51
# 2        여수지역사랑상품권, 온누리상품권    16
# 3             온누리상품권+전자상품권    11
# 4                  온누리 상품권    11
# 5         온누리상품권+울산페이+제로페이     9
# 6             지역화폐, 온누리상품권     4
# 7             온누리, 태안사랑상품권     3
# 8          전통시장 상품권+온누리상품권     1
# 9   온누리상품권+화천사랑상품권+화천시장상품권     1
# 10            온누리상품권(일부점포)     1

# %%
plt.figure(figsize=(20,6))
explode = (0.2,0,0,0,0,0,0,0,0,0)
wedgeprops={'width': 0.8, 'edgecolor': 'w', 'linewidth': 2}
color=sns.color_palette('summer',len(city_count.index))
plt.pie(p_count['사용갯수'], labels=p_count['상품권'],autopct='%.1f%%',explode=explode,wedgeprops=wedgeprops, shadow=True)
plt.title('상품권 사용 가능도')
plt.show()

# %% [markdown]
# * 전체 상품권 종류 중 전통 시장에서 사용 가능한 상품권은 압도적으로 온누리 상품권이 높다.

# %%
year_count = market_df['개설연도'].value_counts()
year_count = pd.DataFrame(year_count)
year_count.reset_index(inplace=True)
year_count.columns=['년도','증가갯수']
year_count
# Out:
#        년도  증가갯수
# 0    2005   217
# 1    2006   131
# 2    2007    74
# 3    2011    65
# 4    2009    49
# ..    ...   ...
# 98   1923     1
# 99   1919     1
# 100  1925     1
# 101  1929     1
# 102  1934     1
#
# [103 rows x 2 columns]

# %%
index=0

for i in year_count['년도']:
    if len(i) != 4:
        print(i)
        year_count.iloc[index,0] = year_count.iloc[index,0].split('-')[0]
    index += 1
# Out:
# 1935-12-15
# 1929-09-02
# 1929-03-02
# 1921-10-07

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=70)

sns.lineplot(x='년도',y='증가갯수',data=year_count.sort_values(by='년도',ascending=True))
# Out:
# <AxesSubplot:xlabel='년도', ylabel='증가갯수'>

# %% [markdown]
# *

# %%
latitude = market_df['위도']
longitude = market_df['경도']
ytick = range(33,39)
xtick = range(125,132)

# %%
fig = plt.figure(figsize = (10,10))
ax1 = fig.add_subplot(1,1,1)
ax1.scatter(y = latitude, x = longitude)
plt.ylabel('위도')
plt.xlabel('경도')
plt.title('전국 전통시장 분포도')
plt.xticks(xtick)
plt.yticks(ytick)
plt.show()
ax2 = fig.add_subplot(2,1,1)
img = Image.open('map_00.gif')
img = np.array(img)
plt.imshow(img)

# %%
allday_market = market_df.loc[market_df['시장개설주기'].str.contains('매일'),:]

# %%
day4_market = market_df.loc[market_df['시장개설주기'].str.contains('4'),:]

# %%
pd.concat(allday_market,day4_market,axis = 0)
# Out:
# C:\Users\tj\AppData\Local\Temp\ipykernel_10300\2568023629.py:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   pd.concat(allday_market,day4_market,axis = 0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10300\2568023629.py in <module>
# ----> 1 pd.concat(allday_market,day4_market,axis = 0)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: concat() got multiple values for argument 'axis'
