# %% [markdown]
# # 제 3차 조별 데이터 분석 실습
#
# * Mission
#     * 지금까지 배운 기술을 활용하여 데이터 분석을 해본다.
#     * 데이터 원본 분석을 한다.
#     * 결측치, 이상치를 점검해 본다.
#     * 전처리
#     * 탐색적 연구 (Step1, Step2를 반복하여 데이터 분석의 깊이를 더한다.)
#          * Step1] 데이터 분석을 위한 목적, 대상 또는 가설을 세워본다.
#          * Step2] 데이터 재 구조화, 시각화를 통해 새로운 insight 및 정보를 습득 및 가설을 검증한다.
#     * 최종 결론을 내린다.

# %% [markdown]
# ## 아래에 데이터를 import 하세요.

# %%
# 데이터 import 코드 구현
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from matplotlib import font_manager,rc

import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# chipo = pd.read_csv('data/book_data.csv',encoding='utf-8')

# %%
dairy_queen = pd.read_csv('../data/dairy-queen-menu-nutrition2.csv',encoding='cp949')

# %% [markdown]
# ---

# %% [markdown]
# # Dairy Queen 한국 런칭 전략 수립을 위한 영양성분 분석

# %%
dairy_queen.head()
# Out:
#                                 Menu Item  Calories (kcal)  \
# 0        Caramel Mocha Chip Shake - Small            600.0
# 1       Caramel Mocha Chip Shake - Medium            830.0
# 2        Caramel Mocha Chip Shake - Large           1100.0
# 3   Cinnamon Roll Centers Blizzard - Mini            360.0
# 4  Cinnamon Roll Centers Blizzard - Small            620.0
#
#    Fat Calories (kcal)  Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  \
# 0                100.0           27.0               21.0            1.0
# 1                170.0           39.0               31.0            1.0
# 2                230.0           52.0               41.0            1.5
# 3                300.0           13.0                8.0            0.5
# 4                240.0           22.0               14.0            1.0
#
#    Cholesterol (mg)  Sodium (mg)  Carbohydrates (g)  Fiber (g)  Sugars (g)  \
# 0              45.0        240.0               79.0        1.0        65.0
# 1              55.0        310.0              106.0        1.0        86.0
# 2              75.0        410.0              140.0        2.0       113.0
# 3              45.0        150.0               53.0        0.0        43.0
# 4              85.0        270.0               93.0        0.0        75.0
#
#    Protein (g) Allergens
# 0         12.0       M\S
# 1         16.0       M\S
# 2         20.0       M\S
# 3          8.0     E\M\W
# 4         13.0     E\M\W

# %%
dairy_queen
# Out:
#                                   Menu Item  Calories (kcal)  \
# 0          Caramel Mocha Chip Shake - Small            600.0
# 1         Caramel Mocha Chip Shake - Medium            830.0
# 2          Caramel Mocha Chip Shake - Large           1100.0
# 3     Cinnamon Roll Centers Blizzard - Mini            360.0
# 4    Cinnamon Roll Centers Blizzard - Small            620.0
# ..                                      ...              ...
# 224     Strawberry Banana Smoothie - XLarge            620.0
# 225            Tripleberry Smoothie - Large            460.0
# 226           Tripleberry Smoothie - Medium            370.0
# 227            Tripleberry Smoothie - Small            280.0
# 228           Tripleberry Smoothie - XLarge            660.0
#
#      Fat Calories (kcal)  Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  \
# 0                  100.0           27.0               21.0            1.0
# 1                  170.0           39.0               31.0            1.0
# 2                  230.0           52.0               41.0            1.5
# 3                  300.0           13.0                8.0            0.5
# 4                  240.0           22.0               14.0            1.0
# ..                   ...            ...                ...            ...
# 224                  5.0            0.5                0.0            0.0
# 225                  0.0            0.0                0.0            0.0
# 226                  0.0            0.0                0.0            0.0
# 227                  0.0            0.0                0.0            0.0
# 228                  0.0            0.0                0.0            0.0
#
#      Cholesterol (mg)  Sodium (mg)  Carbohydrates (g)  Fiber (g)  Sugars (g)  \
# 0                45.0        240.0               79.0        1.0        65.0
# 1                55.0        310.0              106.0        1.0        86.0
# 2                75.0        410.0              140.0        2.0       113.0
# 3                45.0        150.0               53.0        0.0        43.0
# 4                85.0        270.0               93.0        0.0        75.0
# ..                ...          ...                ...        ...         ...
# 224               0.0        240.0              144.0        5.0       131.0
# 225               0.0        180.0              107.0        2.0       104.0
# 226               0.0        135.0               87.0        2.0        84.0
# 227               0.0         90.0               66.0        1.0        65.0
# 228               0.0        220.0              153.0        3.0       149.0
#
#      Protein (g) Allergens
# 0           12.0       M\S
# 1           16.0       M\S
# 2           20.0       M\S
# 3            8.0     E\M\W
# 4           13.0     E\M\W
# ..           ...       ...
# 224         11.0         M
# 225          8.0         M
# 226          6.0         M
# 227          4.0         M
# 228         10.0         M
#
# [229 rows x 13 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 데이터 원본 분석
#
# ### 아래 내용을 확인하세요
# * 데이터 사이즈
# * 데이터 타입
# * 각 열의 의미 (열의 이름 및 데이터를 보고 팀원과 상의하여 분석)
# * 기타 확인하고 싶은 사항

# %%
dairy_queen.shape
# Out:
# (229, 13)

# %%
dairy_queen.dtypes
# Out:
# Menu Item               object
# Calories (kcal)        float64
# Fat Calories (kcal)    float64
# Total Fat (g)          float64
# Saturated Fat (g)      float64
# Trans Fat (g)          float64
# Cholesterol (mg)       float64
# Sodium (mg)            float64
# Carbohydrates (g)      float64
# Fiber (g)              float64
# Sugars (g)             float64
# Protein (g)            float64
# Allergens               object
# dtype: object

# %%
dairy_queen.size
# Out:
# 2977

# %%
dairy_queen.columns
# Out:
# Index(['Menu Item', 'Calories (kcal)', 'Fat Calories (kcal)', 'Total Fat (g)',
#        'Saturated Fat (g)', 'Trans Fat (g)', 'Cholesterol (mg)', 'Sodium (mg)',
#        'Carbohydrates (g)', 'Fiber (g)', 'Sugars (g)', 'Protein (g)',
#        'Allergens'],
#       dtype='object')

# %% [raw]
# 각 열의 의미
# Menu Item           : 메뉴 이름
# Calories (kcal)     : 열량
# Fat Calories (kcal) : 지방 칼로리
# Total Fat (g)       : 총 지방
# Saturated Fat (g)   : 포화 지방
# Trans Fat (g)       : 트랜스 지방
# Cholesterol (mg)    : 콜레스테롤
# Sodium (mg)         : 나트륨
# Carbohydrates (g)   : 탄수화물
# Fiber (g)           : 섬유질
# Sugars (g)          : 당분
# Protein (g)         : 단백질
# Allergens           : 알레르기 원인 물질
# E=계란 F=생선 M=우유 P=땅콩 SF=패류 S=대두 T=나무 견과류 W=밀 SS=참깨 ()=함유 가능

# %% [markdown]
# ---

# %% [markdown]
# ### 원본 데이터 분석 후 학습한 사항

# %% [markdown]
# ## 결측치, 이상치 점검
# * 누락된 값이 있는지 확인
# * 누락된 값을 다른 방식으로 표현하고 있는지도 확인. 예) -, NA, N/A 등
# * 이상치 점검.
# 예) 수치형 데이터중 특이한 min, max값, 수치형 데이터에서 정규분포를 이루는 데이터중 Outlier, 선형데이터상에 중간에 빈 데이터

# %%
dairy_queen.head()
# Out:
#                                 Menu Item  Calories (kcal)  \
# 0        Caramel Mocha Chip Shake - Small            600.0
# 1       Caramel Mocha Chip Shake - Medium            830.0
# 2        Caramel Mocha Chip Shake - Large           1100.0
# 3   Cinnamon Roll Centers Blizzard - Mini            360.0
# 4  Cinnamon Roll Centers Blizzard - Small            620.0
#
#    Fat Calories (kcal)  Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  \
# 0                100.0           27.0               21.0            1.0
# 1                170.0           39.0               31.0            1.0
# 2                230.0           52.0               41.0            1.5
# 3                300.0           13.0                8.0            0.5
# 4                240.0           22.0               14.0            1.0
#
#    Cholesterol (mg)  Sodium (mg)  Carbohydrates (g)  Fiber (g)  Sugars (g)  \
# 0              45.0        240.0               79.0        1.0        65.0
# 1              55.0        310.0              106.0        1.0        86.0
# 2              75.0        410.0              140.0        2.0       113.0
# 3              45.0        150.0               53.0        0.0        43.0
# 4              85.0        270.0               93.0        0.0        75.0
#
#    Protein (g) Allergens
# 0         12.0       M\S
# 1         16.0       M\S
# 2         20.0       M\S
# 3          8.0     E\M\W
# 4         13.0     E\M\W

# %%
dairy_queen.tail()
# Out:
#                                Menu Item  Calories (kcal)  \
# 224  Strawberry Banana Smoothie - XLarge            620.0
# 225         Tripleberry Smoothie - Large            460.0
# 226        Tripleberry Smoothie - Medium            370.0
# 227         Tripleberry Smoothie - Small            280.0
# 228        Tripleberry Smoothie - XLarge            660.0
#
#      Fat Calories (kcal)  Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  \
# 224                  5.0            0.5                0.0            0.0
# 225                  0.0            0.0                0.0            0.0
# 226                  0.0            0.0                0.0            0.0
# 227                  0.0            0.0                0.0            0.0
# 228                  0.0            0.0                0.0            0.0
#
#      Cholesterol (mg)  Sodium (mg)  Carbohydrates (g)  Fiber (g)  Sugars (g)  \
# 224               0.0        240.0              144.0        5.0       131.0
# 225               0.0        180.0              107.0        2.0       104.0
# 226               0.0        135.0               87.0        2.0        84.0
# 227               0.0         90.0               66.0        1.0        65.0
# 228               0.0        220.0              153.0        3.0       149.0
#
#      Protein (g) Allergens
# 224         11.0         M
# 225          8.0         M
# 226          6.0         M
# 227          4.0         M
# 228         10.0         M

# %%
dairy_queen.isnull().sum()
# Out:
# Menu Item               0
# Calories (kcal)         0
# Fat Calories (kcal)     0
# Total Fat (g)           0
# Saturated Fat (g)       0
# Trans Fat (g)           2
# Cholesterol (mg)        0
# Sodium (mg)             0
# Carbohydrates (g)       0
# Fiber (g)               0
# Sugars (g)              0
# Protein (g)             0
# Allergens              16
# dtype: int64

# %%
dairy_queen.loc[(np.isnan(dairy_queen['Trans Fat (g)'])), :]
# Out:
#                        Menu Item  Calories (kcal)  Fat Calories (kcal)  \
# 57   Country Gravy Dipping Sauce             70.0                 40.0
# 62  Marzetti Dijon Honey Mustard            180.0                150.0
#
#     Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  \
# 57            4.5                1.5            NaN               0.0
# 62           16.0                2.5            NaN              10.0
#
#     Sodium (mg)  Carbohydrates (g)  Fiber (g)  Sugars (g)  Protein (g)  \
# 57        360.0                6.0        0.0         1.0          0.0
# 62        230.0                7.0        0.0         7.0          0.0
#
#    Allergens
# 57     M\S\W
# 62         E

# %%
dairy_queen.loc[(pd.isnull(dairy_queen['Allergens'])), :]
# Out:
#                            Menu Item  Calories (kcal)  Fat Calories (kcal)  \
# 38                        Applesauce             45.0                  0.0
# 39                            Banana            110.0                  5.0
# 41                      Fries, Kids'            170.0                 70.0
# 48                      Fries, Large            450.0                190.0
# 49                    Fries, Regular            280.0                110.0
# 50           Lay’s® BBQ Potato Chips            230.0                140.0
# 51    Lay’s® Potato Chips - Original            240.0                140.0
# 56             BBQ Dipping Sauce Cup             90.0                  0.0
# 63   Marzetti Light Italian Dressing             15.0                 10.0
# 64    Wild Buffalo Dipping Sauce Cup             90.0                 90.0
# 169       Mango Misty® Slush - Large            390.0                  0.0
# 170      Mango Misty® Slush - Medium            290.0                  0.0
# 171       Mango Misty® Slush - Small            230.0                  0.0
# 175             Misty® Slush - Large            340.0                  0.0
# 176            Misty® Slush - Medium            260.0                  0.0
# 177             Misty® Slush - Small            200.0                  0.0
#
#      Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  \
# 38             0.0                0.0            0.0               0.0
# 39             0.0                0.0            0.0               0.0
# 41             8.0                1.0            0.0               0.0
# 48            21.0                3.0            0.0               0.0
# 49            13.0                2.0            0.0               0.0
# 50            15.0                2.0            0.0               0.0
# 51            16.0                2.0            0.0               0.0
# 56             0.0                0.0            0.0               0.0
# 63             1.0                0.0            0.0               0.0
# 64            10.0                1.0            0.0               0.0
# 169            0.0                0.0            0.0               0.0
# 170            0.0                0.0            0.0               0.0
# 171            0.0                0.0            0.0               0.0
# 175            0.0                0.0            0.0               0.0
# 176            0.0                0.0            0.0               0.0
# 177            0.0                0.0            0.0               0.0
#
#      Sodium (mg)  Carbohydrates (g)  Fiber (g)  Sugars (g)  Protein (g)  \
# 38           0.0               11.0        2.0         7.0          0.0
# 39           0.0               27.0        3.0        14.0          1.0
# 41         370.0               23.0        2.0         0.0          3.0
# 48         950.0               59.0        4.0         0.0          8.0
# 49         590.0               36.0        3.0         0.0          5.0
# 50         230.0               23.0        2.0         3.0          3.0
# 51         250.0               23.0        2.0         1.0          3.0
# 56         430.0               21.0        1.0        16.0          1.0
# 63         730.0                2.0        0.0         2.0          0.0
# 64        1000.0                1.0        0.0         0.0          0.0
# 169         60.0               99.0        0.0        95.0          0.0
# 170         45.0               74.0        0.0        71.0          0.0
# 171         35.0               57.0        0.0        55.0          0.0
# 175         55.0               86.0        0.0        85.0          0.0
# 176         40.0               65.0        0.0        64.0          0.0
# 177         35.0               50.0        0.0        50.0          0.0
#
#     Allergens
# 38        NaN
# 39        NaN
# 41        NaN
# 48        NaN
# 49        NaN
# 50        NaN
# 51        NaN
# 56        NaN
# 63        NaN
# 64        NaN
# 169       NaN
# 170       NaN
# 171       NaN
# 175       NaN
# 176       NaN
# 177       NaN

# %%
dairy_queen.describe()
# Out:
#        Calories (kcal)  Fat Calories (kcal)  Total Fat (g)  Saturated Fat (g)  \
# count       229.000000           229.000000     229.000000         229.000000
# mean        567.292576           207.694323      23.093013          12.174672
# std         313.542447           151.594545      16.852665           8.975359
# min          15.000000             0.000000       0.000000           0.000000
# 25%         330.000000           100.000000      12.000000           5.000000
# 50%         500.000000           180.000000      20.000000          11.000000
# 75%         760.000000           290.000000      32.000000          18.000000
# max        1510.000000           650.000000      72.000000          41.000000
#
#        Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  Carbohydrates (g)  \
# count     227.000000        229.000000   229.000000         229.000000
# mean        0.650661         46.004367   469.759825          77.489083
# std         0.657050         36.692714   514.575544          45.169623
# min         0.000000          0.000000     0.000000           1.000000
# 25%         0.000000         25.000000   180.000000          40.000000
# 50%         0.500000         45.000000   290.000000          73.000000
# 75%         1.000000         65.000000   520.000000         106.000000
# max         2.500000        180.000000  2710.000000         203.000000
#
#         Fiber (g)  Sugars (g)  Protein (g)
# count  229.000000  229.000000   229.000000
# mean     1.366812   58.270742    13.479476
# std      1.458772   42.420783     9.637712
# min      0.000000    0.000000     0.000000
# 25%      0.000000   14.000000     8.000000
# 50%      1.000000   58.000000    12.000000
# 75%      2.000000   87.000000    18.000000
# max      9.000000  158.000000    49.000000

# %% [markdown]
# ---

# %% [markdown]
# ## 결측치, 이상치 처리 방안 결정
# * Trans Fat 결측치의 경우 아래와 같이 dairy_queen 사이트에 영양정보가 있으며 트랜스 지방은 두 종류 다 0g이다.
# * Allergens 결측치의 경우 알레르기를 유발하는 물질이 있지 않음을 표시하는 의미로 '없음'으로 처리하기로 한다.
# * 그 외 특별한 이상치는 없는 것으로 추정된다.

# %% [markdown]
# ![image-2.png](attachment:image-2.png) ![image.png](attachment:image.png)

# %%
dairy_queen['Trans Fat (g)']=dairy_queen['Trans Fat (g)'].fillna('0')

# %%
dairy_queen['Allergens']=dairy_queen['Allergens'].fillna('None')

# %%
dairy_queen.isnull().sum()
# Out:
# Menu Item              0
# Calories (kcal)        0
# Fat Calories (kcal)    0
# Total Fat (g)          0
# Saturated Fat (g)      0
# Trans Fat (g)          0
# Cholesterol (mg)       0
# Sodium (mg)            0
# Carbohydrates (g)      0
# Fiber (g)              0
# Sugars (g)             0
# Protein (g)            0
# Allergens              0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## 전처리 작업

# %%
dairy_queen.head()
# Out:
#                                 Menu Item  Calories (kcal)  \
# 0        Caramel Mocha Chip Shake - Small            600.0
# 1       Caramel Mocha Chip Shake - Medium            830.0
# 2        Caramel Mocha Chip Shake - Large           1100.0
# 3   Cinnamon Roll Centers Blizzard - Mini            360.0
# 4  Cinnamon Roll Centers Blizzard - Small            620.0
#
#    Fat Calories (kcal)  Total Fat (g)  Saturated Fat (g) Trans Fat (g)  \
# 0                100.0           27.0               21.0           1.0
# 1                170.0           39.0               31.0           1.0
# 2                230.0           52.0               41.0           1.5
# 3                300.0           13.0                8.0           0.5
# 4                240.0           22.0               14.0           1.0
#
#    Cholesterol (mg)  Sodium (mg)  Carbohydrates (g)  Fiber (g)  Sugars (g)  \
# 0              45.0        240.0               79.0        1.0        65.0
# 1              55.0        310.0              106.0        1.0        86.0
# 2              75.0        410.0              140.0        2.0       113.0
# 3              45.0        150.0               53.0        0.0        43.0
# 4              85.0        270.0               93.0        0.0        75.0
#
#    Protein (g) Allergens
# 0         12.0       M\S
# 1         16.0       M\S
# 2         20.0       M\S
# 3          8.0     E\M\W
# 4         13.0     E\M\W

# %% [markdown]
# ---

# %% [markdown]
# ## 1차 탐색적 분석
# ### Step1
# #### 데이터 분석의 목적, 대상 또는 가설을 세운다.
# * 데이터 분석의 목적 : dairy_queen의 미국 현지 메뉴 영양 성분 분석을 통한 한국 현지화 전략 수립하고자 한다.
# * 데이터 분석의 대상 : dairy_queen 메뉴의 영양성분 정보
# * 가설 : 미국 현지 메뉴의 경우 지방 및 당분이 다량 함류된 고열량 메뉴가 주를 이루고 있을 것이다.

# %% [markdown]
# ### Step2
# Step1에서 세운 가설을 지금까지 배운 모든 기술을 활용하여 검증해 보세요.
# 예) 통계자료, 데이터 재구조화, 시각화등

# %%
blizzard = dairy_queen[dairy_queen['Menu Item'].str.contains('Blizzard')]

# %%
blizzard = blizzard[~blizzard['Menu Item'].str.contains('Cake', case=False)]

# %%
blizzard_large = blizzard[blizzard['Menu Item'].str.contains('Large')]
blizzard_large
# Out:
#                                              Menu Item  Calories (kcal)  \
# 6               Cinnamon Roll Centers Blizzard - Large           1170.0
# 10               Frosted Sugar Cookie Blizzard - Large           1240.0
# 16                        Pumpkin Pie Blizzard - Large            940.0
# 76                      Butterfinger® Blizzard - Large            970.0
# 80              Choco Brownie Extreme Blizzard - Large           1120.0
# 84        Chocolate Chip Cookie Dough Blizzard - Large           1340.0
# 88                             Heath® Blizzard - Large           1150.0
# 92             M&M’s® Chocolate Candy Blizzard - Large           1100.0
# 96                       OREO® Cookie Blizzard - Large           1140.0
# 100                   OREO® Hot Cocoa Blizzard - Large           1390.0
# 104       Reese's® Peanut Butter Cups Blizzard - Large           1000.0
# 108                Reese's® Take Five Blizzard - Large           1510.0
# 116  Royal Ultimate Choco Brownie Blizzard Filled w...           1340.0
# 120                         Snickers® Blizzard - Large           1060.0
# 124                 Snickers® Brownie Blizzard - Large           1350.0
# 128              Turtle Pecan Cluster Blizzard - Large           1370.0
# 132                  Very Cherry Chip Blizzard - Large            920.0
#
#      Fat Calories (kcal)  Total Fat (g)  Saturated Fat (g) Trans Fat (g)  \
# 6                  470.0           43.0               27.0           2.0
# 10                 390.0           55.0               24.0           1.5
# 16                 270.0           32.0               19.0           1.5
# 76                 310.0           34.0               20.0           1.0
# 80                 460.0           52.0               28.0           1.0
# 84                 480.0           53.0               32.0           1.0
# 88                 450.0           50.0               32.0           1.5
# 92                 320.0           36.0               23.0           1.0
# 96                 400.0           44.0               21.0           1.0
# 100                540.0           60.0               28.0           1.5
# 104                380.0           42.0               21.0           1.0
# 108                590.0           66.0               28.0           1.5
# 116                540.0           60.0               36.0           1.0
# 120                320.0           36.0               20.0           1.0
# 124                450.0           50.0               26.0           1.5
# 128                640.0           71.0               41.0           1.5
# 132                290.0           32.0               22.0           1.0
#
#      Cholesterol (mg)  Sodium (mg)  Carbohydrates (g)  Fiber (g)  Sugars (g)  \
# 6               160.0        520.0              175.0        1.0       139.0
# 10               95.0        520.0              167.0        1.0       129.0
# 16               70.0        570.0              145.0        2.0       112.0
# 76               75.0        440.0              142.0        2.0       108.0
# 80               70.0        510.0              154.0        6.0       120.0
# 84               75.0        740.0              195.0        3.0       143.0
# 88               85.0        590.0              159.0        2.0       142.0
# 92               80.0        350.0              173.0        3.0       150.0
# 96               75.0        570.0              169.0        2.0       128.0
# 100              80.0        680.0              195.0        4.0       150.0
# 104              80.0        510.0              136.0        3.0       118.0
# 108              90.0       1150.0              198.0        6.0       151.0
# 116              80.0        620.0              186.0        8.0       148.0
# 120              80.0        450.0              162.0        2.0       138.0
# 124              90.0        680.0              203.0        4.0       158.0
# 128              85.0        510.0              165.0        4.0       132.0
# 132              80.0        310.0              143.0        2.0       122.0
#
#      Protein (g)            Allergens
# 6           22.0                E\M\W
# 10          22.0              E\M\S\W
# 16          19.0              E\M\S\W
# 76          24.0    M\P\S\(E)\(T)\(W)
# 80          22.0              E\M\S\W
# 84          22.0                M\S\W
# 88          20.0    M\S\T\(E)\(P)\(W)
# 92          22.0  M\S\(E)\(P)\(T)\(W)
# 96          21.0                M\S\W
# 100         24.0                M\S\W
# 104         25.0    M\P\S\(E)\(T)\(W)
# 108         39.0      M\P\S\W\(E)\(T)
# 116         25.0              E\M\S\W
# 120         24.0          E\M\P\S\(T)
# 124         28.0        E\M\P\S\W\(T)
# 128         24.0                M\S\T
# 132         20.0                  M\S

# %%
blizzard_large.describe().mean()
# Out:
# Calories (kcal)        919.619610
# Fat Calories (kcal)    339.368942
# Total Fat (g)           40.127602
# Saturated Fat (g)       23.064595
# Cholesterol (mg)        74.089629
# Sodium (mg)            485.635688
# Carbohydrates (g)      131.598657
# Fiber (g)                5.019567
# Sugars (g)             105.066777
# Protein (g)             21.403791
# dtype: float64

# %% [markdown]
# ### 경쟁사 제품 영양정보 예시

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 참고) 한국 일일 영양성분 기준치

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 1차 가설과 같이 dairy_queen 미국 메뉴는 동일한 한국 경쟁사 메뉴와 비교하여 각 영양소가 2배가까이 함유되어있었다.
#   이는 한국 일일 영양성분 기준치와 비교하여 당류는 1잔, 단백질은 2잔반, 포화지방은 0.8잔등 시그니쳐 메뉴인 블리자드
#   라지사이즈 밀크쉐이크 1잔이면 기준치를 충족하는 것으로 보인다.

# %%
temp = dairy_queen['Allergens'].str.split('\\')
sum = []

# %%
dairy_queen['Allergens'].str.split('\\')
# Out:
# 0         [M, S]
# 1         [M, S]
# 2         [M, S]
# 3      [E, M, W]
# 4      [E, M, W]
#          ...
# 224          [M]
# 225          [M]
# 226          [M]
# 227          [M]
# 228          [M]
# Name: Allergens, Length: 229, dtype: object

# %%
sum + temp[0]
# Out:
# ['M', 'S']

# %%
for i in range(len(temp)):
   sum += temp[i]

# %%
word_list =['E','F','M','P','SF','S','T','W','SS']
aller = []
for word in word_list:
    percent = (dairy_queen["Allergens"].str.contains(word).value_counts()[1] / dairy_queen.shape[0]) * 100
    aller.append(percent)

# %%
aller
# Out:
# [31.004366812227076,
#  0.8733624454148471,
#  85.58951965065502,
#  17.03056768558952,
#  0.43668122270742354,
#  64.19213973799127,
#  18.777292576419214,
#  52.838427947598255,
#  6.11353711790393]

# %%
x = ['달걀','생선','우유','땅콩','어패류','대두','견과류','밀','참깨']

# %%
df = pd.DataFrame({'알레르기 유발 식품' : x, '퍼센트' : aller})
df = df.sort_values(by=['퍼센트'], ascending=False)

# %%
df.plot.bar(x='알레르기 유발 식품', y='퍼센트')
plt.xticks(rotation = 0, size = 9)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ## 1차 탐색적 분석
# ### Step1
# #### 데이터 분석의 목적, 대상 또는 가설을 세운다.
# * 데이터 분석의 목적 : dairy_queen의 미국 현지 메뉴 영양 성분 분석을 통한 한국 현지화 전략 수립하고자 한다.
# * 데이터 분석의 대상 : dairy_queen 메뉴의 영양성분 정보
# * 가설 : 미국 현지 메뉴의 경우 지방 및 당분이 다량 함류된 고열량 메뉴가 주를 이루고 있을 것이다.

# %% [markdown]
# ## 2차 탐색적 데이터 분석

# %% [markdown]
# * 1차 가설과 같이 dairy_queen 미국 메뉴는 동일한 한국 경쟁사 메뉴와 비교하여 각 영양소가 2배가까이 함유되어있었다.
#   이는 한국 일일 영양성분 기준치와 비교하여 당류는 1잔, 단백질은 2잔반, 포화지방은 0.8잔등 시그니쳐 메뉴인 블리자드
#   라지사이즈 밀크쉐이크 1잔이면 기준치를 충족하는 것으로 보인다.
# * 2차 분석중 Allergens 열과 관련하여 미국 현지 기준의 알러지 유발물질로 인식하였다.
#   이에 전체 각 알러지 유발물질의 함유율을 분석해본 결과 한국인의 알러지 원인 비율에 맞지 않는 것으로 보인다.

# %% [markdown]
# ---

# %% [markdown]
# ## 최종결론
# * dairy_queen의 한국 현지화 전략으로 한국인에게 맞는 메뉴 개발 및 소재 변경을 통하여 제품의 과다한 영양소를 낮추는 전략이
#   필요한 것으로 보인다.
# * 또한 알러지 유발식품을 회피하기 위하여 우유는 두유로 교체하는 등으로 재료 변경등의 전략이 필요해보인다.
