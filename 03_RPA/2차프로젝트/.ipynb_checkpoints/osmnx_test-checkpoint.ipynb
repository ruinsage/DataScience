# %%
import osmnx as ox
import networkx as nx
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import folium
import geopandas as gpd
ox.config(use_cache=True, log_console=True)
ox.__version__
# Out:
# C:\Users\tj\AppData\Roaming\Python\Python39\site-packages\osmnx\utils.py:192: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   warnings.warn(
# '1.3.0'

# %%
place = 'Piedmont, California, USA'
G = ox.graph_from_place(place, network_type='drive')

orig = list(G)[0]
dest = list(G)[120]

# 거리 기반 최단경로 1개 탐색
route = ox.shortest_path(G, orig, dest, weight='length')
fig1_1, ax = ox.plot_graph_route(G, route, route_color='y', route_linewidth=6, node_size=0.5)

# %%
gw = ox.graph_from_point((33.321919, 126.166455), network_type='drive')
ox.plot_graph(gw)
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot:>)

# %% [raw]
# G = ox.graph_from_place('동대문구, 서울, 대한민국', network_type='drive')
# fig, ax = ox.plot_graph(G)
# rig_node = ox.nearest_nodes(G, 37.5804100, 127.0462200) #청량리역
# dest_node = ox.nearest_nodes(G_proj, 37.5718616, 127.0114887) #동대문역
# route = nx.shortest_path(G, rig_node, dest_node, weight='length')
# fig1_1, ax = ox.plot_graph_route(G, route, route_color='y', route_linewidth=6, node_size=0.5)

# %% [raw]
# G = ox.graph_from_place('안동시, 경상북도, 대한민국', network_type='drive', simplify=False)
# fig, ax = ox.plot_graph(G, fig_height=12, node_size=0, edge_linewidth=0.5)

# %%
place = '제주시,제주특별자치도,대한민국'
G = ox.graph_from_place(place, network_type='drive')
fig, ax = ox.plot_graph(G)

# %%
G_proj = ox.project_graph(G)
orig_node = ox.nearest_nodes(G,33.32248, 120)
dest_node = ox.nearest_nodes(G_proj, 33.33938, 126.16745)
route = nx.shortest_path(G, orig_node, dest_node, weight='length')
fig1_2, ax = ox.plot_graph_route(G, route, route_color='y', route_linewidth=6, node_size=0.5)

# %%
len = nx.shortest_path_length(G, orig_node, dest_node, weight='length') / 1000
print(round(len, 1), "킬로미터")

# %%
route_graph_map = ox.plot_route_folium(G, route, popup_attribute='length')
route_graph_map.save('route_graph.html')
