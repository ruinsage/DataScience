# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import urllib.request
from bs4 import BeautifulSoup
import re
import urllib.request as ur
import pandas as pd

# %%
base_options = Options()
base_options.add_experimental_option("detach", True)
base_service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=base_service, options=base_options)
# 가상의 크롬브라우저 실행

url = "https://map.kakao.com/"

driver.get(url)

time.sleep(1)
driver.find_element(By.CLASS_NAME, "tf_keyword").send_keys("제주도렌트카\n")
time.sleep(1)
driver.find_element(By.XPATH, '//*[@id="info.searchHeader.message"]/div/div[2]/a').send_keys(Keys.ENTER)
time.sleep(1)


all_rent_page = []

soup1=BeautifulSoup(driver.page_source,'html.parser')
tags1 = soup1.find_all('li', {"class" : "PlaceItem clickArea"})
rent_company=re.compile('[<]a.*href[=]["](http.*[#]comment)["]\starget')
company_page=rent_company.findall(str(tags1))
for page_num in company_page:
    all_rent_page.append(page_num)

    time.sleep(1)
driver.find_element(By.XPATH, '//*[@id="info.search.place.more"]').send_keys(Keys.ENTER)
time.sleep(1)
soup2=BeautifulSoup(driver.page_source,'html.parser')
tags2 = soup2.find_all('li', {"class" : "PlaceItem clickArea"})
rent_company=re.compile('[<]a.*href[=]["](http.*[#]comment)["]\starget')
company_page2=rent_company.findall(str(tags2))
for page_num2 in company_page2:
    all_rent_page.append(page_num2)

for search_page in range(3,6):
    page_xpath = '//*[@id="info.search.page.no'+str(search_page)+'"]'
    
    time.sleep(1)
    driver.find_element(By.XPATH, page_xpath).send_keys(Keys.ENTER)
    time.sleep(1)
    
    soup3=BeautifulSoup(driver.page_source,'html.parser') 
    tags3 = soup3.find_all('li', {"class" : "PlaceItem clickArea"})
    rent_company=re.compile('[<]a.*href[=]["](http.*[#]comment)["]\starget')
    company_page3=rent_company.findall(str(tags3))
    for page_num3 in company_page3:
        all_rent_page.append(page_num3)

driver.find_element(By.XPATH, '//*[@id="info.search.page.next"]').send_keys(Keys.ENTER)
for search_page in range(1,6):
    page_xpath2 = '//*[@id="info.search.page.no'+str(search_page)+'"]'
    
    time.sleep(1)
    driver.find_element(By.XPATH, page_xpath2).send_keys(Keys.ENTER)
    time.sleep(1)
    
    soup4=BeautifulSoup(driver.page_source,'html.parser') 
    tags4 = soup4.find_all('li', {"class" : "PlaceItem clickArea"})
    rent_company=re.compile('[<]a.*href[=]["](http.*[#]comment)["]\starget')
    company_page4=rent_company.findall(str(tags4))
    for page_num4 in company_page4:
        all_rent_page.append(page_num4)

driver.find_element(By.XPATH, '//*[@id="info.search.page.next"]').send_keys(Keys.ENTER)
for search_page in range(1,4):
    page_xpath3 = '//*[@id="info.search.page.no'+str(search_page)+'"]'
    
    time.sleep(1)
    driver.find_element(By.XPATH, page_xpath3).send_keys(Keys.ENTER)
    time.sleep(1)
    
    soup5=BeautifulSoup(driver.page_source,'html.parser') 
    tags5 = soup5.find_all('li', {"class" : "PlaceItem clickArea"})
    rent_company=re.compile('[<]a.*href[=]["](http.*[#]comment)["]\starget')
    company_page5=rent_company.findall(str(tags5))
    for page_num5 in company_page5:
        all_rent_page.append(page_num5)

# %%
all_rent_page
# Out:
# ['https://place.map.kakao.com/1709068029#comment',
#  'https://place.map.kakao.com/746860953#comment',
#  'https://place.map.kakao.com/14825965#comment',
#  'https://place.map.kakao.com/1762689033#comment',
#  'https://place.map.kakao.com/10620530#comment',
#  'https://place.map.kakao.com/26887342#comment',
#  'https://place.map.kakao.com/25769803#comment',
#  'https://place.map.kakao.com/26521408#comment',
#  'https://place.map.kakao.com/777468585#comment',
#  'https://place.map.kakao.com/1257647888#comment',
#  'https://place.map.kakao.com/657323754#comment',
#  'https://place.map.kakao.com/2014474020#comment',
#  'https://place.map.kakao.com/15328807#comment',
#  'https://place.map.kakao.com/14752017#comment',
#  'https://place.map.kakao.com/8433016#comment',
#  'https://place.map.kakao.com/1008363228#comment',
#  'https://place.map.kakao.com/14951073#comment',
#  'https://place.map.kakao.com/97285313#comment',
#  'https://place.map.kakao.com/13128056#comment',
#  'https://place.map.kakao.com/1278792865#comment',
#  'https://place.map.kakao.com/1590587423#comment',
#  'https://place.map.kakao.com/1573434157#comment',
#  'https://place.map.kakao.com/26410926#comment',
#  'https://place.map.kakao.com/1246504106#comment',
#  'https://place.map.kakao.com/452179586#comment',
#  'https://place.map.kakao.com/12396156#comment',
#  'https://place.map.kakao.com/26794322#comment',
#  'https://place.map.kakao.com/20435418#comment',
#  'https://place.map.kakao.com/132616791#comment',
#  'https://place.map.kakao.com/1040551334#comment',
#  'https://place.map.kakao.com/1775530391#comment',
#  'https://place.map.kakao.com/1279272310#comment',
#  'https://place.map.kakao.com/23233462#comment',
#  'https://place.map.kakao.com/801793631#comment',
#  'https://place.map.kakao.com/23306577#comment',
#  'https://place.map.kakao.com/17143332#comment',
#  'https://place.map.kakao.com/19360327#comment',
#  'https://place.map.kakao.com/25611578#comment',
#  'https://place.map.kakao.com/227103139#comment',
#  'https://place.map.kakao.com/490730093#comment',
#  'https://place.map.kakao.com/17385746#comment',
#  'https://place.map.kakao.com/11084802#comment',
#  'https://place.map.kakao.com/251018047#comment',
#  'https://place.map.kakao.com/1243270632#comment',
#  'https://place.map.kakao.com/1198801448#comment',
#  'https://place.map.kakao.com/14935399#comment',
#  'https://place.map.kakao.com/347472732#comment',
#  'https://place.map.kakao.com/1095110680#comment',
#  'https://place.map.kakao.com/21211496#comment',
#  'https://place.map.kakao.com/10594478#comment',
#  'https://place.map.kakao.com/17868198#comment',
#  'https://place.map.kakao.com/41971535#comment',
#  'https://place.map.kakao.com/27600795#comment',
#  'https://place.map.kakao.com/250792642#comment',
#  'https://place.map.kakao.com/175179946#comment',
#  'https://place.map.kakao.com/230685883#comment',
#  'https://place.map.kakao.com/10609822#comment',
#  'https://place.map.kakao.com/1935905180#comment',
#  'https://place.map.kakao.com/25118589#comment',
#  'https://place.map.kakao.com/386041191#comment',
#  'https://place.map.kakao.com/18211713#comment',
#  'https://place.map.kakao.com/27054790#comment',
#  'https://place.map.kakao.com/1301477495#comment',
#  'https://place.map.kakao.com/1409474938#comment',
#  'https://place.map.kakao.com/27319953#comment',
#  'https://place.map.kakao.com/26938542#comment',
#  'https://place.map.kakao.com/24963077#comment',
#  'https://place.map.kakao.com/317770652#comment',
#  'https://place.map.kakao.com/1504713683#comment',
#  'https://place.map.kakao.com/1526991673#comment',
#  'https://place.map.kakao.com/1844324780#comment',
#  'https://place.map.kakao.com/2019292758#comment',
#  'https://place.map.kakao.com/1423920787#comment',
#  'https://place.map.kakao.com/20580988#comment',
#  'https://place.map.kakao.com/1969706027#comment',
#  'https://place.map.kakao.com/13011546#comment',
#  'https://place.map.kakao.com/849248412#comment',
#  'https://place.map.kakao.com/18488643#comment',
#  'https://place.map.kakao.com/2001392507#comment',
#  'https://place.map.kakao.com/21733597#comment',
#  'https://place.map.kakao.com/1294579489#comment',
#  'https://place.map.kakao.com/1489147341#comment',
#  'https://place.map.kakao.com/62974884#comment',
#  'https://place.map.kakao.com/26932836#comment',
#  'https://place.map.kakao.com/55866338#comment',
#  'https://place.map.kakao.com/1327322844#comment',
#  'https://place.map.kakao.com/429897533#comment',
#  'https://place.map.kakao.com/7940644#comment',
#  'https://place.map.kakao.com/531388305#comment',
#  'https://place.map.kakao.com/14859018#comment',
#  'https://place.map.kakao.com/1255542005#comment',
#  'https://place.map.kakao.com/25996630#comment',
#  'https://place.map.kakao.com/2055149896#comment',
#  'https://place.map.kakao.com/1398782408#comment',
#  'https://place.map.kakao.com/328479733#comment',
#  'https://place.map.kakao.com/1448008031#comment',
#  'https://place.map.kakao.com/9085651#comment',
#  'https://place.map.kakao.com/1540062178#comment',
#  'https://place.map.kakao.com/1056817069#comment',
#  'https://place.map.kakao.com/12319035#comment',
#  'https://place.map.kakao.com/479427491#comment',
#  'https://place.map.kakao.com/11282390#comment',
#  'https://place.map.kakao.com/246672209#comment',
#  'https://place.map.kakao.com/8041449#comment',
#  'https://place.map.kakao.com/323410970#comment',
#  'https://place.map.kakao.com/1755386334#comment',
#  'https://place.map.kakao.com/1811016114#comment',
#  'https://place.map.kakao.com/292605954#comment',
#  'https://place.map.kakao.com/15956601#comment',
#  'https://place.map.kakao.com/268801150#comment',
#  'https://place.map.kakao.com/27579449#comment',
#  'https://place.map.kakao.com/24759364#comment',
#  'https://place.map.kakao.com/2041764006#comment',
#  'https://place.map.kakao.com/1438170576#comment',
#  'https://place.map.kakao.com/374945386#comment',
#  'https://place.map.kakao.com/241934269#comment',
#  'https://place.map.kakao.com/801966900#comment',
#  'https://place.map.kakao.com/1271427954#comment',
#  'https://place.map.kakao.com/736450682#comment',
#  'https://place.map.kakao.com/954809763#comment',
#  'https://place.map.kakao.com/14093548#comment',
#  'https://place.map.kakao.com/993769549#comment',
#  'https://place.map.kakao.com/2136501797#comment',
#  'https://place.map.kakao.com/1212373742#comment',
#  'https://place.map.kakao.com/1107918238#comment',
#  'https://place.map.kakao.com/690708751#comment',
#  'https://place.map.kakao.com/1492123479#comment',
#  'https://place.map.kakao.com/59064937#comment',
#  'https://place.map.kakao.com/1200750242#comment',
#  'https://place.map.kakao.com/183265029#comment',
#  'https://place.map.kakao.com/656491018#comment',
#  'https://place.map.kakao.com/1355326806#comment',
#  'https://place.map.kakao.com/12156591#comment',
#  'https://place.map.kakao.com/9314025#comment',
#  'https://place.map.kakao.com/70983628#comment',
#  'https://place.map.kakao.com/1058462594#comment',
#  'https://place.map.kakao.com/210507257#comment',
#  'https://place.map.kakao.com/16745877#comment',
#  'https://place.map.kakao.com/1468895767#comment',
#  'https://place.map.kakao.com/1831531117#comment',
#  'https://place.map.kakao.com/1355550623#comment',
#  'https://place.map.kakao.com/1998280041#comment',
#  'https://place.map.kakao.com/24764839#comment',
#  'https://place.map.kakao.com/17940761#comment',
#  'https://place.map.kakao.com/10804673#comment',
#  'https://place.map.kakao.com/17673118#comment',
#  'https://place.map.kakao.com/27527607#comment',
#  'https://place.map.kakao.com/400227802#comment',
#  'https://place.map.kakao.com/1202775036#comment',
#  'https://place.map.kakao.com/1082768527#comment',
#  'https://place.map.kakao.com/540321788#comment',
#  'https://place.map.kakao.com/18801206#comment',
#  'https://place.map.kakao.com/1580657752#comment',
#  'https://place.map.kakao.com/1098506214#comment',
#  'https://place.map.kakao.com/635534881#comment',
#  'https://place.map.kakao.com/1548026500#comment',
#  'https://place.map.kakao.com/26418409#comment',
#  'https://place.map.kakao.com/564676511#comment',
#  'https://place.map.kakao.com/982377677#comment',
#  'https://place.map.kakao.com/1690567036#comment',
#  'https://place.map.kakao.com/10944941#comment',
#  'https://place.map.kakao.com/17266597#comment',
#  'https://place.map.kakao.com/437807628#comment',
#  'https://place.map.kakao.com/687752220#comment',
#  'https://place.map.kakao.com/571322596#comment',
#  'https://place.map.kakao.com/42317428#comment',
#  'https://place.map.kakao.com/2072893496#comment',
#  'https://place.map.kakao.com/20033987#comment',
#  'https://place.map.kakao.com/399961245#comment',
#  'https://place.map.kakao.com/473769104#comment',
#  'https://place.map.kakao.com/1981347324#comment',
#  'https://place.map.kakao.com/1925542408#comment',
#  'https://place.map.kakao.com/1619669498#comment',
#  'https://place.map.kakao.com/1985385539#comment',
#  'https://place.map.kakao.com/1658414980#comment',
#  'https://place.map.kakao.com/1154520709#comment',
#  'https://place.map.kakao.com/208784086#comment',
#  'https://place.map.kakao.com/10874477#comment',
#  'https://place.map.kakao.com/1903470188#comment',
#  'https://place.map.kakao.com/27445705#comment',
#  'https://place.map.kakao.com/561308584#comment',
#  'https://place.map.kakao.com/1202518555#comment',
#  'https://place.map.kakao.com/990921948#comment',
#  'https://place.map.kakao.com/452411056#comment',
#  'https://place.map.kakao.com/691654269#comment',
#  'https://place.map.kakao.com/483777957#comment',
#  'https://place.map.kakao.com/1568005762#comment',
#  'https://place.map.kakao.com/762756110#comment',
#  'https://place.map.kakao.com/399855285#comment',
#  'https://place.map.kakao.com/27559439#comment',
#  'https://place.map.kakao.com/369567086#comment',
#  'https://place.map.kakao.com/1902777910#comment',
#  'https://place.map.kakao.com/1471951086#comment']

# %%
len(all_rent_page)
# Out:
# 193

# %%
all_rent_page[192]
# Out:
# 'https://place.map.kakao.com/1471951086#comment'

# %%
all_review_data = []

# %%
for com_num in range(len(all_rent_page)):

    url2 = all_rent_page[com_num]
    print(url2)
    driver.get(url2)
    time.sleep(1)
    soup6=BeautifulSoup(driver.page_source,'html.parser')
    time.sleep(1)  
            
    category2 = soup6.find(attrs = {'class' : 'txt_location'}).text
    print(category2)

    if '렌터카' in category2:
        
        while True:
            time.sleep(1)
            soup6=BeautifulSoup(driver.page_source,'html.parser')
            time.sleep(1)

            if soup6.find(attrs = {'class' : 'cont_evaluation'}).text:
                if soup6.find(attrs = {'class' : 'link_more'}):
                    if soup6.find(attrs = {'class' : 'link_more'}).text == '후기 더보기':
                        more_review = soup6.find(attrs = {'class' : 'link_more'}).text
                        time.sleep(1)
                        driver.find_element(By.CLASS_NAME, "link_more").click()
                        time.sleep(1)
                    else:
                        tags6 = soup6.find_all('div', {"class" : "cont_evaluation"})
                        com_name = soup6.find('h2', {"class" : "tit_location"}).text

                        rent_name=re.compile('link_user.*#none["][>](.*)[<][/]a[>]\n')
                        writer_name=rent_name.findall(str(tags6))

                        rent_date=re.compile('time_write["][>]20(.*)[<][/]span[>]')
                        rent_date2=rent_date.findall(str(tags6))

                        rent_score=re.compile('style[=]["]width[:](.*)[%][;]["][>][<][/]span[>]')
                        rent_score2=rent_score.findall(str(tags6))

                        rent_coment=re.compile('<span>(.*)[<][/]span[>]')
                        rent_coment2=rent_coment.findall(str(tags6))

                        for num in range(0,len(writer_name)):
                            row_reiew_data = []
                            row_reiew_data.append(writer_name[num])
                            row_reiew_data.append(rent_coment2[num])
                            row_reiew_data.append('카카오맵')
                            number_score = int(rent_score2[num])//20
                            row_reiew_data.append(number_score)
                            row_reiew_data.append(rent_date2[num])
                            row_reiew_data.append(com_name)
                            all_review_data.append(row_reiew_data)
                        break
                else:
                    tags6 = soup6.find_all('div', {"class" : "cont_evaluation"})
                    com_name = soup6.find('h2', {"class" : "tit_location"}).text

                    rent_name=re.compile('link_user.*#none["][>](.*)[<][/]a[>]\n')
                    writer_name=rent_name.findall(str(tags6))

                    rent_date=re.compile('time_write["][>]20(.*)[<][/]span[>]')
                    rent_date2=rent_date.findall(str(tags6))

                    rent_score=re.compile('style[=]["]width[:](.*)[%][;]["][>][<][/]span[>]')
                    rent_score2=rent_score.findall(str(tags6))

                    rent_coment=re.compile('<span>(.*)[<][/]span[>]')
                    rent_coment2=rent_coment.findall(str(tags6))

                    for num in range(0,len(writer_name)):
                        row_reiew_data = []
                        row_reiew_data.append(writer_name[num])
                        row_reiew_data.append(rent_coment2[num])
                        row_reiew_data.append('카카오맵')
                        number_score = int(rent_score2[num])//20
                        row_reiew_data.append(number_score)
                        row_reiew_data.append(rent_date2[num])
                        row_reiew_data.append(com_name)
                        all_review_data.append(row_reiew_data)
                    break
            else:
                break

all_review_data
# Out:
# https://place.map.kakao.com/1709068029#comment
# 분류: 렌터카
# https://place.map.kakao.com/746860953#comment
# 분류: 단체,협회
# https://place.map.kakao.com/14825965#comment
# 분류: 렌터카
# https://place.map.kakao.com/1762689033#comment
# 분류: 렌터카
# https://place.map.kakao.com/10620530#comment
# 분류: 렌터카
# https://place.map.kakao.com/26887342#comment
# 분류: 렌터카
# https://place.map.kakao.com/25769803#comment
# 분류: 렌터카
# https://place.map.kakao.com/26521408#comment
# 분류: 렌터카
# https://place.map.kakao.com/777468585#comment
# 분류: 렌터카
# https://place.map.kakao.com/1257647888#comment
# 분류: 렌터카
# https://place.map.kakao.com/657323754#comment
# 분류: 렌터카
# https://place.map.kakao.com/2014474020#comment
# 분류: 렌터카
# https://place.map.kakao.com/15328807#comment
# 분류: 렌터카
# https://place.map.kakao.com/14752017#comment
# 분류: 렌터카
# https://place.map.kakao.com/8433016#comment
# 분류: 렌터카
# https://place.map.kakao.com/1008363228#comment
# 분류: 렌터카
# https://place.map.kakao.com/14951073#comment
# 분류: 렌터카
# https://place.map.kakao.com/97285313#comment
# 분류: 렌터카
# https://place.map.kakao.com/13128056#comment
# 분류: 렌터카
# https://place.map.kakao.com/1278792865#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/1590587423#comment
# 분류: 렌터카
# https://place.map.kakao.com/1573434157#comment
# 분류: 렌터카
# https://place.map.kakao.com/26410926#comment
# 분류: 렌터카
# https://place.map.kakao.com/1246504106#comment
# 분류: 렌터카
# https://place.map.kakao.com/452179586#comment
# 분류: 렌터카
# https://place.map.kakao.com/12396156#comment
# 분류: 렌터카
# https://place.map.kakao.com/26794322#comment
# 분류: 렌터카
# https://place.map.kakao.com/20435418#comment
# 분류: 렌터카
# https://place.map.kakao.com/132616791#comment
# 분류: 렌터카
# https://place.map.kakao.com/1040551334#comment
# 분류: 렌터카
# https://place.map.kakao.com/1775530391#comment
# 분류: 렌터카
# https://place.map.kakao.com/1279272310#comment
# 분류: 렌터카
# https://place.map.kakao.com/23233462#comment
# 분류: 렌터카
# https://place.map.kakao.com/801793631#comment
# 분류: 렌터카
# https://place.map.kakao.com/23306577#comment
# 분류: 렌터카
# https://place.map.kakao.com/17143332#comment
# 분류: 렌터카
# https://place.map.kakao.com/19360327#comment
# 분류: 렌터카
# https://place.map.kakao.com/25611578#comment
# 분류: 렌터카
# https://place.map.kakao.com/227103139#comment
# 분류: 렌터카
# https://place.map.kakao.com/490730093#comment
# 분류: 렌터카
# https://place.map.kakao.com/17385746#comment
# 분류: 렌터카
# https://place.map.kakao.com/11084802#comment
# 분류: 렌터카
# https://place.map.kakao.com/251018047#comment
# 분류: 렌터카
# https://place.map.kakao.com/1243270632#comment
# 분류: 렌터카
# https://place.map.kakao.com/1198801448#comment
# 분류: 렌터카
# https://place.map.kakao.com/14935399#comment
# 분류: 렌터카
# https://place.map.kakao.com/347472732#comment
# 분류: 렌터카
# https://place.map.kakao.com/1095110680#comment
# 분류: 렌터카
# https://place.map.kakao.com/21211496#comment
# 분류: 렌터카
# https://place.map.kakao.com/10594478#comment
# 분류: 렌터카
# https://place.map.kakao.com/17868198#comment
# 분류: 렌터카
# https://place.map.kakao.com/41971535#comment
# 분류: 렌터카
# https://place.map.kakao.com/27600795#comment
# 분류: 렌터카
# https://place.map.kakao.com/250792642#comment
# 분류: 렌터카
# https://place.map.kakao.com/175179946#comment
# 분류: 렌터카
# https://place.map.kakao.com/230685883#comment
# 분류: 렌터카
# https://place.map.kakao.com/10609822#comment
# 분류: 렌터카
# https://place.map.kakao.com/1935905180#comment
# 분류: 렌터카
# https://place.map.kakao.com/25118589#comment
# 분류: 렌터카
# https://place.map.kakao.com/386041191#comment
# 분류: 렌터카
# https://place.map.kakao.com/18211713#comment
# 분류: 렌터카
# https://place.map.kakao.com/27054790#comment
# 분류: 렌터카
# https://place.map.kakao.com/1301477495#comment
# 분류: 렌터카
# https://place.map.kakao.com/1409474938#comment
# 분류: 렌터카
# https://place.map.kakao.com/27319953#comment
# 분류: 렌터카
# https://place.map.kakao.com/26938542#comment
# 분류: 렌터카
# https://place.map.kakao.com/24963077#comment
# 분류: 렌터카
# https://place.map.kakao.com/317770652#comment
# 분류: 렌터카
# https://place.map.kakao.com/1504713683#comment
# 분류: 렌터카
# https://place.map.kakao.com/1526991673#comment
# 분류: 렌터카
# https://place.map.kakao.com/1844324780#comment
# 분류: 렌터카
# https://place.map.kakao.com/2019292758#comment
# 분류: 렌터카
# https://place.map.kakao.com/1423920787#comment
# 분류: 렌터카
# https://place.map.kakao.com/20580988#comment
# 분류: 주차장
# https://place.map.kakao.com/1969706027#comment
# 분류: 렌터카
# https://place.map.kakao.com/13011546#comment
# 분류: 렌터카
# https://place.map.kakao.com/849248412#comment
# 분류: 전문대행
# https://place.map.kakao.com/18488643#comment
# 분류: 렌터카
# https://place.map.kakao.com/2001392507#comment
# 분류: 렌터카
# https://place.map.kakao.com/21733597#comment
# 분류: 렌터카
# https://place.map.kakao.com/1294579489#comment
# 분류: 렌터카
# https://place.map.kakao.com/1489147341#comment
# 분류: 렌터카
# https://place.map.kakao.com/62974884#comment
# 분류: 렌터카
# https://place.map.kakao.com/26932836#comment
# 분류: 렌터카
# https://place.map.kakao.com/55866338#comment
# 분류: 여행사
# https://place.map.kakao.com/1327322844#comment
# 분류: 렌터카
# https://place.map.kakao.com/429897533#comment
# 분류: 렌터카
# https://place.map.kakao.com/7940644#comment
# 분류: 렌터카
# https://place.map.kakao.com/531388305#comment
# 분류: 렌터카
# https://place.map.kakao.com/14859018#comment
# 분류: 렌터카
# https://place.map.kakao.com/1255542005#comment
# 분류: 렌터카
# https://place.map.kakao.com/25996630#comment
# 분류: 렌터카
# https://place.map.kakao.com/2055149896#comment
# 분류: 렌터카
# https://place.map.kakao.com/1398782408#comment
# 분류: 교통,수송
# https://place.map.kakao.com/328479733#comment
# 분류: 렌터카
# https://place.map.kakao.com/1448008031#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/9085651#comment
# 분류: 렌터카
# https://place.map.kakao.com/1540062178#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/1056817069#comment
# 분류: 렌터카
# https://place.map.kakao.com/12319035#comment
# 분류: 렌터카
# https://place.map.kakao.com/479427491#comment
# 분류: 렌터카
# https://place.map.kakao.com/11282390#comment
# 분류: 렌터카
# https://place.map.kakao.com/246672209#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/8041449#comment
# 분류: 렌터카
# https://place.map.kakao.com/323410970#comment
# 분류: 교통,수송
# https://place.map.kakao.com/1755386334#comment
# 분류: 렌터카
# https://place.map.kakao.com/1811016114#comment
# 분류: 렌터카
# https://place.map.kakao.com/292605954#comment
# 분류: 교통,수송
# https://place.map.kakao.com/15956601#comment
# 분류: 숙박
# https://place.map.kakao.com/268801150#comment
# 분류: 렌터카
# https://place.map.kakao.com/27579449#comment
# 분류: 렌터카
# https://place.map.kakao.com/24759364#comment
# 분류: 렌터카
# https://place.map.kakao.com/2041764006#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/1438170576#comment
# 분류: 렌터카
# https://place.map.kakao.com/374945386#comment
# 분류: 렌터카
# https://place.map.kakao.com/241934269#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/801966900#comment
# 분류: 렌터카
# https://place.map.kakao.com/1271427954#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/736450682#comment
# 분류: 렌터카
# https://place.map.kakao.com/954809763#comment
# 분류: 렌터카
# https://place.map.kakao.com/14093548#comment
# 분류: 렌터카
# https://place.map.kakao.com/993769549#comment
# 분류: 렌터카
# https://place.map.kakao.com/2136501797#comment
# 분류: 렌터카
# https://place.map.kakao.com/1212373742#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/1107918238#comment
# 분류: 운송
# https://place.map.kakao.com/690708751#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/1492123479#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/59064937#comment
# 분류: 인터넷,IT
# https://place.map.kakao.com/1200750242#comment
# 분류: 렌터카
# https://place.map.kakao.com/183265029#comment
# 분류: 렌터카
# https://place.map.kakao.com/656491018#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/1355326806#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/12156591#comment
# 분류: 렌터카
# https://place.map.kakao.com/9314025#comment
# 분류: 렌터카
# https://place.map.kakao.com/70983628#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/1058462594#comment
# 분류: 렌터카
# https://place.map.kakao.com/210507257#comment
# 분류: 렌터카
# https://place.map.kakao.com/16745877#comment
# 분류: 렌터카
# https://place.map.kakao.com/1468895767#comment
# 분류: 렌터카
# https://place.map.kakao.com/1831531117#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/1355550623#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/1998280041#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/24764839#comment
# 분류: 롯데렌터카
# https://place.map.kakao.com/17940761#comment
# 분류: SK렌터카
# https://place.map.kakao.com/10804673#comment
# 분류: 렌터카
# https://place.map.kakao.com/17673118#comment
# 분류: 렌터카
# https://place.map.kakao.com/27527607#comment
# 분류: 렌터카
# https://place.map.kakao.com/400227802#comment
# 분류: 롯데렌터카
# https://place.map.kakao.com/1202775036#comment
# 분류: 렌터카
# https://place.map.kakao.com/1082768527#comment
# 분류: 렌터카
# https://place.map.kakao.com/540321788#comment
# 분류: 렌터카
# https://place.map.kakao.com/18801206#comment
# 분류: 롯데렌터카
# https://place.map.kakao.com/1580657752#comment
# 분류: 렌터카
# https://place.map.kakao.com/1098506214#comment
# 분류: 렌터카
# https://place.map.kakao.com/635534881#comment
# 분류: 렌터카
# https://place.map.kakao.com/1548026500#comment
# 분류: 렌터카
# https://place.map.kakao.com/26418409#comment
# 분류: 렌터카
# https://place.map.kakao.com/564676511#comment
# 분류: 렌터카
# https://place.map.kakao.com/982377677#comment
# 분류: 렌터카
# https://place.map.kakao.com/1690567036#comment
# 분류: 렌터카
# https://place.map.kakao.com/10944941#comment
# 분류: 렌터카
# https://place.map.kakao.com/17266597#comment
# 분류: 렌터카
# https://place.map.kakao.com/437807628#comment
# 분류: 렌터카
# https://place.map.kakao.com/687752220#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/571322596#comment
# 분류: 문화시설
# https://place.map.kakao.com/42317428#comment
# 분류: 렌터카
# https://place.map.kakao.com/2072893496#comment
# 분류: 렌터카
# https://place.map.kakao.com/20033987#comment
# 분류: 렌터카
# https://place.map.kakao.com/399961245#comment
# 분류: 렌터카
# https://place.map.kakao.com/473769104#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/1981347324#comment
# 분류: 전기자동차 충전소
# https://place.map.kakao.com/1925542408#comment
# 분류: 렌터카
# https://place.map.kakao.com/1619669498#comment
# 분류: 렌터카
# https://place.map.kakao.com/1985385539#comment
# 분류: 렌터카
# https://place.map.kakao.com/1658414980#comment
# 분류: 렌터카
# https://place.map.kakao.com/1154520709#comment
# 분류: 렌터카
# https://place.map.kakao.com/208784086#comment
# 분류: 렌터카
# https://place.map.kakao.com/10874477#comment
# 분류: 렌터카
# https://place.map.kakao.com/1903470188#comment
# 분류: 렌터카
# https://place.map.kakao.com/27445705#comment
# 분류: 렌터카
# https://place.map.kakao.com/561308584#comment
# 분류: 렌터카
# https://place.map.kakao.com/1202518555#comment
# 분류: 렌터카
# https://place.map.kakao.com/990921948#comment
# 분류: 렌터카
# https://place.map.kakao.com/452411056#comment
# 분류: 렌터카
# https://place.map.kakao.com/691654269#comment
# 분류: CU
# https://place.map.kakao.com/483777957#comment
# 분류: 파리바게뜨
# https://place.map.kakao.com/1568005762#comment
# 분류: ATM
# https://place.map.kakao.com/762756110#comment
# 분류: 컴포즈커피
# https://place.map.kakao.com/399855285#comment
# 분류: 렌터카
# https://place.map.kakao.com/27559439#comment
# 분류: 렌터카
# https://place.map.kakao.com/369567086#comment
# 분류: 여행사
# https://place.map.kakao.com/1902777910#comment
# 분류: 여행사
# https://place.map.kakao.com/1471951086#comment
# 분류: 대출
# [['자연인 주나',
#   '쿱카를 통해 제주로렌트카 차량을 배정받았는데 차 정비를 안하시는 듯(2021.12.22~12.24 렌트)',
#   '카카오맵',
#   1,
#   '21.12.31.',
#   '제주도렌트카협동조합'],
#  ['.', '', '카카오맵', 1, '21.10.01.', '제주도렌트카협동조합'],
#  ['두아이맘',
#   '렌터카카 2000키로도 안된 새차.  주행감도 좋아 기분좋은 여행 했습니다. 다만 너무 새차라 흠집날까봐 긴장이 되었습니다 ㅎㅎ 다음에 또 이용하겠습니다 감사합니다!',
#   '카카오맵',
#   5,
#   '20.08.15.',
#   '제주도렌트카협동조합'],
#  ['JS쿠마',
#   '정말 제주도렌트카협동조합 덕분에 아주 기분좋은여행이었습니다~^^직원분들도 친절하시고<br/>무인시스템으로 신속하게 출고~반납!!<br/>차도 깨끗하고 좋았습니다~다음에도 좋은 차로 잘 부탁드려요~^^',
#   '카카오맵',
#   5,
#   '20.08.14.',
#   '제주도렌트카협동조합'],
#  ['석',
#   '정말 편리하고 싸게 잘 이용했습니다. 미리 등록해 놓으니 무인인수라 인수도 굉장히 빠르고 년식 짧은 걸로 선택했더니 싼데도 차량 정말 깨끗하네요... 다음 제주여행때도 잘 부탁드리고, 사업 번창하시길 바랍니다. 감사합니다. ^- ^',
#   '카카오맵',
#   5,
#   '20.05.28.',
#   '제주도렌트카협동조합'],
#  ['김해영',
#   '여러가지로 좋은 렌트카입니다.<br/>두번 사용했지만 가격대비 가성비<br/>좋아요. 또한 차량 청소상태도 양호<br/>해요. 제주를 자주 가는데 계속 이용<br/>할 것입니다. 감사합니다',
#   '카카오맵',
#   5,
#   '22.12.16.',
#   '무지개렌트카'],
#  ['쿔쿔',
#   '3번 이용해봤는데 모두 무난하게 괜찮았습니다<br/>차량 내부 깨끗하고 외부는 잔기스가 많았지만 어디서 빌리나 다 그렇기에 신경쓸 정돈아니었고<br/>불친절하다고 느낀 포인트는 없었어용~<br/>다음달에 또 이용할 예정이에요',
#   '카카오맵',
#   5,
#   '22.11.13.',
#   '무지개렌트카'],
#  ['모난돌', '싸고 좋습니다. 다만 청소상태가 살짝 부실.', '카카오맵', 4, '22.11.11.', '무지개렌트카'],
#  ['빠께💓',
#   '반납하는데 별것도 아닌 거로 나이 많은 아저씨가 빽빽 소리 지르고 쓰레기를 버리는 것도 오염을 시킨 것도 아닌데 우리 잘못처럼 큰 소리만 내면 이기는 줄 알고 바로 앞에 쓰레기통이 있는데도 난리 치는 곳. 기분 좋게 여행하고 마지막까지 좋은 기억으로 있다가 가려는데 막판에 기분 다 잡치고 갑니다. 어머니한테 온갖 난리 치는 거 보고 빡쳐서 다시는 여기서 렌트 안 하려고요. 찾아보니까 후기도 안 좋던데 싼 게 비지떡이라는 말이 과언이 아닙니다.',
#   '카카오맵',
#   1,
#   '22.10.30.',
#   '무지개렌트카'],
#  ['...',
#   '믿고 걸러야되는 무지개렌트카,통일렌트카!!!!!!<br/>차량인수받을때는 아무도없이 그냥 가져가도된다고하더니만 반납할때는 여러명이 와서 이게 왜이러냐 저거왜이러냐 이렇게 타시면 안된다며 말투 틱틱거리면서 시비조임.그런것있으면 인수해줄때 미리 얘기해줘야는거아닌가? 누가 차량옵션이나 정보를 차종류마다 알고있습니까? <br/>역시 후기는 무시못합니다. 여행마무리가 렌트카반납때문에 좋진않았네요',
#   '카카오맵',
#   1,
#   '22.10.30.',
#   '무지개렌트카'],
#  ['찐후기만쓴다',
#   '진짜 제주도가 욕먹는 이유가 있다~~~ 다신 보지말자~~~~~~~',
#   '카카오맵',
#   1,
#   '22.10.14.',
#   '무지개렌트카'],
#  ['부산슬', '진짜 무지 개같네요^^', '카카오맵', 1, '22.09.19.', '무지개렌트카'],
#  ['앤드', '여행을 망치고 싶은 분들만 여기서 차 빌리세요', '카카오맵', 1, '22.09.03.', '무지개렌트카'],
#  ['김 후기',
#   '특산품 두고 내렸는데 <br/>다시 찾으러 가니까 자기들이 몇개 먹고 주네요..ㅋㅋ',
#   '카카오맵',
#   1,
#   '22.08.31.',
#   '무지개렌트카'],
#  ['오케',
#   '성수기에 다른데보다 훨씬 저렴하게 빌렸어요<br/>추가로 결제한 주유비는뭐,,쏘카나 그린카 키로수이용금? 처럼 생각하면 괜춘한것같아욤<br/>모닝이 조금 힘이딸려서 오르막이 힘들었어요',
#   '카카오맵',
#   5,
#   '22.08.25.',
#   '무지개렌트카'],
#  ['맛돌이',
#   '저렴하지만<br/>차 상태는 타 렌트카에 비해 별로였음(빌릴때 전기 미완충, 청소 불량)',
#   '카카오맵',
#   2,
#   '22.08.07.',
#   '무지개렌트카'],
#  ['미스터챠',
#   '차상태도 미리확인안하고 인도해서 30분가량 기다렸다 출차하고, 업데이트 안된 내비로 인해 고생만 엄청함. 제주여행중 렌터카가 오점을 남김.<br/>30구간인데 50으로 안내. 카메라 누락 다수. 걍 카카오 내비로 다님. 다시는 이용하고 싶지 않음',
#   '카카오맵',
#   1,
#   '22.08.01.',
#   '무지개렌트카'],
#  ['아슬란',
#   '출장때 회사직원을 통해 무지개 렌트카를 알게되어  4번정도 이용 후 이번 휴가에 차를 빌렸는데  만족합니다. 휴가때라 가격은 비싸지만 다른곳보다는 가격도 낮고, 직원분들도 불친절하지 않았습니다. 차량컨디션도 좋았습니다. 매번 차 반납할때도 별 문제 없이 잘 반납했습니다. 다음번에도 또 이용 예정입니다.',
#   '카카오맵',
#   5,
#   '22.07.29.',
#   '무지개렌트카'],
#  ['myks', '20220726 반납<br/>20220725 렌트카', '카카오맵', 3, '22.07.26.', '무지개렌트카'],
#  ['underj',
#   '제주속으로에서 예약했고<br/>차는 너무오래됐고<br/>특히 네비게이션이 여름밖에 세워둬서 뜨거워지면 터치안되고 너무 꾸져서 보지도 못하겠음 업데이트도 안되서 검색도 안되고 없는길이 나옴<br/>셔틀기사님 너무 까칠하고 불친절하고<br/>가방실고 내리는것 도와줄 생각없슴<br/>싼게 비지떡이 맞는거 같습니다<br/>주유는 만땅해놔야 마지막에 넣어서 맞추지 애매한 칸에 들어있으니 들어가서 정산해주는수밖엔<br/>키오스크 시작하기전에 추가요금 설명보고 시작하세요.',
#   '카카오맵',
#   1,
#   '22.07.25.',
#   '무지개렌트카'],
#  ['Katrin',
#   'Despite the negative reviews we had good experience with this company. They have an English speaking manager that helped us a lot. Didn’t have any problem, the only thing is the windows of the car were not too clean, but it was not a deal breaker for us',
#   '카카오맵',
#   5,
#   '22.07.25.',
#   '무지개렌트카'],
#  ['르루',
#   '차량이 노후되어있고 좀 더러워요 <br/>천장에 등이 안켜져서 밤에 사용이 어려웠어요 아기 카시트도 잔고장이 있어서 벨트랑 회전이 됬다 안됬다 그러네요',
#   '카카오맵',
#   2,
#   '22.07.17.',
#   '무지개렌트카'],
#  ['Bona Kim',
#   '카모아통해 이용하니 좋았어요<br/>ㅡ무지개에서안된다고 하는부분이<br/>오히려 카모아에선 해결이되는 느낌요~',
#   '카카오맵',
#   5,
#   '22.07.08.',
#   '무지개렌트카'],
#  ['Park', '', '카카오맵', 5, '22.06.28.', '무지개렌트카'],
#  ['Fly high~♡',
#   '후기보고 정말 고민많이 하다 이용했습니다.<br/>일단 가격 비교하시면 알겠지만 제일 싸구요.<br/>출차는 키오스크로 3분도 안걸림.<br/>반납도 3분걸렸나...? <br/>이용객마다 다들 차이 있겠지만 만족도가<br/>좋았습니다.<br/>2021년 소나타 가솔린.<br/>차량 상태도 좋았습니다.',
#   '카카오맵',
#   5,
#   '22.06.18.',
#   '무지개렌트카'],
#  ['Lee',
#   '8시 이전에 반납이 가능해서 좋았습니다<br/>7시 반납이었는데 6시 40분경에 반납 가능했고<br/>공항과도 가깝습니다',
#   '카카오맵',
#   5,
#   '22.06.12.',
#   '무지개렌트카'],
#  ['내돈내산 찐평',
#   '별점이 낮은건 다 이유가 있다. 유류비로 사람 가지고 장난침ㅋㅋㅋㅋ 빌릴때랑 반납할때랑 말이 달라짐ㅋㅋㅋ 어이가 없다. 다들 조심하세요. 여기는 진짜 답이 없습니다. 도망치세요.',
#   '카카오맵',
#   1,
#   '22.06.11.',
#   '무지개렌트카'],
#  ['감별사',
#   '직원 불친절 한건 둘째 치고 설명도 제대로 안해주고 처음 설명때는 키로수 맞추라고 해놓고 막상 반납할때는 게이지 타령하면서 키로수 많이 나와도 게이지 가 두칸이상 오바 안되면 환불 안해준다고 하고 제가 타자마자 찍은 상태는 두칸인데 자기들 데이터는 3칸이라고 하고 양아치 업체입니다 절때 여행오시는분들 여기하시면 안됩니다',
#   '카카오맵',
#   1,
#   '22.06.08.',
#   '무지개렌트카'],
#  ['박지현',
#   '정말 불친절하고..유류비 불합리해요... 부모님과 제주도 여행에 이런 데에서 렌트를 해서 기분 잡쳤다니까요 정말 최악이애요',
#   '카카오맵',
#   1,
#   '22.05.24.',
#   '무지개렌트카'],
#  ['MO', '', '카카오맵', 1, '22.05.08.', '무지개렌트카'],
#  ['김성진',
#   '손님 모시기위해 렌트한 도민인데요..<br/>출차할땐 어차피 키오스크로 하는데요..<br/>반납할때 젊은(?)남자직원 대략 30대내외<br/>상당히 퉁명스럽네요ㅠㅠ<br/>가다가 보니까 또 다른 손님하고 또 연료문제로 언쟁하고 있고 왜그렇게 삶을 힘들게 사는건지ㅉㅉ',
#   '카카오맵',
#   1,
#   '22.05.04.',
#   '무지개렌트카'],
#  ['Mr.Jeong',
#   '내 귀찮아서 후기 잘 안남기는데 여긴 꼭 남겨야 겠다 맘 먹은게, 참... 차량 깨끗하지도 않고, 핸들도 엄청 뻑뻑해서 돌리다가 팔 어깨 나갈뻔... 전기 충전카드는 걍 강매수준임... 다른데 렌트카 업체로 빌리세요~여긴 후퇴하세요 근처에도 오지마셈...',
#   '카카오맵',
#   1,
#   '22.04.05.',
#   '무지개렌트카'],
#  ['JK',
#   '진짜 제발 이용하지 마세요<br/>불친절 끝판왕, 차 상태 엉망이어서 두 번이나 찾아갔는데 바뀐거 하나 없었음. 제발 여기 망하게 해주세요.',
#   '카카오맵',
#   1,
#   '22.03.01.',
#   '무지개렌트카'],
#  ['명수',
#   '내 인생 최악의 렌트카. 절대 다신 이용 X<br/><br/>- 창문 개더럽. 날이 좋으면 뭐하냐 보이질 않음<br/>- 블루투스 바라지도 않음. USB 음악은 물론<br/>충전도 안됨 (전화했더니 시가잭을 쓰라고..지금 1990년도?)<br/>-네비게이션 스피커 불량으로 시동걸때마다 굉음 및 떨림 엄청남<br/>-연료 표출기 황당할정도로 갑자기 훅 떨어져서 주유소 찾느라 난감<br/><br/>리뷰보니 황천길 갈뻔 한 분들 투성이네요. <br/>미리 좀 보고 구할껄. 정말 이따위로 경영하다 큰 사고 나야 정신차릴런지..개선 의지도 전혀없음. <br/><br/>제주에 일이있어 2-30번정도 렌트 경험있는데<br/>무지개 너무 뎌서 이용하던 렌트가 연결 포털사이트도 갈아탔음',
#   '카카오맵',
#   1,
#   '22.02.28.',
#   '무지개렌트카'],
#  ['올드대디',
#   '이번이 4번째.... 공항하고 가깝고 신속한 반납이 맘에들어요~~^^',
#   '카카오맵',
#   5,
#   '22.02.19.',
#   '무지개렌트카'],
#  ['인도코끼리',
#   '3세대K5 차량 재이용 했는데....출고 반납 빨라서 좋았구요~~~친절하게 안내 해주셔서 잘 이용했습니다~^^',
#   '카카오맵',
#   5,
#   '22.02.19.',
#   '무지개렌트카'],
#  ['서연',
#   '3박4일 이용했습니다.<br/>셔틀버스 이용했고 공항이랑 위치도 가깝고 좋았습니다.<br/>차량도 깨끗했고 모르는게 있어서 물어봤는데<br/>직원분이 친절하고 빠르게 대처해주셨습니다.<br/>저렴한 가격에 이용했는데.. 가성비 정말 좋아서 재이용 의사 있습니다.<br/>리뷰보니,,저렴한 가격에 완벽한 차량을 원하시는건 좀 아닌듯요~~<br/>가성비 최고입니다 ^^',
#   '카카오맵',
#   5,
#   '22.02.19.',
#   '무지개렌트카'],
#  ['맹방',
#   '주유를 기존제공량 보다 많이 해가서 환급을 받아야하는데 75프로로 줬는데 80프로로 반납했다고 환급을 못해주겠다고하더라구요; 분명 80프로가 아니고 만땅과 75프로의 중간이니까 80프로보다 현저히 많이 주유해서 반납했는데...? 막상 반대로 지금 추가 주유해둔것만큼 부족하게 주유했을때 주유비를 추가지불안해도 된다고 했을지 의문이네요. 셔틀기사분들,포스기 직원분 모두 친절하셨는데 제차 반납처리 담당한 모자쓴 30대초반 직원분이었습니다. 주유비환급요청을 하니 어이없는 웃음지으며 끝까지 환불 거부하시다가 마지막에 오천원 드린다고하셨는데 사천원이 입금되었습니다. 천원가지고 손님놀리는게 어이없네요ㅋㅋㅋ뿐만아니라 2018-2019년식으로 저는 예약했는데 최소2017년이나 그이전모델을 주셨어요 제가 동일기종 몰아서 알구요~~스마트키도아니라 매번 시동갈때마다 불편했습니다. 계약조건과 다른 차를 배정받았을때도 별만안했는데 천원 덜 입금한게 좀 신박하고 재미있어서 리뷰남깁니다.',
#   '카카오맵',
#   1,
#   '22.02.13.',
#   '무지개렌트카'],
#  ['똘이누나', '편하고 좋아요!', '카카오맵', 5, '22.02.12.', '무지개렌트카'],
#  ['맛잘알',
#   '차가 오래되고 관리 안된게 바아로 느껴짐 다른 곳을 이용하는걸 추천해요',
#   '카카오맵',
#   1,
#   '22.02.11.',
#   '무지개렌트카'],
#  ['요롱',
#   '가격 저렴하고 가격 대비 적당한 서비스와 거리 총체적으로 무난했습니다.',
#   '카카오맵',
#   4,
#   '22.02.04.',
#   '무지개렌트카'],
#  ['쓰라라', '최악', '카카오맵', 1, '22.01.20.', '무지개렌트카'],
#  ['솔직리뷰',
#   '저도최악임.<br/>일단 여자애 AI처럼 말하고 스아가지없고<br/>무슨 키오스크에서 운전면허증 인증하고<br/>또 그 여자애한테가서 신분증보여주고<br/>뭐쓰고뭐쓰고<br/>심지어 차키가 어딨는지 안내도없고<br/>거기왔던 다른손님들도 열명중 아홉은 기분잡치는게보임.<br/>여행 기분더럽게 시작하고싶으면 강추.<br/>차는 말할것도없이 최악.<br/>앞버퍼 움직일때마다 두르륵두르륵 ㅋㅋㅋ<br/>그렇게 큰소리 살다 첨 들음<br/>사장 진짜 누구냐 인간성 보인다 ㅉㅉ<br/>업체명에 "개"가 들어간 이유가 있음',
#   '카카오맵',
#   1,
#   '22.01.13.',
#   '무지개렌트카'],
#  ['가가호호',
#   '자동차는 만족했으나 공항에서 셔틀타고 왕복해야해요 배차간격도 거의 20분 수준이라 비행기출발 1시간 30분 전에 반납하러 갔어요  빌리는데도 무인기로 빌려야해서 줄서다가 시간 다 갑니다 무엇보다 네비가 과속단속을 알려주지 않길래 전화문의했더니 제주가 과속단속을 자주 변경해서 네비가 알려주지 않는다는 이상한 소리를 들었네요 그냥 핸드폰 네비 썼습니다',
#   '카카오맵',
#   3,
#   '22.01.07.',
#   '무지개렌트카'],
#  ['선데이',
#   '2019년식이라고 하는데 2019년에도 열쇠가 있네요<br/>분명 스마트키라고 봤는데... <br/>열쇠로 열고 열쇠로 시동거는거 생각보다 엄청 귀찮네요<br/>엑셀 밟을때마다 rpm이 엄청 올라가는 잘 나가지도 않는 차에 검수가 필요없을만큼 여기저기 다 까여있는 외관<br/>트렁크도 안열어주면 안열리는 스마트함까지...<br/>2019년식 맞는지 심히 궁금합니다<br/>어짜피 뜨내기 손님이라 신경도 안쓰겠지만<br/>다신 안갑니다',
#   '카카오맵',
#   1,
#   '21.12.24.',
#   '무지개렌트카'],
#  ['짹',
#   '안좋은 후기 있어서 걱정했는데 불편한것도 없고 처리도 빠르고 딱히 불친절하지도 않고 차도 깔끔했어요. 차량빌려서 나갈때 기계세차 한번씩 하고 나가는거 정말 좋았어요! 비수기때라 그런지 저렴했습니다 <br/>차량인수하실때 흠집난거 사진 다 찍어놓으세요',
#   '카카오맵',
#   5,
#   '21.12.17.',
#   '무지개렌트카'],
#  ['뚜벅이', '교통편리하고 처리속도 빠름.', '카카오맵', 4, '21.11.28.', '무지개렌트카'],
#  ['장재헌', '', '카카오맵', 1, '21.11.11.', '무지개렌트카'],
#  ['靜中動',
#   '차 기름 처음있는 양으로 정확히 맞추고 반납하세요.<br/>기름값에서 좀 떼어먹는게 있네요<br/>자기들 유리한쪽으로 계산해서 5천원 정도 떼어먹네요<br/>그리고 12000원 기름값 환불해준다더니 10000원 넣어주더라구요. 전화했더니 사과 한마디 없고 그냥 2000원 다시 넣더라구요. 마치 많이 해 본 것처럼...<br/>행실을 보니 조금씩 일부러 덜 입금해주는 방식으로 해서 그냥 소액이라서 넘어가는 사람껀 떼어 먹는거 아닌가하는 의심이 들었어요.',
#   '카카오맵',
#   1,
#   '21.10.10.',
#   '무지개렌트카'],
#  ['종로미식가',
#   '두번째 이용입니다!다 좋은데 올뉴k5（후방)는 피하시길..차량 옵션이라고 하면 정말 에어컨 밖에 없어요ㅠㅠ그래도 친절하시고 불편함없이 이용하고 있어요^^',
#   '카카오맵',
#   4,
#   '21.10.09.',
#   '무지개렌트카'],
#  ['최관태',
#   '갑작스레 제주를 가게되어 2박3일 급하게 무지개렌터카 예약후  한숨돌리고, 안좋은 후기를 보고 깜놀.. 취소하려 하니 취소수수료가 너무 나와서<br/>맘비우고 이용하기로...<br/><br/>헌데 전 100%  만족이었어요<br/>셔틀 기사님 친절하고 차량 인도시 강압적인 추가 보험가입 없었고,<br/>제주 운전이 녹녹치 않다는 말에  걱정되어<br/>제가 소유한 차량과 동일한 차량을 신청했고,<br/>차량상태도 여러사람이 쓰는  렌터카치고  좋았습니다<br/><br/>사람들의 기대치가 서로달라서 어느정도에 기준을 맞추는지는 모르겠지만<br/>불편함없이 잘 이용했습니다.<br/>반납시 주유량이 살짝 부족해 말씀하시면 현금을 드리려 했는데, 사고 여부만 물으시고 반납해가셔서<br/>오히려 후기보고 걱정한 제가 당황했다는..<br/><br/>덕분에 안전하고 즐거운 여행을 할수 있었습니다 <br/>감사드립니다 <br/><br/>그리고 여행하시는 분들 안전운전하세요<br/>어느 렌터카가 첫째날 보니, 로터리  회전 후 화단위로 차량이 올라타서 운전자가 밖에 나와 통화하고 있더군요...',
#   '카카오맵',
#   5,
#   '21.10.03.',
#   '무지개렌트카'],
#  ['이희영',
#   '이용하시는 분마다 호불호가 있는듯 합니다.<br/>저는 초음 이용하는데 나름 괜찮았습니다.<br/>인수 인계할때 다 좋았어요. 크게 깐깐하게 하시지도 않구요. 차에 쓰레기가 좀 있었는데 본인들이 치울테니 놔두고 가시라고 해서 감사했습니다.^^',
#   '카카오맵',
#   5,
#   '21.09.27.',
#   '무지개렌트카'],
#  ['지나가던행인', '아무기대없이가니까그럭저럭 만족', '카카오맵', 5, '21.09.21.', '무지개렌트카'],
#  ['만두',
#   '어플을 통해 예약 시 전달받지 못한<br/>일일 유료 전기충전 카드 요금을 현장지불해야 함<br/>차량 검수를 제대로 하지 않아 렌트 시에 교체하고 기다림<br/>데스크의 젊은 직원 분, 차량 반납장소에 있는 직원, 차량 라문의를 받은 아저씨 <br/>모두 굉장히 아주 아주 굉장히 서비스 마인드가 없음',
#   '카카오맵',
#   1,
#   '21.09.21.',
#   '무지개렌트카'],
#  ['KIMs',
#   '차가 정말 안 나갔음. 이무리 렌트카라지만 70 km 넘어가니 엔진 회전이 4천회가 갑자기 훅 넘어간다던지..(레이가 원래 잘 안나간다면 할말은 없지만서도)...그럼에도 불구하고 리뷰에 비해 나쁘다는 인상은 없었음. 20일 20시간 정도 빌리는데 6만원이 안되는 돈으로 빌려 탔으니 가격대비성능은 최고가 아닌가 싶음. 차가 잘 안나간다는 점 말곤 솔직히 별로 문제 될게 없었음. 어차피 제주도는 고속도로도 없고 내가 갔을때는 비가 많이 와서 70 이상 밟을 일도 없었음. 빌리는거부터 반납까지 전부 다 괜찮았음. 다음에도 이용할 마음 있음',
#   '카카오맵',
#   4,
#   '21.09.14.',
#   '무지개렌트카'],
#  ['봄봄',
#   '제주도민입니다. 차가필요해 렌트예약했어요.최악의 업체를만났네요.아무리 8시간3만원대 대여를한거지만 청소상태 최악. 눈에다보이는 과자부스러기이물질 찌든때...여기까지도 참으려고했어요. 시동거는데 담배냄새가 코를찌르더군요. 외관 드러운건 이해함. 큰기대안하고 하루빌려타는데 이건 치욕을 느낄정도였습니다.따지고싶지도않을정도. 바로 반납하겠다고하니 돌아온답변은 청소를해주면안되겠냐.당황한모습으로 앵무새답변...아니요 됐습니다.불편을드려죄송합니다가 먼저아닌가요? 렌트카업체직접결제가아니라환불도안됨.알아서하라식.그냥됐다고하고 대여하고 5분만에반납했습니다. 하루망쳤습니다.여행객분들이 제주도를 어떻게생각할까 걱정될정도의 서비스와 품질입니다. 제 첫 네이버 리뷰입니다. 영수증인증까지해서 합니다.하나를보면열을압니다.믿고거르세요.',
#   '카카오맵',
#   1,
#   '21.08.28.',
#   '무지개렌트카'],
#  ['쏭스',
#   '돈좀더주고 브랜드렌트카이용하셈요<br/>차가 가다가 핸들고정풀리더니..높낮이조절않되서 다시 차교환하러감<br/>고속주행했음 누가책임지나..<br/>공항픽업도 버스한대로도는지 서서가고 버스는 낡아서 의자에 앉기도 힘들고<br/>서비스도 엉망<br/>목숨걸고타는기분<br/>휴가철 싼맛에 이용한다지만 형편없응',
#   '카카오맵',
#   1,
#   '21.08.18.',
#   '무지개렌트카'],
#  ['wonn',
#   '아무리 14년식(소나타)이라해도 크락션 작동과<br/>왼쪽 전조등이 들어왔다 나갔다 했네요 <br/>제발 점검좀 해서 내보내주세요<br/><br/>누구나 낮선장소 인지라 더욱더<br/>사전 차량점검 제일임돠<br/><br/>그래도 아무런 사고없이 나랑 36시간동안<br/>고생한 "소나타02허2650" 고생 마나슈~ㅎㅎ',
#   '카카오맵',
#   2,
#   '21.07.22.',
#   '무지개렌트카'],
#  ['Sam 리...',
#   '올해 1월에 이곳을 이용하고 만족해서 두번째로 두달전 예약했는데 그때 정말 비싸게 주고 예약한듯합니다. 두달전에는 이곳이 저렴했는데...현재는 코로나 상황(21년7월21일)때문에 두달전보다 더 더 저렴한듯..취소하고 다시하면, 같은 돈이면 카니발정도는 빌렸지 않을까.... 차량은..아반테MD 기본 모델...혹시나 해서 1만원짜리 패키지 추가... 사이드미러는 접히지도 않고..후방카메라는 있으나 쓸모없는 듯...뒷드렁크는 무조건 앞좌석에서.. 키는 무선도 아닌 앞자리 열쇠...연식이 오래되었고 언덕 오르면 정말 힘들어함.. 차량 상태는 메롱함.(20만km 다됨) 차를 타면서, 정말 욕하고 다님..더운데 에어컨 켜면 곰팡이 냄새나고.. 최악임..... 절대 연식 높은거나 키로수 높은차는 비추. 그리고 이런 차는 폐차하시던가, 귀사 직원이나 타시는것을 추천함. 그리고 네비게이션은 버리세요.. 시동을 켜도 화면 멈춤..off/on 반복해야..2~3차례를 해야함... 거의 전자제품 수명을 다한듯... 고철수준임... 좀 확인하고 고객에게 대여하기 바람...',
#   '카카오맵',
#   1,
#   '21.07.22.',
#   '무지개렌트카'],
#  ['ㅇㅅㅇ',
#   '제주쏙으로에서 배정받은 업체가 무지개렌트카였어요.  예약완료 후 뒤늦게 여기 후기보고 진짜 걱정 한보따리 안고 갔는데..  인수 받을때 사무실 직원분도 괜찮았구요, 반납처리때도 제가 늦게가면서 기름보충도 못하고 갔는데 ㅜ 직원분이 친절하게 빠르게 처리 잘 해주셔서 잘 이용했어요. 그래서 꼭 좋았다고 후기 남기고 싶었어요… &gt;.&lt;  차에 USB잭 없다고 후기도 많이 봤는데요. 그래서 개선되었는지(?) 제가 빌린차에는 3개 있었어요. 덕분에 좋은 여행할 수 있어서 만족합니다.',
#   '카카오맵',
#   5,
#   '21.07.21.',
#   '무지개렌트카'],
#  ['봉자',
#   "차 인수시에 현장에서 얼결에 현장출동특약 1만원 가입...왜했을까나? 자세히 보니 '1건'에 한해! 그나마 차상태,네비 양호해서 별2개. 초기주유량 애매함. 만땅에서 시작하면 좀 좋으련만!!!",
#   '카카오맵',
#   2,
#   '21.07.20.',
#   '무지개렌트카'],
#  ['GFEEK',
#   '제주 the렌트카에서 렌트한다고하면 예약완료하고 배정해준 업체인데 무지개렌트카포함 평점안좋은 곳은 빼달라고하세요. 네비가 업데이트 안되있어서 어.보.구 안나오고 50키로 제한인데 60키로 제한으로 뜨고 네비없이 폰으로 가야됨. 레이빌렸는데 무슨 사고난차처럼 휠도 다녹슬어있고 차안에서는 오래된 냉장고 냄새나고 속도 70키로 넘어가면 차터질듯이 소리남. 시트도 볼륨감 다빠져서 그냥 납작함.',
#   '카카오맵',
#   1,
#   '21.07.15.',
#   '무지개렌트카'],
#  ['사실만쓴다',
#   '차에 실수로 물건 두고 내리지 마세요절대<br/>하루지나서 연락 했는데 없다고 하네요^ ^<br/>고가의 지갑이던 시계이던 보상 못받네요',
#   '카카오맵',
#   1,
#   '21.07.12.',
#   '무지개렌트카'],
#  ['sowpdn',
#   '일단 세차는 아예 안함 개더러움 개찝찝함 시트는 천이라 닦는것도 한계 누가 뭐 먹고 흘린 잔해들이 가득가득<br/>그런데도 싸게 이용할거면 여기 이용하세요 저같으면 돈 더내고 다른곳에서 렌트할거에요 <br/>요즘 제주도 렌트카 값들이 다 너무 비쌈 그래서 싼 곳 찾아서 한건데 절대로 다시는 이용안함',
#   '카카오맵',
#   1,
#   '21.07.11.',
#   '무지개렌트카'],
#  ['a day',
#   '별하나주기도 안까운곳이네요! 사고 나신적없죠? 없죠?   없죠를 몇번을 물어보시는지! 회사 입장에서는 어쩔수 없지만 사진은 왜 찍고? 하는지? 기분 더럽게 하시는 제주가 있으시네요! 만약에 제주에 무지개 렌트카 <br/>밖에 없으면 전 그냥 택시 타고 다니렵니다!',
#   '카카오맵',
#   1,
#   '21.06.28.',
#   '무지개렌트카'],
#  ['서영민',
#   '가정교육 독학한 싸가지 ♪♬♪되는 직원들과 사방팔방 찍혀서 거지꼴인 차량들의 환장의 콜라보. <br/>차에 대한 설명 하나도 안 해주고 어머니가 원래 운전하시던 차종이랑 달라서 설명 좀 부탁한다고 하시는데 “원래 안 해드리는거라고요~”하고 자기들은 원래 그렇게 한다며 가랍니다. <br/>뒷자석 밖에서 안 열려서 교체하러 왔는데 된다고 박박 우기고 설명도 더 안 해주고 그대로 갖고 가라는거 싸워서 겨우 차량 변경했네요. <br/>차 반납할 때 주유를 해야하는지도 전혀 안내 안 해놓고 2만원 뜯어갑니다. <br/><br/>요약하자면 그냥 배워먹은게 하나도 없는 놈들이 하는 업체니까 제발 다른곳 가세요. 어르신들 모시고 왔다가 여행 시작 첫날부터 봉변 당했습니다.',
#   '카카오맵',
#   1,
#   '21.06.28.',
#   '무지개렌트카'],
#  ['윌리엄이모', '', '카카오맵', 3, '21.06.18.', '무지개렌트카'],
#  ['김미영', '리뷰그대로', '카카오맵', 2, '21.06.08.', '무지개렌트카'],
#  ['두부르바',
#   '최악<br/>기름 더 넣어서 반납했더니 2칸이상 넣어져야 차액 준다네요ㅎㅎ<br/>그럼 1칸이나 그 미만으로 출고시보다 기름이 적으면 돈 안내도 되나요? 물었더니<br/>그건 내야된다네..<br/>말이야 방귀야ㅎㅎ<br/>돈 몇천원 아까워서가 아니라 기분이 나쁘더라구요. 싸울거같아서 더 말안하고 나왔습니다ㅎㅎ<br/>제주도 자주 가는데 역시 원래 이용하던 렌트카업체 가야겠네요',
#   '카카오맵',
#   1,
#   '21.05.28.',
#   '무지개렌트카'],
#  ['ㅁㅁ',
#   '이거 보시는 분들 정말 운 좋으십니다<br/>저도 다음 렌트부터는 무조건 리뷰 찾아보고 해야겠네요 <br/>리뷰하신 분들 말 그대롭니다<br/>일단 불친절 끝판왕이고 건들건들하는 태도부터 차량 상태까지 좋은 점이 없었습니다',
#   '카카오맵',
#   1,
#   '21.05.24.',
#   '무지개렌트카'],
#  ['ray',
#   '거의반파된차량 사고 차량 수리없이 주고<br/>서비스최악입니다',
#   '카카오맵',
#   1,
#   '21.05.20.',
#   '무지개렌트카'],
#  ['냥냥펀치',
#   '3박4일 56만원..성수기 감안하고도.,차량이 너무 후짐.담엔 한번쯤 들어본 렌트카 업체랑 해야겠네요..',
#   '카카오맵',
#   1,
#   '21.05.19.',
#   '무지개렌트카'],
#  ['몰튼',
#   '렌터카 K5주문해서 받아보니 15만키로나 주행하고 관리도 안된차를 주네요. 직원들 응대는 나쁘지않은데 중요한 렌터카가 오래된 차를주어서  다시는 이용하고싶지 않아요<br/>제주속으로라는 사이트를 이용했는데 연결만해주는데 같고 통일렌터카 나 무지개렌터카 나 모두 같은곳입니다',
#   '카카오맵',
#   1,
#   '21.05.07.',
#   '무지개렌트카'],
#  ['쏭',
#   '왠만하면 그냥 넘기려고하는데 진짜 이건아닌거같아서<br/>글남기네요. 진짜 별하나도 아까워요.<br/>차량인수할때부터 차상태가 너무 안좋아서 기가막히네요<br/>엔진소리 딱들을때부터 와 이거아닌데..싶었습니다<br/>제주도에서 일 4-5만원돈내고 <br/>스파크를 16-17만키로 차에, <br/>타이어는 빗살무늬토기에(마모심함), <br/>옵션은 완전 깡통에, 여기저기 다 긁혀있고, <br/>세차도 안되어있고 심지어 직원관리도 안되있어서 <br/>안내없이 고객이 셀프로 차를 가져가는시스템...<br/>원래 인수하려던차를 다른사람이 가져가버렸는데도, <br/>미안하다말없이 어차피 다똑같은차니까 그냥쓰라는식<br/>리뷰를 봤으면 절대 렌트안했을텐데 <br/>하...여행시작부터 심각하게 현타오네요..',
#   '카카오맵',
#   1,
#   '21.05.06.',
#   '무지개렌트카'],
#  ['SY',
#   '싸게 빌렸고 며칠 잠깐 타는거니깐 외관이 엉망이고 실내 세차도 하나도 안 되어 있는지 먼지 가득하고 운전석 뒷좌석 손잡이에는 쓰레기가 있어도 그것도 다 이해하고 타려고 했는데.. 차량 반납할 때 수고하세요 하고 가려고 하니깐 기다리라고 화내더니 사고 냈냐고 하면서 차 보더니 그냥 가라고 그러고.. 가면서도 엑셀 완전 부앙 밟고가고... <br/>워셔액도 없는지 전면유리가 더러워서 작동하니깐 찔끔 나오고 안 나왔네요. 차량에 기본적인 워셔액도 없다면 다른 관리는 아예 안 됐다고 생각이 들 수밖에 없는데, 차 상태가 엉망인만큼 직원 관리도 엉망이신가봐요. 리뷰 진짜 잘 안 남기는데 너무 화나서 리뷰 써보네요..',
#   '카카오맵',
#   1,
#   '21.04.20.',
#   '무지개렌트카'],
#  ['프로여행러',
#   '평을 보고 예약했으면 안했을텐데요ㅠㅠ<br/>1. 직원 매우 불친절<br/>2. LPG 해달라고 했는데 휘발유<br/>3. 비싼 가격, 생활감 심하고 상태 안 좋은 차<br/>다른 곳 예약하시길 바랍니다.',
#   '카카오맵',
#   1,
#   '21.04.17.',
#   '무지개렌트카'],
#  ['I',
#   '미리예약을해서 두번 이용했는데요. 1년 된 차 타이어가 뒷바퀴는 한계선. 앞바퀴는 한계선에서 조금 위에. 타이어도 사고수리로 타이어를 바꿨는지 앞바퀴는 금호 뒷바퀴는 넥센. 한번도 아니고 두번 다 타이어 교환시기일 정도로 닳음. 타이어가 오래되니 주행 중 차가 미끄러저 놀람. 타이어 말해도 차량 교환은 안 된다는 말뿐. 응대도 불친절 딱딱한 말투. 내가 이용한 차 2대랑 후기를 보니 다른차도 다 오래된 타이어라 차를 교환해도 타이어는 마찬가지로 닳아 있었을 듯.',
#   '카카오맵',
#   1,
#   '21.03.18.',
#   '무지개렌트카'],
#  ['@_@',
#   '라이트, 브레이크등 한쪽이 안들어오고<br/>불루투스도 없고 냄새나고..저렴한 이유가 있어요<br/>한마디로 차상태 개구려요 ㅋㅋㅋㅋ<br/>다음부터는 이용 안하는걸로',
#   '카카오맵',
#   1,
#   '21.02.25.',
#   '무지개렌트카'],
#  ['류엽',
#   '후기가 안좋아서 걱정했는데 되게 좋아요 차량도 깨끗하고 생활기스도 봐주시네요',
#   '카카오맵',
#   5,
#   '21.02.03.',
#   '무지개렌트카'],
#  ['헤헤',
#   '카카오 평점을 보신 분이라면 무조건 여기 렌터카는 피하시기 바랍니다 저는 미리 안봤는데 제가 느낀거랑 똑같은 경험들을 많이 하셔서 놀라울정도입니다 제주도 여러번 오면서 많은 렌터카를 타봤기에 다른업체들과 너무 비교가 됩니다 <br/>일단 차량상태가 너무 안좋습니다 사고가 안나면 다행겠지만 운 안좋으면 날수 있습니다 타이어 마모상태 엄청나구요 주행하다보면 그 감 있죠 차 상태가 좋지않다 관리가 잘 안되어있다 느껴집니다<br/>셔틀버스 기사, 직원 매우 불친절에 나쁘게 말하면 ㅇㅇㅊ 느낌납니다 제주도에 렌터카 정말 많지요? 무조건 걸러야하는 곳입니다',
#   '카카오맵',
#   1,
#   '21.02.03.',
#   '무지개렌트카'],
#  ['azkjhg', '', '카카오맵', 5, '21.02.02.', '무지개렌트카'],
#  ['배승진',
#   '별 하나도 아까운데 별 제로는 없어서 어쩔수없이 체크합니다.<br/>저렴하게 렌트하려고 레이를 2박3일에 43,000원 주고 렌트했다가 부실한 타이어가 문제가 생겨 렉카 출동비 45,000원(현금)와 견인비 7만원 +뒷 타이어 파손으로 특수 견인비로 추가 7만원 모두 합이 185,000원을 요구하여 직접 운행시 차 파손에대한 책임을 감수하겠다 하고 직접 타이어 교체하였습니다.<br/>결과적으로 렌트비 43,000으로 저렴하게 하려다<br/>추가비용이 115,000이 더 들었네요.<br/>제주도 렌터가 타이어 사고가 잦다는 소리는 들었지만<br/>실제로 제가 겪으니 심히 불쾌하고 화나네요.<br/>심지어 빌릴때는 친절 상담하시더니 타이어 사고 접수 이후 상담때는 무뚝뚝해지고 전화조차 잘 안받으니 앞뒤가 다름이 여실히 느껴졌습니다.',
#   '카카오맵',
#   1,
#   '21.01.27.',
#   '무지개렌트카'],
#  ['봄라에몽',
#   '아니ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ<br/>셔틀기사님<br/>"이 시국에 제주도는 뭐하러 와가지고 에이씨" 라고 <br/>하셧져 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 손님 다 태우고요^_^<br/>버스에서 말하지 말라고 하셨는데 뒤쪽에서 계속 대화하니까 "에이씨 내려버릴까보다" 이런 뉘앙스도 계속 하시고 째려보시고ㅋㅋ <br/>코로나라 백번 이해합니다. 암요<br/><br/>근데 그럼 팔지도 마시지 그러셨어요 ^^ <br/>이 시국에 상품공급은 하면서 공급된 상품 수요한다고 욕을 먹어야한다니요.. <br/><br/>이렇기 심해질지 모르고, 집안에 큰 경사 겸사겸사 한참전에 예약했다가 취소 못하고 어영부영 갔는데<br/>제주 제일 먼저가서 들은말이 "뭐하러왔냐" 이거네요^^*<br/>제주도 자주 갔지만 이런 경우는 첨이라 당황스럽네여<br/><br/>다신 이용안할게요^_^ 감사합니다.',
#   '카카오맵',
#   1,
#   '20.12.13.',
#   '무지개렌트카'],
#  ['장현',
#   '카니발 2628 피하세요<br/><br/>타이어 마모가 어마어마함<br/><br/>담배 찐내 및 악취 심함.<br/><br/>핸들떨림. 브레이크 위험.<br/><br/>싼마이로 목숨 걸고 다녔음.<br/><br/>이상 무',
#   '카카오맵',
#   1,
#   '20.12.13.',
#   '무지개렌트카'],
#  ['장 진숙',
#   '뭐든게  다 신속하고 정확해서 좋았어요  친구들과  쏘나타ㆍ투싼 두대 빌렸는데 도착해서 셔틀버스타고  한시간 반 일찍 갔는데도 이미  사무실옆에 저희차가  준비되어 있었어요 반납도  신속했어요 만족합니다 다음에  또 이용할겁니다',
#   '카카오맵',
#   5,
#   '20.12.09.',
#   '무지개렌트카'],
#  ['lee',
#   '평이 안좋아서 되게 걱정했는데, 전 만족합니다~ 친절하시고 반납도 아무문제 없었구요~',
#   '카카오맵',
#   5,
#   '20.11.27.',
#   '무지개렌트카'],
#  ['환상',
#   '아반떼 AD차량을 렌트하던중 사고가 발생해서 걱정 많이 했는데 사고 담당자분이 너무 친절히 잘 처리해 주셔서 감사합니다.<br/>사고 수리비도 많이 나올것 같아 걱정했는데 고급자차를 가입해서 수리비는 하나도 지불할 필요가 없다고 해서 너무 좋았어요 ㅋㅋ<br/>다른분들도 자차보험 꼭 가입하세요',
#   '카카오맵',
#   5,
#   '20.11.26.',
#   '무지개렌트카'],
#  ['이쁜맘',
#   '차량배차 및 반납이 빨라서...좋아요~~~^^ 다음에 또 이용~~~할께요! 싸게 해주시면~~ㅋㅋ',
#   '카카오맵',
#   5,
#   '20.11.26.',
#   '무지개렌트카'],
#  ['이정호',
#   '제주에서 가장큰 업체라고 해서 이용했어요~ 잘 이용했어요~ 새차 받아서 좋았습니다.',
#   '카카오맵',
#   5,
#   '20.11.26.',
#   '무지개렌트카'],
#  ['밤밤',
#   '욕많던데 저는 괜찮았음 <br/>운행중에도 이상 없고  가격도 싸게 빌림 소나타 렌트했는데 다른곳 모닝 레이보다 저렴했음',
#   '카카오맵',
#   5,
#   '20.11.23.',
#   '무지개렌트카'],
#  ['최정민',
#   '무지개같아요 오늘 황천길 영접함<br/>싼거 찾다가 한달동안 레이타고다녔는데<br/>첫날부터 시동 잘 안걸리더니<br/>일주일도 안돼서 방전됨<br/>차량 교체도 받았는데 교체받은 차도 말썽<br/>결국 오늘 공항가는길에 차에서 연기남<br/>라디오도 꺼졌다 켜졌다 첨엔 귀신들린줄<br/>핸들도 안움직여서 갓길 간신히 세우고<br/>전화해서 이것 저것 물었더니<br/>조치취하려는데 자꾸 전화한다고 끊으라함<br/>택시비 준다해서 516도로한복판에서 택시기다림<br/>택시기사분은 좋은분 만나서 편하게옴^-^<br/>다들 부디 돈좀 더주고 다른곳 가셔서<br/>목숨 챙기세요ㅎㅎ',
#   '카카오맵',
#   1,
#   '20.11.18.',
#   '무지개렌트카'],
#  ['weon', '차상태별로에요 냄새도나고 담부터 여기패스', '카카오맵', 1, '20.11.17.', '무지개렌트카'],
#  ['^ㅇ^',
#   '단 한가지 빼고 모든게 완벽했던 제주여행이었습니다.ㅎ 진작 후기를 읽어봤어야 했는데 엄청 후회했습니다,,기본적인 설명은 해주지도 않고, 궁금한 것을 물어보았을 때 손님을 응대하는 태도는 더 별로였던..다른 사람들이 왜 이러한 평가를 했는지 충분히 이해가갑니다. 여행의 시작부분을 담당하고 있는만큼 신중하게 선택하시는게 좋을듯합니다~',
#   '카카오맵',
#   1,
#   '20.11.15.',
#   '무지개렌트카'],
#  ['진국',
#   '다른분 말대로 별 하나도 아깝네요. 랜트카도 서비스업인데 공짜로 차 얻어타는 느낌이랄까? 아들보다 더 어린친구한테 고함소리들이니 기분 참 묘하데요. 차도 외부에 물만 한번 뒤집어씌우고 바로 다시 렌트한 느낌이랄까? 지인소개로 예약했는데 정말 비추 또 비춥니다.',
#   '카카오맵',
#   1,
#   '20.11.13.',
#   '무지개렌트카'],
#  ['박지훈',
#   '* 여행 망치고 싶으면 예약하세요 *<br/><br/>완전자차로 이미 결제하고 예약했음에도 현장에서 완전자차에 미포함되어있는 5가지 항목에 대해 특약가입을 유도합니다 그 내용이 아주 가관입니다 타이어펑크 휠손상등 아주 흔히 발생하기 쉬운 항목들입니다 <br/><br/>이렇게 울며 겨자먹기로 만원을 추가로 결제해야합니다 찝찝하니까...<br/><br/>직원의 불친절은 뭐 기본입니다 사람들 모아놓고 얘기하는 사람 다소 고압적입니다 접수때도 수식어가 없고 전부 명사 입니다 <br/><br/>차량은 뭐 최근연식으로 2만키로탄 차라 상태는 나쁘지 않았습니다<br/>하지만 기름은 한칸 차 있었습니다',
#   '카카오맵',
#   1,
#   '20.11.12.',
#   '무지개렌트카'],
#  ['모지',
#   '처음부터 여길 고르는게 아니였네요 <br/>과한 친절을 바란것도 아니고 기본적인 것도 모르는 직원들^^.. 여행 망치고 싶으시면 이용하세요~~',
#   '카카오맵',
#   1,
#   '20.10.28.',
#   '무지개렌트카'],
#  ['ㅇㅇㅇ',
#   '별 한개도 아까워요 여기서 렌트해봤는데 직원들 너무 불친절해요.. 다시는 여기서 렌트하지않으려구요',
#   '카카오맵',
#   1,
#   '20.10.28.',
#   '무지개렌트카'],
#  ['J',
#   '최악 중에 최악 차는 후지고 블루투스로 음악도 안되고 세차도 안되어있고 관리도안되고 그냥 별로임.',
#   '카카오맵',
#   1,
#   '20.10.11.',
#   '무지개렌트카'],
#  ['소식.저염식.평균치입맛.',
#   '전기차 대여했고, 시키는대로 사진 왕창 찍어놔서 분쟁거리 없었습니다.<br/>전기차 완충이 80%정도인데 이틀에 한 번 충전하면 되더군요.<br/>사람이 엄청 몰려서 상세 설명이 없는건 아쉽지만 저렴하게 대여했고, 서비스가 불만족스러울 정돈 아니었습니다.',
#   '카카오맵',
#   3,
#   '20.10.10.',
#   '무지개렌트카'],
#  ['김상혁',
#   '렌트카 반납하는데 차키던지시고 <br/>서비스꽝입니다 증말...',
#   '카카오맵',
#   1,
#   '20.10.03.',
#   '무지개렌트카'],
#  ['dshong',
#   '주유량 모닝차 12시방향보다 더넘게 채워갔는데 눈금 하나더있었다며 바쁘고 짐많고 어리버리한 바보인줄 알아본 그들 돈 5천원 받아낸 칼안든 강도심보',
#   '카카오맵',
#   1,
#   '20.09.16.',
#   '무지개렌트카'],
#  ['카라멜',
#   '걍 정상적으로 주차했는데 하루사이에 방전됨<br/>싸지만 싼게 비지떡...',
#   '카카오맵',
#   1,
#   '20.09.09.',
#   '무지개렌트카'],
#  ['Hi',
#   '차량 두번 빌렸는데 둘 다 방전... 차량 관리 좀 부탁 드립니다..',
#   '카카오맵',
#   1,
#   '20.09.08.',
#   '무지개렌트카'],
#  ['아오지탄광노동자',
#   '렌트는 걍 메이저로 하세요 새차받았다는 사람들은 직원인듯합니다 저는 18만km 마일리지 차 받았구요 등판때 차 가속 진짜 안나오고, 덜컹하기도 해서 진짜 무서웠습니다. 도저히 차몰기가 겁나서 반납시간 이틀전에 반납했구요, 롯데로 새로 빌려서 썼습니다 참고하세요',
#   '카카오맵',
#   1,
#   '20.09.07.',
#   '무지개렌트카'],
#  ['밝은미래',
#   '뉴라이즈 3박4일 사용하였는데 사이드브레이크 불량으로 몇번씩 해봐야 브레이크 체결됨. 그렇다고 내부가 깔끔한것도 아님. 차량인수시 직원이 차량에대한 설명 하나고 안해주고 알아서 기스부위 사진찍고 가라고함. 블랙박스도 없어서 사고시 덤탱이 씌우기 십상임. 차량반납후 공항셔틀버스탈때는 사람들이 그냥 다 좀비들임. 한줄로서라는 표시도없고 먼저와서 대기해도 제일 늦게타게됨. 원래 메이저 렌터카회사만 이용하다가 가격도 저렴하고 보험도 괜찮길래 했다가 앞으로 메이저 렌터가 이용할 계획임.',
#   '카카오맵',
#   1,
#   '20.08.16.',
#   '무지개렌트카'],
#  ['전병근(B.K. Jun)',
#   '업무 처리도 빠르고, 차량 청결상태도 양호하였습니다',
#   '카카오맵',
#   4,
#   '20.08.07.',
#   '무지개렌트카'],
#  ['도깨비 투',
#   '13명이 탔는데 너무 편하고 좋았어요<br/>승차감도 좋고...<br/>그리고 에어컨빵빵....반납할때 쓰레기 나두면 다치워주신다고 하니까 좋아요<br/>저렴하게1박2일...오전9시~다음날 저녁8시까지<br/>제일싸게 했어요',
#   '카카오맵',
#   5,
#   '20.07.23.',
#   '무지개렌트카'],
#  ['jiyoon',
#   '여행사 통해서 무지개렌트카 이용하게 됐는데, 평이 별로여서 정말 걱정 많이 했어서, 저 같은 분들을 위한 리뷰 남김ㅋㅋ <br/>저는 신차로 배정받고 차 안도 엄청 깨끗하고 반납에도 특별한 테클 없이 문제없이 잘 썼어요ㅎ 특약(타이어)는 오히려 물어봐줘서 고마웠음. 이 전에 그냥 렌트 자차로 해서 별 신경 안쓰고 있다가, 타이어 터져서 5만원인가 추가로 돈 물었거든요. 타이어 마모도 꽤 만족스러운 상태였고,  잘 탔어요ㅋ 걍 참고하세요~',
#   '카카오맵',
#   5,
#   '20.07.20.',
#   '무지개렌트카'],
#  ['JH',
#   '차 관리 안하는지?<br/>내부청소는 고사하고 새똥 가득한<br/>차량을 건내주는지.. <br/>또한 애매한 주유량<br/>직원들의 불친절에 매우 감명받고 갑니다.',
#   '카카오맵',
#   1,
#   '20.07.18.',
#   '무지개렌트카'],
#  ['3대 걸고 솔직한 리뷰',
#   '급하게 경차 빌리려고 했는데 여기만 경차가 남아있길래 여기로 예약했는데, 남은 이유가 있었네요.<br/>직원들은 괜찮았는데, 차 상태가 너무 엉망이었어요ㅋㅋ<br/>차가 심하게 덜덜거리고 소리나서 전화로 문의하니까 에어컨끄고 서행하라고 하셨는데 그래도 똑같았습니다.<br/>너무 덜덜대서 차 탈때마다 머리아프고 기분나빴어요.<br/>경차여서 그런지 모르겠지만 엑셀을 밟아도 속도가 안나거나 갑자기 속도붙고 그랬어요. 블랙박스도 없네요.',
#   '카카오맵',
#   1,
#   '20.07.03.',
#   '무지개렌트카'],
#  ['초코라즈베리',
#   '싼맛에 한다고 렌트했는데 싸니까 차량이 후진건 이해하겠는데 직원들 ㅈㄹ 싸가지 없음 그리고 네비는 업데이트가 몇년간 안된건지 관리 아예 안한 느낌에 블랙박스도 없어서 사고뿐만 아니라 누가 박도 튄다면 답 없음 일부러 블박 안달고 사기치려는듯ㅋ 그냥 다음엔 좀더 내더라도 메이져렌트업체 쓸 생각임',
#   '카카오맵',
#   1,
#   '20.07.02.',
#   '무지개렌트카'],
#  ['구구', '금연차량인데 담배냄새도 너무 심하고 내부가 넘 더러움...', '카카오맵', 1, '20.06.29.', '무지개렌트카'],
#  ['돌직구',
#   '별 1개 주기도 아까움, 고객응대도 개똥이고 궁금한거 물어보려고 전화하면 화를내지를 않나..출장때문에 회사에서 어쩔수없이 렌트카를 썼지만 다신 안감 진심 최악중에 최악',
#   '카카오맵',
#   1,
#   '20.06.19.',
#   '무지개렌트카'],
#  ['지성',
#   '단기렌트 최대 7일이고요. 카니발 7인승 빌렸는데 문도 너무 뻑뻑해서 부모님이 열고 닫기가 너무 불편했어요. 한달살기로 빌리기는 좀 불편한거 같네요.',
#   '카카오맵',
#   2,
#   '20.06.07.',
#   '무지개렌트카'],
#  ['비탕이',
#   '장기렌트가 거의없고 <br/>대부분 8박9일씩 렌트해야한다. <br/><br/>다른 업체에서 매번 반납에 맞춰 다시 동일 차종 렌트로 모두 예약하면  재 방문없이 여행기간 편하게 여행<br/><br/>여기도 당연히 될줄 알았지만<br/>와서 계약서 쓰란다 ㅋ<br/><br/>그러고 하는말<br/>전기차 충전효 미리 결제 할거에요?<br/>ㅋㅋㅋ<br/><br/>미쳤냐 다시 오래매 ㅋ<br/><br/>.<br/><br/>전화4번해서 담당자 바뀌면 혹 가능하지 않을까해서 여행기간 내내 전화했지만 매번 앵무새<br/><br/>심지어 2번째 빌리는 날짜들은 다른 곳보다 여기가 1만원 비쌌지만 제주 방문해서 왕복하기 귀찮아서 했는데 완전 대실패<br/><br/>다시는 이용안함. <br/>다른 곳 빌리세여<br/><br/>불친절. 혹시 사고라도 나면 사람 잡을 업체',
#   '카카오맵',
#   1,
#   '20.06.02.',
#   '무지개렌트카'],
#  ['조수영', '', '카카오맵', 1, '20.05.26.', '무지개렌트카'],
#  ['박용준',
#   '갑작스런 여행에 예약 제대로 안되어 공항 도착 렌트하라고 다가오는 분들 비쌌음. 렌트카 데스크 모인 곳에서 저렴하다는 문구보고 선택. 만족스러웠음. 남은 연료비 정산도 잘 받음.',
#   '카카오맵',
#   4,
#   '20.05.21.',
#   '무지개렌트카'],
#  ['CCP',
#   'GPS NOT WORKING ,  SERVICE NEED TO IMPROVE , STAFF INPOLITE , NO NEXT TIME',
#   '카카오맵',
#   1,
#   '20.05.07.',
#   '무지개렌트카'],
#  ['.',
#   '싸가지 겁나없음. 하긴 뭐이런거 남긴다고 바뀌는데였으면 진작 바뀌었겠지 ㅎ',
#   '카카오맵',
#   1,
#   '20.05.04.',
#   '무지개렌트카'],
#  ['이규열', '직원들이 손님한테 화내고 짜증내요 <br/>다른데 가세요', '카카오맵', 1, '20.05.04.', '무지개렌트카'],
#  ['새로운 길을 위해...',
#   '차량 내가 형광등이네요<br/>2분대기...<br/>일부러 비싸도 새차 렌트해서 차량문제는 없었고<br/>직원분들 친절도가 별로라<br/>다음에는 이용 안하렵니다',
#   '카카오맵',
#   3,
#   '20.03.21.',
#   '무지개렌트카'],
#  ['..',
#   '기름은 그때그때 넣으세요<br/>마지막에 소액 주유했더니 소액은 계기판에 반영이 안된다고 기름값 더 냈네요',
#   '카카오맵',
#   2,
#   '20.03.18.',
#   '무지개렌트카'],
#  ['쓰레기만보면짖는냐옹이',
#   '장점 싸다<br/>단점 싸고 좋은차는 없다<br/><br/>차량들 연식이 오래되어 연비는 좋지않다',
#   '카카오맵',
#   3,
#   '20.03.01.',
#   '무지개렌트카'],
#  ['do it',
#   '제주 도민인데요 가끔씩 렌트카가 필요한 때가 있어서 빌려요. 땡처리 닷컴에서 완전자차 고급보험들고도 너무 착한 가격에 빌렸고 차량은 옵션은 없었지만 사전 고지 정보 게시됐었고 차 잘나가고 잘서요. 차량 외관이 참 깨끗하거나 특별하진 않지만  솔직히 가성비도 좋았고 차 문제 없으면 대여도 반납도 엄청 빨라요 1분 컷인듯 ㅋㅎ 저는 다음에도 대여 생각 있습니다! 평점이 왜이렇게까지 낮은지 이전이 별로였는지는 모르겠지만 제 사용 리뷰 써둡니다!',
#   '카카오맵',
#   4,
#   '20.02.19.',
#   '무지개렌트카'],
#  ['애젤콩',
#   '한개도 아까움 <br/>진짜 이런거 안남기는데 하.. 진짜 최악',
#   '카카오맵',
#   1,
#   '20.02.15.',
#   '무지개렌트카'],
#  ['짱갱', '차 깨끗하고 괜찮았어요', '카카오맵', 3, '20.02.12.', '무지개렌트카'],
#  ['김진석',
#   '타업체보다 가격도 저렴하고<br/>차도 적당하고<br/>후기점수보고<br/>고민했는데<br/>저는 만족합니다',
#   '카카오맵',
#   4,
#   '20.01.28.',
#   '무지개렌트카'],
#  ['JH~~천사',
#   '자동차 내부 머리카락과 모래 투성이에 시트 위는 지저분하고 차 내부 청소 하나도 안되어 있어 너무 지저분합니다. 그리고 보험 추가하려고 질문했더니 짜증내는 직원 때문에 그냥 탔습니다. 제주도 5번째 방문인데 이런 형편없는 렌트카회사 처음 입니다.',
#   '카카오맵',
#   1,
#   '20.01.24.',
#   '무지개렌트카'],
#  ['평진', '나쁘진 않았어요', '카카오맵', 3, '19.12.28.', '무지개렌트카'],
#  ['탁아저씨',
#   '통일/무지개 같은 회사라서 후기 남깁니다. <br/><br/>배차 받기 전 툴툴거리는 여직원/ 예약 시간보다 늦은 배차 / 차량 내부 악취 / 주유 빨간불 들어와있는 상태로 배차<br/><br/>쿠팡에서 차량 예약 후 이쪽 렌트카로 배정되었는데 제주도 자주 다니지만 렌트카 중 최악이네요.',
#   '카카오맵',
#   1,
#   '19.12.25.',
#   '무지개렌트카'],
#  ['sue',
#   '진짜 불친절합니다.. 가격도 비싼편이고 더 좋은 렌트카업체가세요ㅠㅠㅠ 셔틀버스도 너무 더러워서 만지기도 싫었어요 <br/><br/>평점안보고 급하게 예약했는데 실수였네요 <br/>제발 거르세요',
#   '카카오맵',
#   1,
#   '19.12.20.',
#   '무지개렌트카'],
#  ['내가내가',
#   '최악. 정말 최악. 공항에서 렌트장소까지 운행하는 젊은 버스기사 드라마보면서 운전함.. 정말 식겁..제주 여행갔다가 장례치를뻔. 직원들도 불친절. 정말 싸게 렌트하고 싶으면 가세요. 아니면 정말 비추입니다. 별 1개도 아까움',
#   '카카오맵',
#   1,
#   '19.12.17.',
#   '무지개렌트카'],
#  ['신형준',
#   '렌트 한 두번 한게 아닌데 여긴 최악. 연료 엥꼬난 차를 줘놓고 밤에 주유소들 문 닫아서 일일히 찾게 만들고, 연료 체우고 여행 끝나서 반납할 때 연료가 많이 남아 있음에도 환불처리 제대로 해주지도 않는 렌트 업체였음',
#   '카카오맵',
#   1,
#   '19.12.15.',
#   '무지개렌트카'],
#  ['김영진',
#   '평보고 걱정했는데<br/>일주일간 18년식 올뉴k3 깨끗한차 잘타고 다녔습니다.',
#   '카카오맵',
#   5,
#   '19.12.07.',
#   '무지개렌트카'],
#  ['박상인', '제주도에서 렌트는 덕분에 그냥 쏘카가 최선이라고 배웠네요.', '카카오맵', 1, '19.12.06.', '무지개렌트카'],
#  ['.', '차 상태 최악 불친절.. ㅋㅋㅋ 그냥 싼값에 쓰는곳', '카카오맵', 1, '19.11.21.', '무지개렌트카'],
#  ['지원',
#   '평 보고 걱정했는데<br/>완전 무난; 차도 깨끗하고 잘 썼습니다.',
#   '카카오맵',
#   5,
#   '19.11.11.',
#   '무지개렌트카'],
#  ['smpark', '뭐하나 수틀리면 윽박질러요..ㅎ', '카카오맵', 1, '19.11.09.', '무지개렌트카'],
#  ['하잉',
#   '가격적인 이득도 없고.. 차 상태도 완전히 안좋고.. 18년형인데 한 10년은 된차 같고요? 외부에 긁힌 자국 많던데 수리 좀 하세요.. 그리고 워셔액도 하나도 안들어있더라고요? 비올때까지 앞창문 닦지 말라는건지? 여러분 대기업 렌터카 이용하세요',
#   '카카오맵',
#   1,
#   '19.11.07.',
#   '무지개렌트카'],
#  ['소비자는왕',
#   '(중요)공항으로 돌아가는 셔틀이 간격 길어요<br/>내가 도착하고 바로간건지~<br/>30 분기다렸습니다~~<br/>큰차말고 수시로 다니는 작은 버스가 하나있으면<br/>좋을거같은데~~<br/><br/>비행 시간 급하게 반납하러 오면~<br/>고려하세요~~<br/><br/>제주속으로 랜덤 배정같은데 ㅠ<br/>첫 인상이 도떼기 시장 같아요~~<br/>마이크잡고 설명하는데 ~<br/>사고나면 큰일날거 같은 기분이~<br/>불친절함이 느껴져요~<br/><br/>차는 그냥제가받은차는 고만고만했어요<br/>청소잘되어있고~~<br/>근데 블박없어서 사고나면 덤터기 쓸수있을듯해요',
#   '카카오맵',
#   2,
#   '19.10.18.',
#   '무지개렌트카'],
#  ['가희',
#   '직원들  불친절합니다<br/>질문을하면  말투가 싸우고  싶어하는  듯 답하고 반납완료됐다는  말도 없이  사라져버리더군요<br/>차도  오래되고  청결상태도  불량했습니다<br/>차  빌릴때 패키지  손님인줄  알았네요 모아놓고  안내방송처럼  기계적  안내  한 번하고  끝입니다',
#   '카카오맵',
#   1,
#   '19.10.01.',
#   '무지개렌트카'],
#  ['이세상음식다내꺼',
#   '리뷰 평이 너무 안좋아서 취소할까하다가 그냥 렌트했는데,<br/>딱히 불만은 없습니다! 굳이 뽑자면 연식이 좀 되서 차가 잘 안나가는 것 같은 느낌! 그 외에는 그냥 무난해요! 네비 좀 오래되보이니ㅜ핸드폰 내비 필수입니닷!! 핸드폰 거치대 없으니 꼭 챙겨오세영~~',
#   '카카오맵',
#   4,
#   '19.09.29.',
#   '무지개렌트카'],
#  ['fhbnd', '왜 별점이 1개인지 겪어보니 알겠네요..', '카카오맵', 1, '19.09.27.', '무지개렌트카'],
#  ['민주영',
#   '연료량이 출발전보다 많으면,<br/>많은 만큼 연료비를 주기로 되있었는데 안주네요.<br/>메모하면 연료비를 준다는데 말이 다르네요.<br/><br/>저번주 토 ~ 일에 빌렸었습니다.<br/><br/>받으러가자니 비행기 값이 더 나오겠네.....',
#   '카카오맵',
#   1,
#   '19.08.06.',
#   '무지개렌트카'],
#  ['치즈대왕',
#   '불친절한 직원 차상태 엉망 공항가는 셔틀버스도 간격이 넘 길어요  비추입니다',
#   '카카오맵',
#   1,
#   '19.07.28.',
#   '무지개렌트카'],
#  ['방준식', '차냄새가 많이났어요', '카카오맵', 2, '19.07.05.', '무지개렌트카'],
#  ['SY', '셔틀버스 기사님 빼고 맘들', '카카오맵', 4, '19.06.25.', '무지개렌트카'],
#  ['정윤호+세분',
#   '볼트 48시간. 충전카드비 9천원 따로 받음. 누적주행거리 41400정도인데 실내 먼지 많고 오래된 차냄새가 좀 나네요. 워셔액도 없고 외부세차도 안되어 있음. 야간인수 비용은 안받았으나 차 인수받는데 사람없어서 그냥 몰고 나옴. 아주 싼가격 아니고는 비추..',
#   '카카오맵',
#   1,
#   '19.06.22.',
#   '무지개렌트카'],
#  ['김일우', '저녁엔 30분에 한번씩 셔틀이 운행합니다. 이용 비추', '카카오맵', 1, '19.06.02.', '무지개렌트카'],
#  ['김용찬', '차가 온통 상처투성이에 안테나도 없고 뒷문짝은 고장났음', '카카오맵', 1, '19.05.22.', '무지개렌트카'],
#  ['김판철',
#   '어제 렌트 받아서 지금 여행중입니다.<br/>차 진짜 더럽네요. 먼지 수북히 쌓여있고 핸들은 풀을 처발랐는지 끈적거리고. 탑승전 차량 외관이랑 주유게이지 찍으라는데 ㅋ 기스 흠집 하도 많아서 무슨 자동차 촬영하러 온건지 후기보니 뭐 기름값 더 받는대서 혹시 몰라 영수증도 안버릴라구요^^ 진짜 또 제주여행 오게되면 믿고 거릅니다. <br/>짜증나네 여행기간 동안 이 차 타고다닐 생각하니까',
#   '카카오맵',
#   1,
#   '19.05.13.',
#   '무지개렌트카'],
#  ['TG',
#   '별 0개는 줄수 없는 거예요?<br/>나 사람들이 왜 다들 비난하는 지 오늘 알았음.<br/>오랜만에 내차 놓고 미리 예약하고 제주도 왔음.<br/>볼트(전기차)빌림.<br/>차를 딱 받았는데 차내 공기가 너무 않좋음.<br/>다음날 아침에 전화 해서 <br/>나: 차내 공기가 너무 않좋은데 에어컨 필터 교환해 줄 수 있나요?<br/>무지개: (어이없다는 듯 웃으며) 네?! 허.. 참 <br/>나: 아니 웃으라고 전화드린 거 아니고요, 가능하다 아니다 뭐 답변을 주셔야 할 것 아닙니까.<br/>무지개: 전기차는요~ 부품이 없어요~ 무조건 사업소 들어가야 되요~<br/>나: 아 예. 안된다는 거죠? <br/>무지개: 예~<br/>나: 네, 알겠습니다.<br/>통화종료.<br/>아니 내가 말도 않되는 거 요구 했나? 그리고 고객이 문의하는데 그딴태도는 뭐냐?!<br/>아니 상식적으로 이런 경우에<br/>‘불편하게 해서 미안하다. 근데 필터교체는 해주지 않는다.’ 그냥 이렇게 말하면 되는 거 아녀?! <br/>우선 불편함 건 나이므로 이마트 가서 5000원 주고 필터 사서 교환했음.<br/>하지만 이 불쾌한 대화는 영영 잊지 않을 것임.',
#   '카카오맵',
#   1,
#   '19.05.02.',
#   '무지개렌트카'],
#  ['최원혁', '차 더러움. 직원 불친절.', '카카오맵', 1, '19.03.10.', '무지개렌트카'],
#  ['귀록',
#   '정말 별로입니다. 어쩌다 보니 2번째 이용을 했는데 차량에서 이상한 냄새가 나구요. 서비스 마인드는 제로입니다. <br/><br/>또 사전이 차량 점검을 제대로 안하고, 관리가 잘 안되는 곳입니다.<br/>운행중에 타이어에 이상을 발견해서 이야기를 했더니 가까운 정비소에서 수리하고 내역을가져다달라고 하고... <br/>사전점검을 제대로 안하고 왜 수리 책임을 왜 고객에게 전가하는지.<br/>물론 계속 이야기해서 차를 가져다 주시긴 하셨는데,<br/>미안하다는 이야기도 없고, 참 어이없더라구요. 다신 안갈겁니다.<br/><br/>참 별 경험을 다해보네요. 통ㅇ',
#   '카카오맵',
#   1,
#   '19.02.27.',
#   '무지개렌트카'],
#  ['-',
#   '이용하지마세요. 직원들도 불친절하고, 차량 인수인계할때 제대로 알려주지도 않습니다. 나중에 운전자 잘못이라며 떠넘깁니다.기름 부족할때도 주유소 금액보다 훨씬비싸게 받고는 자기가 적정수준이라고 우깁니다',
#   '카카오맵',
#   1,
#   '19.02.05.',
#   '무지개렌트카'],
#  ['귀찮은데진실을쓴다',
#   '한개도 아깝습니다. 시장통도 이런 시장통이 ㅋㅋ 셔틀만석에 사람 다 서서 도착... 카운터 겨우 2개.. 대기 많이 걸려서 차 찾는데 몇번 구역에서 알아서 찾아가라.. 가니까 차없어서 다른 직원이 다른 구역에서 찾아주는데... 미안은 커녕 친절하지도 않음',
#   '카카오맵',
#   1,
#   '19.01.11.',
#   '무지개렌트카'],
#  ['JPH', '정말 지저분하게 영업하네요.', '카카오맵', 1, '18.10.09.', '무지개렌트카'],
#  ['이쁜이',
#   '공항에서 길을 제대로 찾았는지 몰라 전화했을 때도 친절하게 맞아주셨는데 환승차량 기사님도 친절하셔서 기분 좋았습니다! 저희는 부모님과의 여행이라 신경 덜 쓰고 싶어 만원인가 더 주고 보험특약을 들어서 혹시 기스나지 않을까 걱정하지 않으며 잘 다녔습니다 ㅋㅋ 차는 기스도 좀 있고 해서 걱정했는데 잘 나가서 좋았습니다! 마지막에 반납할 때도 특약을 들어 그런가 보통 렌트차들 블로그와는 다르게 사고 없으셨죠? 하고는 그냥 주고 왔습니다~^^ 감사합니다!',
#   '카카오맵',
#   5,
#   '18.08.03.',
#   '무지개렌트카'],
#  ['minsingg',
#   '뱅기타러 반납하며 정신없으니 주유비 추가 청구. 무슨 돈 긁는 기계같음....',
#   '카카오맵',
#   1,
#   '18.05.07.',
#   '무지개렌트카'],
#  ['루니',
#   '대여, 반납 과정은 신속하고 불만 없습니다. 대여받은 차가 좀 오래돼서 그런지 항상 시동을 두번씩 걸어야 했네요^^;; 그리고 네비가 너무 심하게 안좋아서 그냥 폰네비 쓰는게 좋았어요. 대여하러 가는 셔틀에는 트렁크에 짐을 넣을 수 있었는데 공항 갈때는 들고 타야 했습니다. 왜 그러는지는 의문,,',
#   '카카오맵',
#   2,
#   '18.04.30.',
#   '무지개렌트카'],
#  ['균',
#   '진짜 별하나도주기아깝네요<br/>다시는여기서 차안빌립니다 청소도 대충한느낌팍팍드네요<br/>어쩔수없이 예약하고와서 탓네요  하여간 별한개도주기아깝습니다',
#   '카카오맵',
#   1,
#   '18.04.03.',
#   '무지개렌트카'],
#  ['재경',
#   '진짜 별로. 차 내부 청소 하나도 안되어 있어서 바닥에 흙먼지 그대로 다 있었어요. 냄새나는 차에 공항에서 먼 구석진 곳에 꼬불꼬불 좁은 골목길 지난 곳에 차 인수 반납장 있어요. 차 외관부터 내부까지 성하거나 깨끗한 곳이 없어요  얼마 더 내더라도 다른데 이용하세요. 최악입니다. 아, 렌트카인데 기름이 반도 안남은채로 있는 차도 처음이고, 차 인수시 직원안내도 없어서 직접 차를 찾아야했어요',
#   '카카오맵',
#   1,
#   '18.02.18.',
#   '무지개렌트카'],
#  ['김다정',
#   '왠민하면 넘어가려했는데  로그인까지해서 리뷰답니다. 직원들 불친절은 물론 아무런 안내 공지도 없이  트렁크 안 열린다며 알아서 짐 들고들어가 타게하고 끝까지 안하무인태도네요.  왜 평점이 1.5인지.. 다들  리뷰보고  렌트카 꼭 고르세요~!',
#   '카카오맵',
#   1,
#   '18.02.11.',
#   '무지개렌트카'],
#  ['dkenxooppㅅ',
#   '시작부터 불친절, 차량 외관에 기스 엄청나게 나있는 차, 금연차라고 떡하니 붙여 놨지만 시트에 담배빵자국 나있는 차, 앞유리 유막이 엄청껴서 비오는날 황천길로 안내해줄뻔한 차, 청소도 안되서 차 내부에 먹지도 않은 과자봉지가 보관되있는 차, 내부 유리에 기름인지 뭔지 껴서 안에서 거울도 제대로 보이지 않는차, 차량 유리도 제대로 작동 안되는차, 기분좋게 제주도 왔다가 처음시작부터 기분 버리게해준 차, 한개 차종에서 이런 여러가지가 발견되는 차를 빌려주는 업체인줄 몰랐네요 정말 별 하나도 아깝습니다',
#   '카카오맵',
#   1,
#   '17.12.24.',
#   '무지개렌트카'],
#  ['바티스투타',
#   '안 빌리는게 최고 절대 계약서 믿지 않고 사진 다 찍어 놓으세요 어떤 스크래치로 눈탱이를 당할지 모르니<br/>차가 없어 어쩔수 없이 차를 빌렸더니 세차는<br/>안되어있고 실외도 더러운데 실내는 유리창이랑 사이드미로에 때가 가득 의자도 찐득하게 뭐가 묻어 있고 뒷자리에 과자뷰스러기 머리카락 있어서 출고하는 애한테 세차가 된건가요? 차를 빌려줄려면 세차정도는 해줘야지요 했더니 원래 그럽니다 하고 그냥 가버림',
#   '카카오맵',
#   1,
#   '17.09.23.',
#   '무지개렌트카'],
#  ['나나', '계약서 꼼꼼히 보셔야합니다 진짜 비추천', '카카오맵', 1, '22.11.15.', '탐라렌트카'],
#  ['손병조',
#   '직원들 불친절하고 차받는 시스템도 엉망 사무실 화장실도 지저분하고. 결정적으로 k8을 랜트했는데 티고 모는것처럼 힘도 딸리고 엔진음 미션음 시끄럽고. 운행하는 내내 짜증 났다.<br/>셔틀버스도 패차할 차로 운행하고 기사는 말할거 없이 불친절했다.<br/>주위에 탐라랜트카 절대로 반대 할거다..<br/>이번 여행 다 좋았는데 랜트카가 옥에 티였다.',
#   '카카오맵',
#   1,
#   '22.08.06.',
#   '탐라렌트카'],
#  ['올리브쥬스',
#   '내 경험상으로만 평가하겠음. 저번주 렌트했는데 차는 아반떼 신형빌려서 그런지 아주 깨끗했고, 카운터 여직원분 불친절한거 전혀 모르겠음. 물어보면 이것저것 설명해주고 끝. 앞에 자동화 키오스크가 있기 때문에 대화할일이 많지않은데 뭐가 불친절하다는건지.. 별로 어렵지도 않은 이용방법만 한번 숙지하고 가면 직원들이랑 말섞을 일이 거의 없는데; 불친절하다고 하는 분들 본인들이 진상은 아니었나 잘 생각해보길 바람(다른 평가 제외 직원 불친절 하다고 하는 분들만!)',
#   '카카오맵',
#   5,
#   '22.08.02.',
#   '탐라렌트카'],
#  ['도리도리통통',
#   '7/26 카운터 언니 친절해요<br/>전기차 반납하는데 많이 타셨나고 웃으면서<br/>물어도 봐주시고<br/>공항이랑 가까워서 항상 여기 이용합니당<br/>다음에도 이용할게요!',
#   '카카오맵',
#   5,
#   '22.07.26.',
#   '탐라렌트카'],
#  ['전명희',
#   '별 하나도 아깝다.<br/>왼쪽앞자리 몸집 거대한 여직원 말투가 대단함.<br/>(기다리라고 아까 말했을텐데요~?) 이런식의 대화.<br/>퉁명스럽고 불친절함의 끝판왕.<br/>손님은 거들떠도 안보고<br/>직원들끼리만 서로 상냥하게 인사하는 업체.',
#   '카카오맵',
#   1,
#   '22.07.03.',
#   '탐라렌트카'],
#  ['살고',
#   '여직원 정말 불친절하고 네가지 없네요!!<br/>차는 심하게 노후되었고 사이드미러는 끼긱거리고 썬팅도 안되어있고 ㅡㅡ 공항 데려다 달라고 할 생각도 없었지만 신경1도 안쓰는 반납직원 기분나쁘고  어이없네요. 제주와서 이런 렌트카 첨이네요. 다신 이용 안합니다. 리뷰 보시는분들 잘 생각하시길.. 즐거운여행 잡칠수있어요',
#   '카카오맵',
#   1,
#   '22.07.03.',
#   '탐라렌트카'],
#  ['하하',
#   '차 잔뜩 기스난거 빌려주고 차도 잘 안나가고 미치는줄 <br/>완전 자차 보험 다 되있는데 기스 좀 났다고 10만원 내래 잔뜩 기스난거 빌려주고 차 하나로 몇백만원 버는 업체임 <br/>이렇게 기스 많이 난차 빌려주는곳은 처음봄 <br/>보험 왜있어  탐라 연결된 제주패스 앱도 문제 이런 불량한 업체 소개하고',
#   '카카오맵',
#   1,
#   '22.06.18.',
#   '탐라렌트카'],
#  ['진숙이',
#   '셔틀기사도 최악<br/>여직원도 불친절 <br/>기스수두룩한 차 빌려주고 조금 더 났다고 10마눤듣어가고 아주 난리다 최악',
#   '카카오맵',
#   1,
#   '22.06.18.',
#   '탐라렌트카'],
#  ['마도라스',
#   '최악임.<br/>다른차랑 옆면 살짝 긁힘.<br/>자차 보험으로 돈도 냈는데 블랙 박스 있는데 확인도 안하고 과실 100프로라고 10만원 뜯어감.',
#   '카카오맵',
#   1,
#   '22.06.17.',
#   '탐라렌트카'],
#  ['꿔바로우',
#   '1. 블박 추가금 줘도 설치못함 <br/>2. 차량 내부 청소 잘 안하는것 같았음(음료수 말라붙은거 안닦아져있었고 내가 반납하고 10분만에 딴사람이 그차 타고 감) <br/>3. 반납예정시간보다 30분 일찍 반납하라는걸 부탁하는게 아니라 그게 운전자의 센스라고 표현함(누구 맘대로 센스인지?) <br/>4. 대신 차량 반납시 깐깐하게 하지 않는건 좋았음 그래서 별점 1개 더 줌<br/>5. 다음번에 제주도 간다면 이 업체는 거르고 보겠음',
#   '카카오맵',
#   2,
#   '22.06.08.',
#   '탐라렌트카'],
#  ['희정',
#   '렌트해서 2번방전. 이런차 렌트하고 긴급출동비 고객에게 부담. 긴급출동비도 35000원씩이나 받음. 여행내내 렌터카때문에 시동 안 걸릴까봐 마음불편. 제주도 10번갔는데 이런적 처음. 별하나도 아까움.',
#   '카카오맵',
#   1,
#   '22.05.27.',
#   '탐라렌트카'],
#  ['마마파파', '공항이랑 가까운것 말고는 메리트 없음', '카카오맵', 3, '22.04.27.', '탐라렌트카'],
#  ['정혜승',
#   '이렇게 불친절한 렌터카는 처음봄. 직원들 모두 고객을 쳐다보지도않고, 대답도 느려터지고, 차리리 AI를 앉혀놓지. 특히 카운터에 앉아있는 여직원은 승질나게 불친절함!!!  이런 렌트카 직원들은 보다보다 처음봄!  시작부터 기분 꽝됨.   불친절x10,000=탐라렌트카!!!',
#   '카카오맵',
#   1,
#   '22.04.16.',
#   '탐라렌트카'],
#  ['박희준',
#   '6시 예약했는데 6시20분에 세차하고 자빠졌네요 그래놓고 사과도 없고 기름 조금 덜렁 넣어준다고ㅋㅋㅋㅋㅋ 직원 교육좀요',
#   '카카오맵',
#   1,
#   '22.04.14.',
#   '탐라렌트카'],
#  ['호랑이',
#   '더뉴레이 빌렸습니다. 준신차급 3만키로 정도된 차를 배정받았구요. 네비,후카,핸들열선,열선,6:4폴딩,스마트키 등등 거의 다들어간 풀옵션 차량이네요. 외관상태 좋구 큰 흠집없었습니다. 직원들 불친절하다는 말이 많았는대 비대면으로 차량 배정받고 반납도 기름칸 보시더니 3초만에 OK, 6년전 신혼여행때 이용하고 좋은기억이있어 또 빌려봤는대 괜찮네요. 저는 만족합니다.',
#   '카카오맵',
#   5,
#   '21.12.20.',
#   '탐라렌트카'],
#  ['선율이',
#   '카니발 11인승, 선팅 거의 안돼있음(왼팔 개뜨거움), abs경고등, 미끄럼방지 경고등 계속뜸ㅋㅋ 담부턴 안빌림 ㅅㄱ',
#   '카카오맵',
#   1,
#   '21.09.22.',
#   '탐라렌트카'],
#  ["kk's iPhone",
#   '타이어 공기압 경고 뜨고, 후방 등 전구하나 나갔고, 후진 등 하나 나갔고, 차량은 10만키로 노후 차량이였고, 차량 찾으러 갔을때 도와주시는 직원이 2명밖에 없어서 시간도 제법 걸렸는데 가격이 싸서 좋았어요.',
#   '카카오맵',
#   3,
#   '21.09.12.',
#   '탐라렌트카'],
#  ['나비효과',
#   '올해 5월 차량 빌렸는데<br/>후기 보고 걱정했지만 가격이 착해서 예약함<br/><br/>후기만큼은 아니지만 데스크 직원분은 시크?하셨고<br/><br/>차량 상태는 좋아서 만족했습니다^^',
#   '카카오맵',
#   4,
#   '21.09.07.',
#   '탐라렌트카'],
#  ['정',
#   '제주도 여행의 시작은 자동차 렌트 부터 해야 했기에 여러 업체를 고민하고 선택한 탐라렌트카.. 차 상태도 좋고 무엇보다 직원분들 친절함에 너무 기분이 좋았습니다.',
#   '카카오맵',
#   5,
#   '21.09.03.',
#   '탐라렌트카'],
#  ['김효진',
#   '제주도 매년 2번씩 가는데 ㅎㅎ 렌트카는 탐라렌트카죠 ㅎㅎ 눈에 탐라렌트카만 보입니다 ㅎㅎ',
#   '카카오맵',
#   5,
#   '21.09.03.',
#   '탐라렌트카'],
#  ['민디',
#   '전기차 예약하고 받으러 갓을때 충전카드 대여하실꺼냐만 물어봐서 안사고 신카로<br/>충전하려햇으나 시간이 촉박해서 못하고<br/>반납햇더니 갠찮다고 하고는 충전카드 대여값까지 지불해야한다고 9천원 요구 하는게 맞는건지 모르겟네요.<br/>전기차 대여 하실때 꼭 금액 문의 하세요',
#   '카카오맵',
#   2,
#   '21.08.22.',
#   '탐라렌트카'],
#  ['뭉',
#   '진짜 최악이고 모든 직원이 불친절합니다.. 대박임<br/>여행 망치고 싶지 않다면 제발 거르세요<br/>전기차 충전도어 불량인거 받았는데 상담사가 "당신같은 이유로 문의한 사람 많았다"고 하네요 ;;;<br/>기본적인 마인드가 우리가 불친절하고 차가 이상하면 니가 어쩔건데? 입니다 ㅎㅎ 비 다 맞아가며 긴급출동서비스 부르고 시간날리고 잊지못할 기억이 될 것 같습니다^^',
#   '카카오맵',
#   1,
#   '21.07.31.',
#   '탐라렌트카'],
#  ['미소지안',
#   'GV 80을 주말 이틀 렌트를 했습니다.  실내에는 먼지가 쌓여 있고 뒷자석 시트 밑에는  과자 부스러기가 그대로  있고 담당자는  청소가 되어 있지 않으면 대여가 안되는 말만 하고  전혀 앞뒤가 맞지 않는 렌터카 입니다. 여직원분도 불친절하고 가족 여행이라 짜증도 못내고 반납하고 집으로  복귀합니다.',
#   '카카오맵',
#   1,
#   '21.07.11.',
#   '탐라렌트카'],
#  ['미아공쥬',
#   '통화가 너무 어렵습니다.<br/>5번 걸면 1번 통화 가능.<br/>그리고 정말 사무실분들 불친절하네요.',
#   '카카오맵',
#   1,
#   '21.07.05.',
#   '탐라렌트카'],
#  ['굿',
#   '아니 어떻게 관광객을 상대로 빡빡하게 구는 건지... 10분 늦는다고 그렇게 기분나쁘게 말하시면 안되죠.. 저도 돈내고 쓰는 고객입니다.',
#   '카카오맵',
#   1,
#   '21.06.18.',
#   '탐라렌트카'],
#  ['따라다니지마라뒤진다',
#   '왠만해선 다 제주공항쪽에 렌트카 별로던데 감안하고 와도 직원분이 친절하게 응대해줘서 기억에 남네요~ 아무래도 호불호가 갈려서 아래와같은 글이 달리는듯하네요~ 저는 운좋게 아주 만족하고 갑니다~',
#   '카카오맵',
#   5,
#   '21.05.21.',
#   '탐라렌트카'],
#  ['울리쿠쿠기',
#   'bmw 430i 렌트 (7일)<br/>차량 상태 : 잔기스 있는 편, 주행 문제점은 없음, 뚜껑 잘 열림<br/>직원 친절도 : 특별히 친절하거나 불친절한 부분 없었음<br/>기타 : 반납 시 까탈스럽게 하지 않아서 편했음, 공항이랑 셔틀로 10분 내외임 (교통사정에 따라 다름)<br/>가격 : 최고임, 다른데서 아반떼 빌릴 가격에 bmw 430i빌림<br/>암튼 기분 좋게 잘 돌아다님',
#   '카카오맵',
#   5,
#   '21.05.01.',
#   '탐라렌트카'],
#  ['Ny',
#   '불친절하고 이용에 대한 정확안 안내가 없네요<br/>전기차 렌트하고 충전카드 18000원짜리 구매했는데 반납후 남은 연료 계산해서 정확하게 카드 잔액에서 얼마 차감했는지 잔액확인 시켜줘야 되는거 아닌가요? 반납 할때는 그냥 대여료를 3천원을 낸거라만 대충 설명하고 카드 회수해버리고 그럼 사용자가 정확히 충전카드 구매해서 얼마나 쓰고 남겼는지는 전혀 확인할수가 없네요. 불분명하길래 물어보니 데스크 여직원이 너무 불친절해서 다시 묻지도 못하고 그냥 나왔어요. 서비스 최악이고 이용금액 정확히 확인도 안시켜주고 최악의 업체네요.',
#   '카카오맵',
#   1,
#   '21.04.13.',
#   '탐라렌트카'],
#  ['비둘기',
#   '전화직원이 조금 불친절 합니다<br/><br/>차량관리는 대체적으로 좋은데 네비게이션 과속단속이 구버전이라 휴대폰 네비 꼭 사용하세요 구간단속 안알려줍니다',
#   '카카오맵',
#   3,
#   '21.03.26.',
#   '탐라렌트카'],
#  ['hun', '별한개도아깝다. 최악으로불친절함', '카카오맵', 1, '21.03.20.', '탐라렌트카'],
#  ['JJo',
#   '차량관리가 잘되어있어 강추해요!! 공항 바로 앞에 있어서 위치적으로 너무 편리해요!!',
#   '카카오맵',
#   5,
#   '21.03.05.',
#   '탐라렌트카'],
#  ['유지나',
#   '차 오래대고 더러움  멀미나서5분도 못함.<br/>교체요청했으나 직원들 상상이상으로  불친절하고 예의없음,  절대 이용안함<br/>다른회사 렌트하느라 2시간 손해봄',
# ...
#   '카카오맵',
#   3,
#   '21.04.19.',
#   '스타렌트카'],
#  ['바이든',
#   '네이버 댓글에 추천이 있어서 선택했는데 엉망이네요 카카오리뷰를 먼저볼껄..',
#   '카카오맵',
#   1,
#   '21.04.10.',
#   '스타렌트카'],
#  ['완써니',
#   '차량에 문제가 있다며 기다리라고 해서 예약 시간보다 1시간이 지나서 차량 인수함. <br/>여행지인 만큼 발이 묶여 시간이 너무 아까웠음. <br/>물론 금액 조정이나 다른 배상도 없었음.<br/>몇년간 잘 이용해 오던 곳인데 서비스가 점점 후퇴하는 듯하여 다음번에는 다른 곳을 이용할 예정임.',
#   '카카오맵',
#   1,
#   '21.04.03.',
#   '스타렌트카'],
#  ['TBG',
#   '이거 별로 신경 안쓸줄 알았는데 은근 신경쓰임. 차량 배정받고 나서야 알았는데 이럴줄은 몰랐다. 사전에 알려줬으면 안빌렸을거임. 공짜로 타는 차도 아닌데 이러면 상도덕에 어긋나는거 아님? 몇 대만 이런꼴인줄 알았더니 다 이렇게 해놨네 ㅋㅋㅋ',
#   '카카오맵',
#   1,
#   '21.03.28.',
#   '스타렌트카'],
#  ['프시케(Psyche)',
#   '공항에서 걸어갈수 있는 렌탈 업체라 꾸준히 이용해왔지만 이제 다신 이용 안할듯. 년식이 좀 된 스파크를 발렸는데.. 차량 하부에서 쇼바 끊어질듯한 소리가 계속남..ㅡㅡ;;; 그냥 앞으론 이용 안하려고요.',
#   '카카오맵',
#   1,
#   '21.03.11.',
#   '스타렌트카'],
#  ['jinho',
#   '참!......<br/>끌리면타라!!<br/>참.............<br/>이런업체는 고객을 호구로 생각하는<br/>그런느낌을 잊지못하겠네요<br/>최악입니다<br/>끌리면 너나타라 생각만하면 열받네<br/>최악 끔찍해',
#   '카카오맵',
#   1,
#   '21.02.25.',
#   '스타렌트카'],
#  ['찐',
#   '차량이용은 큰 불편없었음 일부 직원분들 서비스마인드교육이 필요할듯.. 가격도 인터넷과 전화상 요금이 다름~ 재이용 의향없음',
#   '카카오맵',
#   1,
#   '21.02.23.',
#   '스타렌트카'],
#  ['최원준', '이제여기안씀', '카카오맵', 1, '21.02.07.', '스타렌트카'],
#  ['HR',
#   '전에 이용했을때에는 예약 과정과 금액이 투명하다라고 느꼈는데 이제는 결제가 홈페이지에서 이루어 지지않고 전화로 예약 완료하는데 가격이 인터넷이랑 다름 2021 1월달의 별점은 2개',
#   '카카오맵',
#   2,
#   '21.01.26.',
#   '스타렌트카'],
#  ['박지연',
#   '매번 이용하던 곳이었는데<br/>환불 졸 안해줌<br/>2번의 독촉전화 했음에도 돈은 안 들어오고 시간은 한달 되어감',
#   '카카오맵',
#   1,
#   '21.01.08.',
#   '스타렌트카'],
#  ['ch', '택시타라 ㅋㅋㅋㅋㅋ', '카카오맵', 1, '20.12.14.', '스타렌트카'],
#  ['그렇군요', '제주도에서 이 정도면 괜찮은 편이에요.', '카카오맵', 5, '20.11.17.', '스타렌트카'],
#  ['friday', '마음에 안듭니다', '카카오맵', 1, '20.11.03.', '스타렌트카'],
#  ['장군맘',
#   '예전에 이용한 후 별다른 문제점이 없어서 다시 예약했는데 넘 후회가 되네요.<br/>아직 첫날이지만 창피해서 차를 갖고 다니기가 싫어요. 그리고 타이어는 보험이 안 되는데 완전 낡아서 불안하네요.<br/>공항 픽업장소에도 다른 렌트업체 두대 올 동안 한대와서 오래 기다렸습니다.<br/>기다리다보니 SK가 젤 자주 오네요.<br/>불륜남 회장이 싫어서 이용 안 하지만...',
#   '카카오맵',
#   1,
#   '20.10.25.',
#   '스타렌트카'],
#  ['봉이형', '최악', '카카오맵', 1, '20.10.21.', '스타렌트카'],
#  ['길동',
#   '2-3년 전 스타를 생각하고 렌트함. 도착해서 차 상태보니 최악 <br/>타이어 왼쪽 앞 꺼 제외 3개 모두 야마가 닳아서 직접 타보니 밀릴정도 ㅋ 육안으로도 위험해 보여서 말하니 알바인지 직원인지 어려보이는 분이 정비소에서 괜찮다고 했다는 말만 반복함. 불안한 마음으로 대여 했고 역시나 차는 밀렸고 얼라이멈트 문제인지 왼쪽 앞바퀴만 살아있어서 인지 오른쪽으로 계속 쏠려서 4일간 아주 피곤한 운전을 함^^ 걍 2-3만원  더 주더라도 다른 업체에서 안전한 차량 빌리는게 건강에 좋을듯^^ <br/>아 그리고 와이퍼도 잘 안닦임~ 비라도 왔으면 사고 났을듯',
#   '카카오맵',
#   1,
#   '20.10.20.',
#   '스타렌트카'],
#  ['냠냠',
#   '덜덜거리는 초 구형 아반떼60만원에 빌렸습니다. 외관에 뭔 기름 먼지가 꼈는지 그야말로 더러운차 받았고, 어이가 없고 가는길에 기름 넣고 자동세차  돌렸어요 그래도 안닦여ㅋ<br/>계좌이체로 예약 무조건 해야되고, 인수하면서 카드결제시 선입금 내역은 3주 걸린다고 안내하지만 실상은 먼저 달라고 연락하기 전까진 감감 무소식<br/>으레 알아서 해줬으려니 잊고 있다가 두달만에 연락하려니 낮에는 상담원 연결조차 안되고 환불에도 중간에 상담원들 내세워서 차일피일 미룹니다.<br/>게시판 글 올렸지만 지금은 홈페이지 업데이트 통해 다른사람들도 볼수 있었던 천태만상 컴플레인이 더이상 보이지 않군요. 부디 카카오 지도 이용하시는 분들은 이 업체만큼은 피하길 바라는 마음에 구구절절 남깁니다.<br/>블로그니 구글이니 검색해보니 환불 문제로 하루이틀 이러는 것도 아니고, 예약할 경우에도 네고를 해야하고, 심지어 차상태는 이걸 돈을 주고 빌려야 하나 싶은 어마어마한 곳입니다.<br/>어떤 업체인지 뉴스며 인스타며 찾아보니 직원에 대한 갑질은 고객이 아니라 사장이 하는듯 한데 근무 생각하시는 분들도 부디 똥자리는 잘 피하셔서 인생 낭비 안하시면 좋겠네요.',
#   '카카오맵',
#   1,
#   '20.10.16.',
#   '스타렌트카'],
#  ['세라노큰손',
#   '차에 스티커하며 차 겉에 상태하며;; 차량 인수받고 놀랫습니다 일부러 이름유명한곳에서 했는데 2017년형맞는지도 모르겟고  그냥 개실망<br/><br/>수정합니다. <br/>홈페이지에는 코로나 100-300원 적어놓고 예약전화와서 한다는말이 경차 스파크 기준 10만원이 말이됩니까 ㅋ <br/>차라리 홈페이지에 가격이라도 볼수잇게 하시던가요. 사람 놀리는것도아니고 이게뭡니까진짜<br/>전화 기다린다고 시간만 낭비햇네요<br/><br/>3번째 이용하고 나서 적는 후기입니다.',
#   '카카오맵',
#   1,
#   '20.10.09.',
#   '스타렌트카'],
#  ['은하수',
#   '차에 블루투스 없는게 말이되나요<br/>있는차량중에 있는걸로 준다는 것도 안되고 <br/>차에 있을지 없을지 아무도 모른다고 함 <br/>너무 어이업네요 다시는 이용 안함',
#   '카카오맵',
#   1,
#   '20.10.07.',
#   '스타렌트카'],
#  ['저엉말!',
#   '기본 20분 이상은 기다려요.<br/>먼저 카운터 대기가 5분은 걸리고, 카운터에서 처리후에 배차받기까지 기본 저정도 걸리네요.... 배차직원이 두명 정도밖에 없는 것 같은데 개선이 필요해 보여요.<br/>렌트카 빌리는데 30분 대기가 왠말.... 바로 배차되서 버스 내리자마자 바로 차 픽업 가능한곳도 많던데 너무 비교됩니다.<br/><br/>추가로 시스템이 어떻게 된 건진 모르겠지만 예약 전화할 때마다 차량이 있다고 했다가, 바로 다시 전화하면 없다고 했다가, 또 전화하면 있다고 했다가... 가격도 계속 바뀌고 하루나 몇시간걸러 전화하면 모르겠는데 짧은간격으로 전화해도 계속 바뀌네요. 예약전화할땐 잘되는데 다른문의 하려고 전화하면 연결도 절대 안되구요. 문의하려고 했다가 연결이 하루종일 안되서 결국 신규예약건으로 상담신청해서 전화받았어요. 예전엔 괜찮았는데 왜이렇게 된건지 ㅠㅠ',
#   '카카오맵',
#   1,
#   '20.10.05.',
#   '스타렌트카'],
#  ['김지은',
#   '저희 렌트카 업체 많이 이용해 봤는데 진짜 여기는 최악이네요 다시는 이용하고 싶지 않아요<br/>1.  차 앞 창문에 일단 앞이 잘 안 보일 정도의 얼룩이 있는 상태로 빌려주더라구요 지워지지도 않고요 <br/>2. 사이드 미러가 기름이 낀 것 처럼 잘 보이지도 않았어요 <br/>3. 비가 오는데 와이퍼가 제 기능을 못 해서 앞이 잘 보이지 않아서 운전 하는 데 큰 어려움이 있었습니다. <br/>4. 브레이크도 너무 밀려요 <br/>5. 그 외 차상태 너무 별로에요.(소음&amp;냄새) <br/><br/>다시는 이용 안 할 것 같아요 . 무슨 100원 이벤트도 다 거짓말이고요...',
#   '카카오맵',
#   1,
#   '20.09.26.',
#   '스타렌트카'],
#  ['쫌',
#   '예전에 좋은기억으로(차에 스티커가 맘에 안들었음에도 불구하고) 제주도 갈때마다 렌트했는데, 이번에 다시 렌트 예약할려니 예약걸어놓은지 3일만에 전화와서 사이트에서 나온 렌트비보다 더 많은 보험료를 내라하더군요. 게다가 현금입금이라니..이제 절대 이용안할렴니다. 전화서비스도 엉망..',
#   '카카오맵',
#   1,
#   '20.09.26.',
#   '스타렌트카'],
#  ['코리',
#   '별1개도 주기 싫은 렌트카 차가 고장났는데 서귀포에서 끌고 오라는 ○○○○ 렉카불러달라니깐10키로초과는 내돈 내야된다는 ○○○○들 2번째 빌렸을때도 경차빌렸는데 한겨율에 히터안됨 송풍나와서 차배꿔달라니깐 뗘 끌고 오라함 이런 ○○○○들',
#   '카카오맵',
#   1,
#   '20.09.22.',
#   '스타렌트카'],
#  ['ekim',
#   '최악의 렌트카. 경차 빌렸는데 조수석 문이 안닫긴 채로 출발할 뻔. 발견했으니 망정이지 아니었다면 목숨을 잃을 수도 있는 사고 날 뻔. 다른 차로 변경한다고 한시간 가량 질질 끌었는데 미안하다는 말 한마디도 없고 시간보상 물어보니 말돌리거나 안내데스크가서 말하라는 소리 들음 ㅋㅋ 스탭 몇분은 친절한데 머리 짧고 피부하얀 남직원 ○○○○. 얼탱 없음. 다신 이용안할예정.',
#   '카카오맵',
#   1,
#   '20.09.05.',
#   '스타렌트카'],
#  ['???',
#   '보험료 장사하는 렌트카 업체들 <br/><br/>비성수기땐 대여료도 저렴하고 보험료도 1-2만원 이였는데<br/><br/>성수기때 대여료 15만원 올려놓고 보험료 15만원이라고 함',
#   '카카오맵',
#   1,
#   '20.08.18.',
#   '스타렌트카'],
#  ['검',
#   '만족합니다!! 19년도 차라서 엄청 깨끗했고 시스템도 맘에들어요. 전에 너무 이상한데서 빌려서  더 좋아보였을지도^^',
#   '카카오맵',
#   4,
#   '20.08.16.',
#   '스타렌트카'],
#  ['노씨',
#   '차는 왜이렇게 상처가 많고...<br/>타이어 상태도 안좋고...<br/>스티커들은 대체 뭔가요...<br/>창피하고 두번은 이용하고싶지 않아요',
#   '카카오맵',
#   2,
#   '20.08.15.',
#   '스타렌트카'],
#  ['부쳐핸섬',
#   '차에 붙은 광고글 너무 큰게 아쉽긴 하지만 난 아직도 가성비는 스타렌트카라고 생각함. 이번이 세번째였는데 매번 만족했음',
#   '카카오맵',
#   5,
#   '20.08.05.',
#   '스타렌트카'],
#  ['peace',
#   '접근성, 가격, 서비스 좋지만 차가 안좋네요.<br/>브레이크 많이 밀리고 기어변속도 툭툭 걸리고ㅠ <br/>차량 상태가 안좋은듯 합니다.',
#   '카카오맵',
#   2,
#   '20.08.03.',
#   '스타렌트카'],
#  ['mus',
#   '1. 그렇게 오래된 차가 아님에도 불구하고 차 외부 기스, 차 안 냄새 엄청 나서 탈 때마다 토 하는 줄 알았음<br/>2. 차 빌릴때는 엄청 친절하더니 차 반납할 때 안내데스크 진짜 ^^.. 후<br/>3. 타이어 마모가 너무 심해서 비오는데 미끌려서 사고날뻔함; 이딴 차를 돈주고 빌려서 사고나면 어쩔려고 ㅋㅋㅋ <br/>4. 다른 리뷰에도 적혀있듯 내 돈 주고 차 광고 해야할 만큼 차에 엄청 큰 로고가..^^ <br/>다신 안 쓸 것 ㅂㅂ',
#   '카카오맵',
#   1,
#   '20.07.28.',
#   '스타렌트카'],
#  ['샤인머쓱캥',
#   '전 제주와서 세번정도 이용했는데<br/>항상 만족입니다~ 이번에 빌릴땐 가격이 좀 비싸졌나싶어 다른데할까도 고민하긴했는데... 이번에도 이용했는데 차가 19-20년형이여서인지 전 차량도 문제없이 깔끔했고 서비스도 큰 불편없었습니다! 다음에도 이용할겁니닷',
#   '카카오맵',
#   5,
#   '20.07.24.',
#   '스타렌트카'],
#  ['웅이뿡이',
#   '결론부터 말하자면 예전의 스타렌트카가 아님. <br/>다시는 이용 안할 생각임. <br/><br/>예약 시간이 지나서 도착했는데도 <br/>30분 기다려서 물 줄줄 흐르는 세차도 제대로 안된 상태로 차량 인도 받음. <br/>왜 이리 늦냐고 따지니 주력 차량이 아니라서 그렇다는 개소리 들음. <br/><br/>그러려니 하고 타고 가는데 좀 달리기 시작하니 <br/>타이어에서 탱크 굴러가는 소리 나기 시작. <br/>시간도 늦고 해서 일단 숙소 가서 전화하니 <br/>내일 가지고 오면 다른 차로 바꿔 준다고 함. <br/>다음날 모슬포에서 한시간 걸려서 바꾸러 갔지만 제대로 된 사과도 못받고 동급의 옵션 더 안좋은 다른 차량으로 교체 받음. <br/><br/>하지만 바꾼 차 상태도 엉망진창. <br/>비오는데 와이퍼를 쓰기 싫을 정도로 소음이 나고 무릎쪽에선 무슨 전선 같은게 정리도 안되서 너덜거림. <br/>어차피 다시는 이용 안할거고 여기 저기 리뷰 다 올릴 생각으로 다시 교체 안하고 타고 다님. <br/><br/>그리고 얼마나 직원 대우가 안좋은진 모르겠지만 <br/>직원 대부분이 대학생인가 싶을 정도로 어린 사람들 밖에 없음. <br/>그러니 차량 상태와 서비스가 최악일 수밖에. <br/><br/>예전의 친절하고 차량 상태 좋던 스타렌트카가 절대 아니니 이용하실분들은 참고 하세요.',
#   '카카오맵',
#   1,
#   '20.07.13.',
#   '스타렌트카'],
#  ['유상헌', '상태 안좋은 차를 싸게 렌트할 수 있는 촣은 회사.', '카카오맵', 1, '20.07.11.', '스타렌트카'],
#  ['무적트원스',
#   '왜 큰회사를 해야하는지 깨닫게 해주는 렌트카업체이네요 코로나때문에 못가는 상황닌데도 수수료 받는 곳이네요 숙박업체도 다 100프로 해줬는데 코로도 영향을 안미치는곳인가봐요 번창하시고 미리 후기 봤더라면 안했을꺼에요 고객 응대하는 직원도 참 노답이고 여자분들은 그래도 상냥하신데 남자분들은 서비스가 영 아니에요',
#   '카카오맵',
#   1,
#   '20.07.09.',
#   '스타렌트카'],
#  ['가장 행복한 시간',
#   '별 하나는 기본으로 체크해야 되어서 줌.<br/>서비스 최악임<br/>과거 제주 스타 렌트가에 대한 기억으로 이용했지만<br/>정말 최악임.<br/>카드 결제후 20일 넘게 환불 안되어서 몇번 통화후에 환불됨.<br/>오전 카운터 직원들 서비스 최악임.<br/>예약시 현금만 받음.<br/>카드로 변경시 카드 승인하고<br/>10일후에 입금해 준다는데 이것도 20일 넘어서 전화통화해야 입금해줌.<br/>일행들 모두 다신 이용 안한다고 함.<br/>손님 많아서 배부른거 같음.<br/>내돈 주고 나쁜기억 얻고 싶으면 이용하세요.',
#   '카카오맵',
#   1,
#   '20.07.06.',
#   '스타렌트카'],
#  ['아이휴',
#   '1. 차에 버스같이 너무 과대광고가 되어 있어서 내돈주고 내가 광고하러 다닌다.<br/><br/>2. 실외는 그냥 물을 뿌리는 시늉을 하는 듯 하나, 실내는 정말... 전에 사용자가 놓고간 쓰레기부터 흙발자국까지 그대로.. 실내소독은 제대로 하는가 모르겠다.<br/><br/>4. 블랙박스는 없다. <br/><br/>5. 끌리면 타라.. 그런데 끌리지가 않는다..',
#   '카카오맵',
#   1,
#   '20.06.27.',
#   '스타렌트카'],
#  ['ch.',
#   '안좋은 후기 쓰면 <br/>어떻게든 핑계 잡아서 삭제요청하나봐요.<br/><br/>매년 1~2번씩은 제주도를 방문하는 편이라<br/>몇 년 전에는 참 많이 이용했는데<br/>이제는 절대 여기 이용 안함.<br/>차라리 롯X렌터카 같은 대기업 회사를 이용하는게 좋아요. <br/>이유는 뭐 이용해보신 모든 분들이 아실테고...<br/>그러고보니 여기에선 그동안 현금영수증도 한번도 안해줬네.',
#   '카카오맵',
#   1,
#   '20.05.13.',
#   '스타렌트카'],
#  ['김성호',
#   '환불을 안해주네요.. 참.. <br/>고객센터에 전화하니 통화 안됨. <br/>미리 차단한건 아닌지 의심이갑니다.',
#   '카카오맵',
#   1,
#   '20.03.04.',
#   '스타렌트카'],
#  ['나무목',
#   '제주 최악의 렌트카<br/>처음 카드 결제 받다가 무조건 현금 결제(송금)<br/>그러면서 현장에서 카드결제 다시 가능하다고 함<br/>현장카드 결제 잊어 먹으면 무자료 수익되는 거<br/>현장 카드 결제 하고 현금 반환 시청하면 말로는<br/>몇일 안걸린다고 하고 2주가 넘어도 안돌려줌<br/><br/>전기렌트카 19년초 반납  시 충전게이지 별 상관없이<br/>반납 받고.. 전기차 자체 코드 있어 무료충전이었는데<br/>19년 말부터 전기차 충전 코드 만료되며<br/>반납  시  충전량이 생기고..<br/>충전코드 아직 갱신 안했다고 고객이 직접 돈내고 충전하고<br/>나중에 돌려주는 형식으로 변경..<br/><br/>18년부터 종종사용하며 2020년 1월에 최는 빌리며<br/>느끼는 것이지만 겉으로는 좋은 렌트카인척..<br/>실제는 완전..<br/><br/>제주도 렌트카  정확히 따져보면 다른 렌트카가 더 좋음',
#   '카카오맵',
#   1,
#   '20.02.17.',
#   '스타렌트카'],
#  ['ㅇㅇㅇ', '후기를 먼저 봤었다면 이용안했을텐데....', '카카오맵', 1, '20.01.30.', '스타렌트카'],
#  ['왘',
#   '제주도 갈때마다 이용하던곳이라 이번에도 했는데 대문짝만한 광고스티커 뭐예요;; 차에대한 설명 너무 없음 끌던차아니면 렌트하지말라 이건가.. 그래도 3개인건 빌리고난후 문의나 반납할때 괜찮았어서 드려요',
#   '카카오맵',
#   3,
#   '20.01.20.',
#   '스타렌트카'],
#  ['환각범', '왜 메이저 렌트카를 찾는지 알 것 같음!', '카카오맵', 3, '20.01.20.', '스타렌트카'],
#  ['백구',
#   '차 양옆에 대문짝만하게 광고스티커가 붙어있습니다.<br/>내돈주고 내가 광고를 해줌.<br/>예약 시 참고하세요.<br/>수년간 이용했는데 담부터 딴데 이용합니다.',
#   '카카오맵',
#   1,
#   '19.12.23.',
#   '스타렌트카'],
#  ['joseph',
#   '올해 3월만 해도 그냥저냥 이용할만 했는데 망조가 들었나.. 긴축중인지 사업장이 위태로워 보이네.. 슈퍼면책은 또 뭐야..ㅎㅎ 이상한 상품 만들지 말라고..;; SM6 렌트했는데 양옆에 버스광고판을 붙이고 다니는 느낌이다.. 적당히좀 하라고..;; 암튼 별거 아니었지만 vip창구도 없애고.. 직원들 일하는 태도도 그냥 저냥 찌들어보이고.. 차량상태도 쏘쏘.. 내돈내고 오히려 갑질당하는 느낌?ㅋㅋ 다음부터는 그냥 돈 더주고 롯데렌트카 이용할란다..',
#   '카카오맵',
#   1,
#   '19.12.17.',
#   '스타렌트카'],
#  ['theway',
#   '렌트한 차에서 너무 냄새나고 친절한것도 모르겠고 차 내외부 상태도 별로 .. 굳이 이용할 이유가 없는 렌트카',
#   '카카오맵',
#   1,
#   '19.11.01.',
#   '스타렌트카'],
#  ['JHJ',
#   '이제 스타렌트카는 안쓸려구요ㅠ 몇년간 제주도 올때마다<br/>스타렌트카 이용했었는데 이번에는 뭔가 직원들도 그렇고 분위기가 다 불친절하게 바뀐듯해요 데스크에 있는 여자분도 그렇고 스타렌트카 앞에 걸려있는 현수막 보고 좀.... 고객입장에서는 기분이 좀 안좋고 ;;   여기 평가보니까 대표가 직원들한테 함부로 했나봐요 ;; 암튼 예전같지않네요ㅠ',
#   '카카오맵',
#   1,
#   '19.10.28.',
#   '스타렌트카'],
#  ['식신',
#   '이용에는 큰 불편함은 없었으나,<br/><br/>반납후 연료의 가,감을 본인들스스로 측정하여<br/>메시지 상으로 입금을 요청하는건 상당히 불콰하였습니다.<br/><br/>반납시 현장에서 체크를 해서 요청을 하던지 하지.<br/><br/>연료가 부족하니 돈을 입금하라는  메시지는 참으로 불쾌했습니다.',
#   '카카오맵',
#   1,
#   '19.10.20.',
#   '스타렌트카'],
#  ['아이제이',
#   '5일간 불편함 없이 잘 사용했습니다.<br/>전기차 처음 운전해봤는데 괜찮네요.',
#   '카카오맵',
#   4,
#   '19.10.08.',
#   '스타렌트카'],
#  ['2hj',
#   '차는 상태도 좋고 괜찮았습니다<br/>다만 반납할때 여직원이 너무 불친절하네요',
#   '카카오맵',
#   3,
#   '19.10.04.',
#   '스타렌트카'],
#  ['근데',
#   '아니 전기차 충전 카드를 확인도 안하고 줍니까???? <br/>충전하려고 숙소 근처 충전기 갔더니 정지된 카드라고 나오고 렌터카 콜센터 전화했더니 충전기에 신용카드나 다른 카드 번호 누르라고 하는데 숙소 기계에는 그게 안된다고 ㅡㅡ 그랬더니 자기도 모른댜ㅡㅡ기껏 그래서 직접 충전기 콜센터 또 전화했더니 숙소 근처에는 신용카드 안되는 충전기밖에 안되고... 제일 가까운 신용카드 가능한 충전기는 밤10시에 기껏 갔더니 근처에 아무것도 없어ㅡㅡ 참나 한시간동안 덕분에 시간 잘 보냈습니다ㅡㅡ',
#   '카카오맵',
#   1,
#   '19.09.16.',
#   '스타렌트카'],
#  ['차', '불친절. 다시는 이용 안함.', '카카오맵', 1, '19.08.20.', '스타렌트카'],
#  ['Elin',
#   '불친절 끝판에 지내 어플 가입하라고 유도도 쩔고 이따위면 망해라 진짜 그지 같네..',
#   '카카오맵',
#   1,
#   '19.07.25.',
#   '스타렌트카'],
#  ['hzip20', '차 인도할때 직원이 불친절 합니다.', '카카오맵', 2, '19.07.05.', '스타렌트카'],
#  ['독립운동가', '', '카카오맵', 4, '19.07.02.', '스타렌트카'],
#  ['히쿠',
#   '요즘도타이어상태최악인가요? 몇번이용하다가 펑크나서내돈으로처리한뒤로는이용안합니다 그것도사진보내주니타이어찢어졌다고다바꿔야한다고했는데 알고보니단순펑크였네요  이용하시는분들꼭타이어보세요',
#   '카카오맵',
#   1,
#   '19.06.26.',
#   '스타렌트카'],
#  ['건우',
#   '여기 대표가 직원들 그렇게 괴롭힌다고 뉴스에 나오던데<br/>대표에게 갈굼당하는 직원이 세차하고 기름넣는 차가 과연 안전할지? 중고딩 양아치도 아니고',
#   '카카오맵',
#   1,
#   '19.05.03.',
#   '스타렌트카'],
#  ['young', '차 깨끗하고 서비스 만족스럽습니다^^', '카카오맵', 5, '19.03.18.', '스타렌트카'],
#  ['제주도민준', '차가 깔끔해서 매번 이용.', '카카오맵', 5, '19.02.23.', '스타렌트카'],
#  ['황혜빈',
#   '스타렌트카 안에서 특산품 판매하시는 여자분 진짜 너무하시네요 제주도 다신 안가고싶어졌어요 마지막날 렌트카 반납하고 버스기다리는 옆에 초콜릿이랑 파시길래 구매했는데 선물을 할거라 상하지는않는지 상품은 괜찮은지싶어서 여쭤봣더니 바로 “그럼 공항가서 사실래요?”라는 비아냥거리는 어투로 ....어떻게 판매하시는분이 그런말을 하실수있는지 소비자는 상품에 대한 정보를 모르니까 물어볼수있는 아닌가요 정말 이렇게 꼬이신분 처음봐서 제주도 이미지도 나빠지고 정말 놀랬습니다....진짜 어쩔수없이 사갔지만 멘탈 정말 튼튼하고 싸울준비 되신 분만 가야될거같아요 무서워죽겠네요<br/><br/>렌트카 직원분들은 친절하십니다',
#   '카카오맵',
#   1,
#   '19.01.03.',
#   '스타렌트카'],
#  ['김찬수', '상담원과 상담했는데 친절합니다.', '카카오맵', 5, '18.12.06.', '스타렌트카'],
#  ['김지훈',
#   '빵점이 없네.. 상담원 목소리나 응대태도보니 곧 장사접나요? 매출 못해도 상관없나봐요~^^',
#   '카카오맵',
#   1,
#   '18.12.05.',
#   '스타렌트카'],
#  ['야수의청춘',
#   '특가로 저렴한 가격에 편리하게 잘 이용했습니다~ 직원분들도 평이랑은 다르게 친절하셨어요~',
#   '카카오맵',
#   4,
#   '18.09.29.',
#   '스타렌트카'],
#  ['나',
#   '0점이 선택이 안되네요<br/>상담원 정말 불친절하네요<br/>일하기 싫으면 하지를 말던가<br/>왜이렇게 툴툴대는지',
#   '카카오맵',
#   1,
#   '18.07.31.',
#   '스타렌트카'],
#  ['아벨라',
#   '친절하진 않았지만 보통은 되었습니다<br/>시스템이 잘 갖춰져있는게 너무 좋더라구요<br/>돈 조금 더 보태서 깔끔하게 일처리하는게 낫겠더라구요<br/>굿 시스템 굿 굿입니다',
#   '카카오맵',
#   4,
#   '18.07.22.',
#   '스타렌트카'],
#  ['냠냠',
#   '홈페이지에서는 사전예약이 가능했던 차인데 예약확정은 전화로 하다보니 실제랑 차이가 있습니다. 결국 더 비싼 차로 예약 진행했고 차액은 소비자 부담이네요. 큰업체다보니 바쁘고 정신 없어서 서비스가 좀 거칠고 아쉬움이 생기는 부분도 있는듯하여 다음번엔 작은 곳에서 이용해보려고오.',
#   '카카오맵',
#   2,
#   '18.06.28.',
#   '스타렌트카'],
#  ['Daramgee',
#   '요즘은 깔끔하고 괜찮아요<br/>가격도 저렴해서 잘빌렸다는 생각이 드네요<br/>다음에 제주도 올때 또 이용할랍니다',
#   '카카오맵',
#   5,
#   '17.12.31.',
#   '스타렌트카'],
#  ['최만행',
#   '편리함을 제공하는곳<br/>토산품도 제주공항보다  아주저렴한곳~~~',
#   '카카오맵',
#   5,
#   '17.11.27.',
#   '스타렌트카'],
#  ['유빈아빠',
#   '두번째 이용하는데 차는 관리 잘 되있는데 반납할때 애들 있으면 위험하다. 차고지에 차 있으면 길에서 짐 빼야되데 짐 다 빼기도 전에 뒤차 들어오고 애 어디 안가나 봐야되고 멘탈 털림. 애들 크기 전까지는 반납 대기실 따로 갖춘데 이용할거다. 가격 인터넷 비교 쫌만 해보면 다 비슷하다. 여기가 젤 싸요 이건 아님. 장점은 규모가 크니까 아가랑 카시트가 파견 나와 있어서 편함',
#   '카카오맵',
#   2,
#   '17.11.09.',
#   '스타렌트카'],
#  ['Gilbert Kim',
#   'feb.17<br/>dec.15<br/>제주여1-01. 렌트카?<br/>제주도 여행에서 제일 많이 보이는?',
#   '카카오맵',
#   4,
#   '17.02.17.',
#   '스타렌트카'],
#  ['보야보야보',
#   '소셜커머스랑 브랜드렌트카랑 가격비교시 자차완전보험했을때 제일 저렴했음<br/>공항순환셔틀이 자주 있어 편함<br/>반납시 반납기름보다 많으면 반납기름 뺀만큼 환불해줌<br/>유일한 단점은 스타렌트카 스티커가 이곳저곳 붙어있어 부끄러울수있으나 돌아다니다보면 이곳저곳에서 스타렌트카 스티커를 붙인 동족을 쉽게 볼수있어 그나마 위안이됨',
#   '카카오맵',
#   4,
#   '16.11.07.',
#   '스타렌트카'],
#  ['mememe',
#   '여행 잘 마치고 차도 문제없이 잘 사용하고 반납하려고 차량에 기본 탑재된 내비로 차량반납안내 누르고 달렸더니 엄한 곳에 도착했네요.. <br/><br/>최신 네비 옵션 추가안내 예약시에 강조를 해주면 좋았을텐데 최끔 아쉬움긴하네 <br/><br/>어차피 요즘 내비 휴대폰 앱으로 보고 다니니까 그런거 신경안쓰시는 분들은 넘기시고 예약하실 분은 참고하시길염:b',
#   '카카오맵',
#   1,
#   '23.01.04.',
#   '제주현대렌트카'],
#  ['맛있으면 우는 고양이',
#   '예약시간에 차가 준비안되어있어서 예약시간 지나서 받음<br/>블랙박스 추가적으로 유료대여해야하고 1일 4000원이고 선착순임 그리고 셔틀버스 기사 불친절함 이 곳에서 빌릴 이유 없는 거 같아서 후기 씀',
#   '카카오맵',
#   1,
#   '22.12.29.',
#   '제주현대렌트카'],
#  ['Transport trip',
#   '대여 하루 전에 미리 면허 등록이랑 추가 서비스를 가입할 수 있어서 빨리 인수할 수 있습니다. 이번에도 환경을 위해 전기차로 대여했는데 제가 빌린 차만 그런지 모르겠으나 코나는 블루투스 연결이 안 되고 AUX 지원도 안 돼서 결국 이어폰을 이용하여 음악 듣고 전화를 이용했습니다. 내비게이션도 자동 확대가 안 된데다 업그레이드가 몇 년 동안 안 되어 있네요. 블랙박스는 대여료가 있습니다. 그나마 셔틀버스가 잘 다니는 것 같은데 저는 운이 좋은 건지 인수하러 갈 때와 반납하러 갈 때 기다리지 않고 바로 버스를 타고 이동했습니다. 지도상엔 공항이랑 가까워 보이는데, 길이 안 좋아서 공항까지 10분 넘게 걸리네요.',
#   '카카오맵',
#   5,
#   '22.12.18.',
#   '제주현대렌트카'],
#  ['언터처블',
#   '차량 내/외부 전부 세차된 상태로 인수받음. 렌트카치고 차량상태가 좋았고 옵션도 적당히 들어가있어서 편하게 운전했음(순정네비, 후방카메라, 스마트크루즈, 차선이탈방지 등) 무제한자차 상품으로 대여해서 연료량 체크만 받고 30초만에 반납완료. 셔틀버스 배차간격이 긴 것은 조금 아쉬웠음.',
#   '카카오맵',
#   5,
#   '22.12.15.',
#   '제주현대렌트카'],
#  ["(''''''j'''''')",
#   '소나타dn8은 빌리지 마세요.<br/>냄새나요.네비는 왜 그모양인지.<br/>실내 냄새와 네비는 여태까지 빌려본 렌트카중 최악.<br/>네비 진짜 쓰레기.<br/>처음 받았을때 앞유리 유막 양호하고 사이드미러 유막 양호하다고 생각했으나 비가 와서 와이퍼 작동 시켜보니  앞이 매직아이 처럼 보임. 눈물질질 흘릴정도로 피곤하고 앞이 안보임.  뒤유리는 첨부터 불투명 시트시 붙여놓은줄.<br/>장점 저렴함. <br/>온라인 체크인했음에도 렌트카 사무실에 가서 카오스로 다시 접수해야하는 번거로움이 있음.',
#   '카카오맵',
#   1,
#   '22.12.14.',
#   '제주현대렌트카'],
#  ['이시영',
#   '공항에서 좀 거리가 있긴한데 셔틀타서 문제는 되지않았어요<br/>차가 깨끗했고 차 뒤에 @@렌터카 이런 스티커 안붙어있어서 좋았어요<br/>직원들 응대도 괜찮고 친절한편이에요',
#   '카카오맵',
#   5,
#   '22.10.31.',
#   '제주현대렌트카'],
#  ['-',
#   '진짜 최후의 보루로 예약해야할업체... 안그래도 업체위치도 공항하고 꽤 먼데 셔틀은 달랑한대에 손님들은 계산없이 많이받아놓은탓에 같은타임에 한버스로도 못가고 질서정리도 못해가지고 버스기사는 쩔쩔매고 ... 셔틀을 한대 더 늘리던지 하세요 제발',
#   '카카오맵',
#   2,
#   '22.10.31.',
#   '제주현대렌트카'],
#  ['이중벙커',
#   '제주현대렌트카 강추합니다.<br/>첨에는 제네시스G80 렌트하고 싶어 몇개 업체 비교했는데, 후기들이랑 머 업체 정보들 확인하다 보니 도저히 못하겠더라구요, 그래서 수퍼자차 되는 기종이랑 업체 찾다보니, 돌하루팡에서 여기에 K8 가솔린 모델이 저렴하게 있어서 3박4일 동안 이용하게되었습니다.<br/>단독업체인데 규모가 있다보니 자체 정비소랑, 세차등 차량관리가 정말 잘 되어 있습니다. 실내 깨끗하고 냄새 안나고요, 단지 뒷유리창은 좀 잘 닦았으면 합니다.<br/>출발과  동시에 타이어 공기압경보 떠서 보니 나사가 박혀있었는데 다시 돌아가니 바로 조치취해줬습니다.<br/>대형차라 기본 엔트리지만 옵션들 충분했구요, 여행내내 편안하게 다녔습니다. 연비는 10킬로 조금 넘게 나와서 주유비 6.5만원 들었습니다. <br/>반납은 1초컷입니다. 차세워두고 내리니 바로 끝났답니다... 첨에 수퍼자차지만 1회 이후는 보험 미적용이라 동영상도 찍고 했는데 다 부질없는 짓이었네요..<br/>셔틀이 좀 작아서 가족들만 앉고 전 서서 갔어요.. 여튼 종합적으로 상당히 만족합니다. 총비용적으로 비슷한 최신 전기차랑 비교해도 비용적으로 비슷했지만 대형차량이 가져다 주는 이점에서 오히려 나은 선택이었습니다.<br/>다음에 다시 찾게 될거 같아요.',
#   '카카오맵',
#   5,
#   '22.09.27.',
#   '제주현대렌트카'],
#  ['사생활',
#   '밤늦게 남아있는 여자직원분 너무 친절하시고 감사했습니다 \U0001f979 다음에 또 이용할게요!!',
#   '카카오맵',
#   5,
#   '22.09.26.',
#   '제주현대렌트카'],
#  ['참트루',
#   '괜찮습니다. 차 상태도 좋았어요. 보험으로 사기치지도 않는 모습이고 크기도 커서 안심했습니다.<br/>지난번에 드림 렌트카에 사기를 당해서 주의했는데 굳이 걱정할 필요 없었습니다.',
#   '카카오맵',
#   5,
#   '22.09.18.',
#   '제주현대렌트카'],
#  ...]

# %%
column_name = ['WRITER','CONTENT','TYPE','SCORE','CREATED_AT','RENTAL_CAR_ID']
df2 = pd.DataFrame(
    all_review_data, columns = [column_name])
df2
# Out:
#          WRITER                                            CONTENT  TYPE  \
# 0        자연인 주나  쿱카를 통해 제주로렌트카 차량을 배정받았는데 차 정비를 안하시는 듯(2021.12....  카카오맵
# 1             .                                                     카카오맵
# 2          두아이맘  렌터카카 2000키로도 안된 새차.  주행감도 좋아 기분좋은 여행 했습니다. 다만 ...  카카오맵
# 3          JS쿠마  정말 제주도렌트카협동조합 덕분에 아주 기분좋은여행이었습니다~^^직원분들도 친절하시고...  카카오맵
# 4             석  정말 편리하고 싸게 잘 이용했습니다. 미리 등록해 놓으니 무인인수라 인수도 굉장히 ...  카카오맵
# ...         ...                                                ...   ...
# 2854          강                                       A MEN YO(__)  카카오맵
# 2855          .  셔틀버스 자리가 헷갈려서 8구역에 계시는 직원분께 여쭤봤는데 '제대로 알고 물어봐야...  카카오맵
# 2856      피트니스럽  불친절하고 이럴 거면 종합으로 왜 세워놨나 싶음. 일하는 남자 직원은 일하기 싫은 ...  카카오맵
# 2857  Александр                                                     카카오맵
# 2858       동그라미  다른 렌트카에 비해서는 쌉니다. 그런데 타시기 전에 사진 꼭 잘 찍어두세요. 출고전...  카카오맵
#
#      SCORE CREATED_AT  RENTAL_CAR_ID
# 0        1  21.12.31.     제주도렌트카협동조합
# 1        1  21.10.01.     제주도렌트카협동조합
# 2        5  20.08.15.     제주도렌트카협동조합
# 3        5  20.08.14.     제주도렌트카협동조합
# 4        5  20.05.28.     제주도렌트카협동조합
# ...    ...        ...            ...
# 2854     5  20.12.22.  제주국제공항 렌터카하우스
# 2855     1  20.01.21.  제주국제공항 렌터카하우스
# 2856     1  19.09.23.  제주국제공항 렌터카하우스
# 2857     5  19.08.08.  제주국제공항 렌터카하우스
# 2858     2  22.08.19.         타시오렌트카
#
# [2859 rows x 6 columns]

# %%
df2.shape
# Out:
# (2859, 6)

# %%
driver.close()
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15760\3193570824.py in <module>
# ----> 1 driver.close()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     559                 driver.close()
#     560         """
# --> 561         self.execute(Command.CLOSE)
#     562
#     563     def quit(self) -> None:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     442         response = self.command_executor.execute(driver_command, params)
#     443         if response:
# --> 444             self.error_handler.check_response(response)
#     445             response["value"] = self._unwrap_value(response.get("value", None))
#     446             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     247                 alert_text = value["alert"].get("text")
#     248             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249         raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00A1F243]
# 	(No symbol) [0x009A7FD1]
# 	(No symbol) [0x0089CF10]
# 	(No symbol) [0x008C1009]
# 	(No symbol) [0x008E8486]
# 	(No symbol) [0x008E530A]
# 	(No symbol) [0x008E4E48]
# 	(No symbol) [0x0087A1D7]
# 	(No symbol) [0x0087A87E]
# 	(No symbol) [0x0087ACBA]
# 	GetHandleVerifier [0x00CB9A22+2655074]
# 	GetHandleVerifier [0x00CACA24+2601828]
# 	GetHandleVerifier [0x00AC8C0A+619850]
# 	GetHandleVerifier [0x00AC7830+614768]
# 	(No symbol) [0x009B05FC]
# 	(No symbol) [0x0087A047]
# 	(No symbol) [0x00879A52]
# 	GetHandleVerifier [0x00CCB6DC+2727964]
# 	BaseThreadInitThunk [0x76AD00F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x775B7BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x775B7B8E+238]

# %%
df2.to_csv('kakao_review.csv',index=False, encoding='utf-8')
