# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import urllib.request
from bs4 import BeautifulSoup
import re
import urllib.request as ur

# %%
options = Options()
options.add_experimental_option("detach", True)
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)
# 가상의 크롬브라우저 실행

url = "https://map.kakao.com/"

driver.get(url)

time.sleep(3)
# <input type="text" id="search.keyword.query" name="q" class="query tf_keyword bg_on" 
# maxlength="100" autocomplete="off" accesskey="s">
driver.find_element(By.CLASS_NAME, "tf_keyword").send_keys("제주도렌트카\n")
time.sleep(3)

all_rent_page = []

soup=BeautifulSoup(driver.page_source,'html.parser')
tags = soup.find_all('li', {"class" : "PlaceItem clickArea"})
rent_company=re.compile('[<]a.*href[=]["](http.*[#]comment)["]\starget')
company_page=rent_company.findall(str(tags))
for page in company_page:
    all_rent_page.append(page)

# %%
all_rent_page
# Out:
# ['https://place.map.kakao.com/10620530#comment',
#  'https://place.map.kakao.com/24764839#comment',
#  'https://place.map.kakao.com/17940761#comment',
#  'https://place.map.kakao.com/1657351953#comment',
#  'https://place.map.kakao.com/400227802#comment',
#  'https://place.map.kakao.com/1762689033#comment',
#  'https://place.map.kakao.com/26887342#comment',
#  'https://place.map.kakao.com/25769803#comment',
#  'https://place.map.kakao.com/10804673#comment',
#  'https://place.map.kakao.com/452411056#comment',
#  'https://place.map.kakao.com/26521408#comment',
#  'https://place.map.kakao.com/777468585#comment',
#  'https://place.map.kakao.com/1257647888#comment',
#  'https://place.map.kakao.com/17673118#comment',
#  'https://place.map.kakao.com/18801206#comment']

# %%
all_rent_page[0]
# Out:
# 'https://place.map.kakao.com/10620530#comment'

# %%
url2 = all_rent_page[0]
driver.get(url2)

time.sleep(3)
soup=BeautifulSoup(driver.page_source,'html.parser')
soup
# Out:
# <html lang="ko"><head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <title>탐라렌트카 | 카카오맵</title>
# <meta content="탐라렌트카" property="og:title"/>
# <meta content="카카오맵" property="og:site_name"/>
# <meta content="제주특별자치도 제주시 공항로 5 (용담2동 1588-2)" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="http://map3.daum.net/staticmap/og?type=place&amp;srs=wcongnamul&amp;size=400x200&amp;m=383116%2C3365&amp;service=placeweb" property="og:image"/>
# <meta content="https://place.map.kakao.com/10620530" property="og:url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="탐라렌트카" name="twitter:title"/>
# <meta content="제주특별자치도 제주시 공항로 5 (용담2동 1588-2)" name="twitter:description"/>
# <meta content="http://map3.daum.net/staticmap/og?type=place&amp;srs=wcongnamul&amp;size=400x200&amp;m=383116%2C3365&amp;service=placeweb" name="twitter:image"/>
# ...

# %%
tags = soup.find_all('div', {"class" : "evaluation_review"})
tags
# Out:
# [<div class="evaluation_review">
#  <strong class="screen_out">후기 리스트</strong>
#  <ul class="list_evaluation">
#  <li class="" data-id="6556089" data-is-block="false" data-ismy="false" data-userid="s2ltst">
#  <a class="profile_info" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/1a7d2e13ef45bdca1570da48d576a4b9acd05fee?original" data-username="나나" href="javascript:void(0);">
#  <img alt="" class="thumb_g" height="48" onerror="this.style.display='none'" src="//t1.kakaocdn.net/thumb/C48x48.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Fprofile%2F1a7d2e13ef45bdca1570da48d576a4b9acd05fee%3Foriginal" width="48"/>
#  </a>
#  <div class="unit_info">
#  <em class="screen_out">작성자 : </em>
#  <a class="link_user" href="#none">나나</a>
#  <span class="bg_bar"></span>
#  <span class="txt_item">후기</span>
#  <span class="txt_desc">1</span>
#  <span class="txt_item">별점평균</span>
#  <span class="txt_desc">1.0</span>
#  <span class="bg_bar"></span>
# ...

# %%
rent_coment=re.compile('link_user.*#none["][>](.*)[<][/]a[>]\n')
coment_name=rent_coment.findall(str(tags))
coment_name
# Out:
# ['나나', '손병조', '올리브쥬스']

# %%
rent_date=re.compile('time_write["][>](.*)[<][/]span[>]')
coment_date=rent_date.findall(str(tags))
coment_date
# Out:
# ['2022.11.15.', '2022.08.06.', '2022.08.02.']

# %%
rent_score=re.compile('style[=]["]width[:](.*)[%][;]["][>][<][/]span[>]')
coment_score=rent_score.findall(str(tags))
coment_score
# Out:
# ['20', '20', '100']

# %%
rent_coment=re.compile('<span>(.*)[<][/]span[>]')
coment=rent_coment.findall(str(tags))
coment
# Out:
# ['계약서 꼼꼼히 보셔야합니다 진짜 비추천',
#  '직원들 불친절하고 차받는 시스템도 엉망 사무실 화장실도 지저분하고. 결정적으로 k8을 랜트했는데 티고 모는것처럼 힘도 딸리고 엔진음 미션음 시끄럽고. 운행하는 내내 짜증 났다.<br/>셔틀버스도 패차할 차로 운행하고 기사는 말할거 없이 불친절했다.<br/>주위에 탐라랜트카 절대로 반대 할거다..<br/>이번 여행 다 좋았는데 랜트카가 옥에 티였다.',
#  '내 경험상으로만 평가하겠음. 저번주 렌트했는데 차는 아반떼 신형빌려서 그런지 아주 깨끗했고, 카운터 여직원분 불친절한거 전혀 모르겠음. 물어보면 이것저것 설명해주고 끝. 앞에 자동화 키오스크가 있기 때문에 대화할일이 많지않은데 뭐가 불친절하다는건지.. 별로 어렵지도 않은 이용방법만 한번 숙지하고 가면 직원들이랑 말섞을 일이 거의 없는데; 불친절하다고 하는 분들 본인들이 진상은 아니었나 잘 생각해보길 바람(다른 평가 제외 직원 불친절 하다고 하는 분들만!)']

# %%
driver.close()
