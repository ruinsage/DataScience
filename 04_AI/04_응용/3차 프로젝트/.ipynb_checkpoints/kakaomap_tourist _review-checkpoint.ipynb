# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import urllib.request
from bs4 import BeautifulSoup
import re
import urllib.request as ur
import pandas as pd

# %%
kakao = pd.read_csv('관광지end.csv',encoding = 'cp949')
kakao.head()
# Out:
#                                             관련 태그 전체                콘텐츠 ID  \
# 0                                              문화유적지  CNTS_000000000022884
# 1                              포구,해변,문화유적지,맑음,아주 어려움  CNTS_000000000020982
# 2                                     포구,일몰,해변,걷기,커플  CNTS_000000000021407
# 3  반려동물,반려동물동반,반려동물전용,예스펫존,반려동물동반입장,혼저옵서개,강아지,반려동...  CNTS_200000000014290
# 4                            휴식/힐링,맑음,자연경관,공용주차장,화장실  CNTS_000000000019458
#
#        콘텐츠명                          주소                        도로명주소  \
# 0  만벵듸 공동장지    제주특별자치도 제주시 한림읍 금악리 2754   제주특별자치도 제주시 한림읍 갯거리오름길 114
# 1      신양포구        제주특별자치도 서귀포시 성산읍 고성리         제주특별자치도 서귀포시 성산읍 고성리
# 2     옹포리포구         제주특별자치도 제주시 한림읍 옹포리          제주특별자치도 제주시 한림읍 옹포리
# 3     삐삐그루밍  제주특별자치도 서귀포시 대정읍 구억리 835-1  제주특별자치도 서귀포시 대정읍 중산간서로 2269
# 4       옹포천     제주특별자치도 제주시 한림읍 옹포리 404      제주특별자치도 제주시 한림읍 한림로 563
#
#                                          태그  \
# 0                 문화유적지,자연경관,문화관광,역사유적,어트랙션
# 1                  포구,해변,문화유적지,맑음,자연경관,역사유적
# 2                       포구,일몰,해변,걷기,커플,자연경관
# 3  반려동물,반려동물동반입장,반려동물공간_기타,애견미용실,애견유치원,애견호텔
# 4                             휴식/힐링,맑음,자연경관
#
#                                       간단소개         위도          경도   우편번호 전화번호  \
# 0  한림지서 예비검속 희생자 유족들이 61구의 시신을 수습하여 안장한 묘역  33.372234  126.295900  63021   --
# 1                성산일충봉과 섭지코지가 한눈에 보이는 신양포구  33.444576  126.909500    NaN   --
# 2      제주올레 14코스에 위치한 일몰이 아름다우며 항아리를 닮은 포구  33.400580  126.255325    NaN   --
# 3        삐삐그루밍은 제주 영어교육도시 내에 위치한 반려견 놀이터다.  33.280630  126.286213    NaN  NaN
# 4                                서부지역의 상수원  33.407660  126.257420  63012   --
#
#    썸네일 이미지경로
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
name_list = kakao['콘텐츠명']
name_list
# Out:
# 0       만벵듸 공동장지
# 1           신양포구
# 2          옹포리포구
# 3          삐삐그루밍
# 4            옹포천
#           ...
# 1030     제주에코승마장
# 1031        엉알해안
# 1032         송악산
# 1033         비자림
# 1034       물뫼힐링팜
# Name: 콘텐츠명, Length: 1035, dtype: object

# %%
all_name = []
for i in name_list:
    all_name.append(i)
len(all_name)
# Out:
# 1035

# %%
base_options = Options()
base_options.add_experimental_option("detach", True)
base_service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=base_service, options=base_options)
# 가상의 크롬브라우저 실행

# %%
url = "https://map.kakao.com/"

all_page = []

for name in all_name:
    restorant_name = '제주도 ' + name
    driver.get(url)
    time.sleep(1)
    driver.find_element(By.CLASS_NAME, "tf_keyword").send_keys(restorant_name)
    time.sleep(1)
    driver.find_element(By.XPATH, '//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)
    time.sleep(1)

    # 1페이지
    soup1=BeautifulSoup(driver.page_source,'html.parser')
    tags1 = soup1.find_all('li', {"class" : "PlaceItem"})
    location_company=re.compile('[<]a.*href[=]["](https.*place.*#comment)["]\starget')
    company_page=location_company.findall(str(tags1))
    if len(company_page) >= 1:
        print(company_page[0])
        all_page.append(company_page[0])
    else:
        company_page = ['정보없음']
        print(company_page[0])
        all_page.append(company_page[0])
# Out:
# https://place.map.kakao.com/1212658116#comment
# https://place.map.kakao.com/7980017#comment
# https://place.map.kakao.com/13723607#comment
# https://place.map.kakao.com/468448037#comment
# https://place.map.kakao.com/25728624#comment
# https://place.map.kakao.com/1763197176#comment
# https://place.map.kakao.com/763641480#comment
# https://place.map.kakao.com/1264588511#comment
# https://place.map.kakao.com/27049080#comment
# 정보없음
# https://place.map.kakao.com/40622413#comment
# https://place.map.kakao.com/13723641#comment
# https://place.map.kakao.com/8034134#comment
# https://place.map.kakao.com/1858329827#comment
# https://place.map.kakao.com/13723624#comment
# https://place.map.kakao.com/25450213#comment
# https://place.map.kakao.com/1756539039#comment
# https://place.map.kakao.com/17811623#comment
# https://place.map.kakao.com/1679065853#comment
# https://place.map.kakao.com/1746893521#comment
# https://place.map.kakao.com/7894206#comment
# https://place.map.kakao.com/1649727732#comment
# https://place.map.kakao.com/12736194#comment
# 정보없음
# https://place.map.kakao.com/8513650#comment
# https://place.map.kakao.com/7915927#comment
# https://place.map.kakao.com/10356367#comment
# https://place.map.kakao.com/25224758#comment
# 정보없음
# https://place.map.kakao.com/25190845#comment
# https://place.map.kakao.com/8212572#comment
# https://place.map.kakao.com/12561125#comment
# https://place.map.kakao.com/10442378#comment
# 정보없음
# 정보없음
# https://place.map.kakao.com/7822217#comment
# https://place.map.kakao.com/1729023455#comment
# https://place.map.kakao.com/51635726#comment
# https://place.map.kakao.com/1322848311#comment
# https://place.map.kakao.com/131787039#comment
# 정보없음
# https://place.map.kakao.com/625512156#comment
# https://place.map.kakao.com/770561720#comment
# https://place.map.kakao.com/74254170#comment
# https://place.map.kakao.com/1832447276#comment
# https://place.map.kakao.com/21656625#comment
# https://place.map.kakao.com/956522271#comment
# https://place.map.kakao.com/357983849#comment
# https://place.map.kakao.com/27418655#comment
# https://place.map.kakao.com/23972934#comment
# https://place.map.kakao.com/13723442#comment
# https://place.map.kakao.com/1249437757#comment
# https://place.map.kakao.com/21500494#comment
# https://place.map.kakao.com/8640631#comment
# 정보없음
# https://place.map.kakao.com/12528563#comment
# 정보없음
# https://place.map.kakao.com/11141566#comment
# https://place.map.kakao.com/522689899#comment
# https://place.map.kakao.com/7937029#comment
# https://place.map.kakao.com/1152324213#comment
# https://place.map.kakao.com/13723882#comment
# https://place.map.kakao.com/11017083#comment
# https://place.map.kakao.com/264598647#comment
# https://place.map.kakao.com/13725881#comment
# https://place.map.kakao.com/1697108052#comment
# https://place.map.kakao.com/8197075#comment
# https://place.map.kakao.com/1264782617#comment
# https://place.map.kakao.com/17382437#comment
# https://place.map.kakao.com/26823680#comment
# https://place.map.kakao.com/8115207#comment
# 정보없음
# https://place.map.kakao.com/7911973#comment
# https://place.map.kakao.com/27598301#comment
# https://place.map.kakao.com/8121610#comment
# https://place.map.kakao.com/21348535#comment
# https://place.map.kakao.com/25047260#comment
# https://place.map.kakao.com/25023085#comment
# https://place.map.kakao.com/8236791#comment
# https://place.map.kakao.com/25204904#comment
# https://place.map.kakao.com/11273772#comment
# https://place.map.kakao.com/25431012#comment
# https://place.map.kakao.com/10793668#comment
# https://place.map.kakao.com/10941032#comment
# https://place.map.kakao.com/18151396#comment
# https://place.map.kakao.com/19712514#comment
# https://place.map.kakao.com/26980153#comment
# https://place.map.kakao.com/21500227#comment
# https://place.map.kakao.com/8025182#comment
# https://place.map.kakao.com/26319779#comment
# https://place.map.kakao.com/1060814722#comment
# https://place.map.kakao.com/27581976#comment
# https://place.map.kakao.com/25274725#comment
# https://place.map.kakao.com/8194588#comment
# https://place.map.kakao.com/736608622#comment
# https://place.map.kakao.com/12354187#comment
# https://place.map.kakao.com/7863269#comment
# https://place.map.kakao.com/11540370#comment
# https://place.map.kakao.com/215604458#comment
# https://place.map.kakao.com/8232047#comment
# https://place.map.kakao.com/13095815#comment
# https://place.map.kakao.com/8100102#comment
# https://place.map.kakao.com/24946711#comment
# https://place.map.kakao.com/20056455#comment
# https://place.map.kakao.com/7956367#comment
# https://place.map.kakao.com/7912085#comment
# https://place.map.kakao.com/21656625#comment

# %%
all_page
# Out:
# ['https://place.map.kakao.com/1212658116#comment',
#  'https://place.map.kakao.com/7980017#comment',
#  'https://place.map.kakao.com/13723607#comment',
#  'https://place.map.kakao.com/468448037#comment',
#  'https://place.map.kakao.com/25728624#comment',
#  'https://place.map.kakao.com/1763197176#comment',
#  'https://place.map.kakao.com/763641480#comment',
#  'https://place.map.kakao.com/1264588511#comment',
#  'https://place.map.kakao.com/27049080#comment',
#  '정보없음',
#  'https://place.map.kakao.com/40622413#comment',
#  'https://place.map.kakao.com/13723641#comment',
#  'https://place.map.kakao.com/8034134#comment',
#  'https://place.map.kakao.com/1858329827#comment',
#  'https://place.map.kakao.com/13723624#comment',
#  'https://place.map.kakao.com/25450213#comment',
#  'https://place.map.kakao.com/1756539039#comment',
#  'https://place.map.kakao.com/17811623#comment',
#  'https://place.map.kakao.com/1679065853#comment',
#  'https://place.map.kakao.com/1746893521#comment',
#  'https://place.map.kakao.com/7894206#comment',
#  'https://place.map.kakao.com/1649727732#comment',
#  'https://place.map.kakao.com/12736194#comment',
#  '정보없음',
#  'https://place.map.kakao.com/8513650#comment',
#  'https://place.map.kakao.com/7915927#comment',
#  'https://place.map.kakao.com/10356367#comment',
#  'https://place.map.kakao.com/25224758#comment',
#  '정보없음',
#  'https://place.map.kakao.com/25190845#comment',
#  'https://place.map.kakao.com/8212572#comment',
#  'https://place.map.kakao.com/12561125#comment',
#  'https://place.map.kakao.com/10442378#comment',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/7822217#comment',
#  'https://place.map.kakao.com/1729023455#comment',
#  'https://place.map.kakao.com/51635726#comment',
#  'https://place.map.kakao.com/1322848311#comment',
#  'https://place.map.kakao.com/131787039#comment',
#  '정보없음',
#  'https://place.map.kakao.com/625512156#comment',
#  'https://place.map.kakao.com/770561720#comment',
#  'https://place.map.kakao.com/74254170#comment',
#  'https://place.map.kakao.com/1832447276#comment',
#  'https://place.map.kakao.com/21656625#comment',
#  'https://place.map.kakao.com/956522271#comment',
#  'https://place.map.kakao.com/357983849#comment',
#  'https://place.map.kakao.com/27418655#comment',
#  'https://place.map.kakao.com/23972934#comment',
#  'https://place.map.kakao.com/13723442#comment',
#  'https://place.map.kakao.com/1249437757#comment',
#  'https://place.map.kakao.com/21500494#comment',
#  'https://place.map.kakao.com/8640631#comment',
#  '정보없음',
#  'https://place.map.kakao.com/12528563#comment',
#  '정보없음',
#  'https://place.map.kakao.com/11141566#comment',
#  'https://place.map.kakao.com/522689899#comment',
#  'https://place.map.kakao.com/7937029#comment',
#  'https://place.map.kakao.com/1152324213#comment',
#  'https://place.map.kakao.com/13723882#comment',
#  'https://place.map.kakao.com/11017083#comment',
#  'https://place.map.kakao.com/264598647#comment',
#  'https://place.map.kakao.com/13725881#comment',
#  'https://place.map.kakao.com/1697108052#comment',
#  'https://place.map.kakao.com/8197075#comment',
#  'https://place.map.kakao.com/1264782617#comment',
#  'https://place.map.kakao.com/17382437#comment',
#  'https://place.map.kakao.com/26823680#comment',
#  'https://place.map.kakao.com/8115207#comment',
#  '정보없음',
#  'https://place.map.kakao.com/7911973#comment',
#  'https://place.map.kakao.com/27598301#comment',
#  'https://place.map.kakao.com/1011773473#comment',
#  'https://place.map.kakao.com/13725748#comment',
#  'https://place.map.kakao.com/27147755#comment',
#  'https://place.map.kakao.com/763067363#comment',
#  'https://place.map.kakao.com/1267769906#comment',
#  '정보없음',
#  'https://place.map.kakao.com/23641912#comment',
#  'https://place.map.kakao.com/10799984#comment',
#  'https://place.map.kakao.com/12705876#comment',
#  'https://place.map.kakao.com/13725737#comment',
#  'https://place.map.kakao.com/1759167347#comment',
#  'https://place.map.kakao.com/608888753#comment',
#  'https://place.map.kakao.com/17581736#comment',
#  'https://place.map.kakao.com/7966574#comment',
#  'https://place.map.kakao.com/8068195#comment',
#  'https://place.map.kakao.com/11260133#comment',
#  'https://place.map.kakao.com/20196627#comment',
#  'https://place.map.kakao.com/23972751#comment',
#  'https://place.map.kakao.com/11079026#comment',
#  '정보없음',
#  'https://place.map.kakao.com/114443358#comment',
#  'https://place.map.kakao.com/12736207#comment',
#  'https://place.map.kakao.com/25288503#comment',
#  '정보없음',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/1815334541#comment',
#  'https://place.map.kakao.com/461964394#comment',
#  'https://place.map.kakao.com/7877823#comment',
#  'https://place.map.kakao.com/18577520#comment',
#  'https://place.map.kakao.com/10177694#comment',
#  'https://place.map.kakao.com/12501222#comment',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/1276987776#comment',
#  'https://place.map.kakao.com/184#comment',
#  'https://place.map.kakao.com/7849255#comment',
#  '정보없음',
#  'https://place.map.kakao.com/416053296#comment',
#  'https://place.map.kakao.com/1536472821#comment',
#  'https://place.map.kakao.com/13723502#comment',
#  'https://place.map.kakao.com/13723853#comment',
#  '정보없음',
#  'https://place.map.kakao.com/8214370#comment',
#  '정보없음',
#  'https://place.map.kakao.com/13723442#comment',
#  'https://place.map.kakao.com/25335651#comment',
#  'https://place.map.kakao.com/13723853#comment',
#  '정보없음',
#  'https://place.map.kakao.com/27055539#comment',
#  'https://place.map.kakao.com/7834107#comment',
#  'https://place.map.kakao.com/15437263#comment',
#  'https://place.map.kakao.com/8066752#comment',
#  'https://place.map.kakao.com/10566814#comment',
#  'https://place.map.kakao.com/10566814#comment',
#  'https://place.map.kakao.com/12889950#comment',
#  'https://place.map.kakao.com/8490981#comment',
#  'https://place.map.kakao.com/10471809#comment',
#  'https://place.map.kakao.com/8035989#comment',
#  'https://place.map.kakao.com/11289720#comment',
#  'https://place.map.kakao.com/26864928#comment',
#  'https://place.map.kakao.com/12736208#comment',
#  'https://place.map.kakao.com/7964847#comment',
#  'https://place.map.kakao.com/8121453#comment',
#  '정보없음',
#  'https://place.map.kakao.com/10798266#comment',
#  'https://place.map.kakao.com/8224820#comment',
#  'https://place.map.kakao.com/10686012#comment',
#  'https://place.map.kakao.com/7878638#comment',
#  'https://place.map.kakao.com/39399880#comment',
#  'https://place.map.kakao.com/423502796#comment',
#  'https://place.map.kakao.com/228305623#comment',
#  'https://place.map.kakao.com/7958576#comment',
#  'https://place.map.kakao.com/12979413#comment',
#  'https://place.map.kakao.com/8418668#comment',
#  'https://place.map.kakao.com/10118902#comment',
#  'https://place.map.kakao.com/25229887#comment',
#  'https://place.map.kakao.com/22018448#comment',
#  'https://place.map.kakao.com/19386662#comment',
#  'https://place.map.kakao.com/7996060#comment',
#  'https://place.map.kakao.com/581695647#comment',
#  '정보없음',
#  'https://place.map.kakao.com/13723518#comment',
#  'https://place.map.kakao.com/8022571#comment',
#  'https://place.map.kakao.com/7860041#comment',
#  'https://place.map.kakao.com/11274593#comment',
#  'https://place.map.kakao.com/131201176#comment',
#  'https://place.map.kakao.com/11250683#comment',
#  'https://place.map.kakao.com/10328747#comment',
#  'https://place.map.kakao.com/13725869#comment',
#  'https://place.map.kakao.com/12705877#comment',
#  'https://place.map.kakao.com/8130507#comment',
#  'https://place.map.kakao.com/32321858#comment',
#  'https://place.map.kakao.com/17809535#comment',
#  'https://place.map.kakao.com/8510185#comment',
#  'https://place.map.kakao.com/27383717#comment',
#  'https://place.map.kakao.com/7828483#comment',
#  'https://place.map.kakao.com/1542160051#comment',
#  'https://place.map.kakao.com/8128672#comment',
#  'https://place.map.kakao.com/1173444143#comment',
#  'https://place.map.kakao.com/25382966#comment',
#  'https://place.map.kakao.com/27452357#comment',
#  'https://place.map.kakao.com/10165834#comment',
#  'https://place.map.kakao.com/10289213#comment',
#  'https://place.map.kakao.com/7944019#comment',
#  'https://place.map.kakao.com/25354927#comment',
#  'https://place.map.kakao.com/25712589#comment',
#  'https://place.map.kakao.com/7962202#comment',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/25240627#comment',
#  '정보없음',
#  'https://place.map.kakao.com/9937633#comment',
#  'https://place.map.kakao.com/7910482#comment',
#  'https://place.map.kakao.com/354372483#comment',
#  'https://place.map.kakao.com/852041742#comment',
#  'https://place.map.kakao.com/8018193#comment',
#  'https://place.map.kakao.com/8316764#comment',
#  'https://place.map.kakao.com/8577985#comment',
#  'https://place.map.kakao.com/7919832#comment',
#  'https://place.map.kakao.com/8386141#comment',
#  'https://place.map.kakao.com/10787327#comment',
#  'https://place.map.kakao.com/237503897#comment',
#  'https://place.map.kakao.com/8060962#comment',
#  'https://place.map.kakao.com/26120527#comment',
#  '정보없음',
#  'https://place.map.kakao.com/10328462#comment',
#  'https://place.map.kakao.com/22018448#comment',
#  'https://place.map.kakao.com/10977931#comment',
#  'https://place.map.kakao.com/10915804#comment',
#  'https://place.map.kakao.com/17788818#comment',
#  'https://place.map.kakao.com/13723492#comment',
#  'https://place.map.kakao.com/723896010#comment',
#  'https://place.map.kakao.com/24021334#comment',
#  'https://place.map.kakao.com/24860542#comment',
#  'https://place.map.kakao.com/8659345#comment',
#  'https://place.map.kakao.com/25237382#comment',
#  'https://place.map.kakao.com/8205022#comment',
#  'https://place.map.kakao.com/10426263#comment',
#  'https://place.map.kakao.com/10769042#comment',
#  'https://place.map.kakao.com/1468156660#comment',
#  'https://place.map.kakao.com/8148451#comment',
#  'https://place.map.kakao.com/10145930#comment',
#  'https://place.map.kakao.com/8638077#comment',
#  'https://place.map.kakao.com/10795473#comment',
#  'https://place.map.kakao.com/25478412#comment',
#  'https://place.map.kakao.com/753975467#comment',
#  'https://place.map.kakao.com/265774663#comment',
#  'https://place.map.kakao.com/8588538#comment',
#  'https://place.map.kakao.com/26575409#comment',
#  'https://place.map.kakao.com/1788535582#comment',
#  'https://place.map.kakao.com/25985380#comment',
#  'https://place.map.kakao.com/376263485#comment',
#  'https://place.map.kakao.com/1417303758#comment',
#  'https://place.map.kakao.com/25686110#comment',
#  'https://place.map.kakao.com/644158565#comment',
#  'https://place.map.kakao.com/326639#comment',
#  'https://place.map.kakao.com/618999865#comment',
#  'https://place.map.kakao.com/12501502#comment',
#  'https://place.map.kakao.com/26809802#comment',
#  '정보없음',
#  'https://place.map.kakao.com/1731144250#comment',
#  '정보없음',
#  'https://place.map.kakao.com/10129920#comment',
#  'https://place.map.kakao.com/797105773#comment',
#  'https://place.map.kakao.com/935744621#comment',
#  '정보없음',
#  'https://place.map.kakao.com/1740694192#comment',
#  'https://place.map.kakao.com/385071510#comment',
#  'https://place.map.kakao.com/1650973249#comment',
#  'https://place.map.kakao.com/17360222#comment',
#  '정보없음',
#  'https://place.map.kakao.com/10116894#comment',
#  'https://place.map.kakao.com/1826295011#comment',
#  'https://place.map.kakao.com/405890910#comment',
#  'https://place.map.kakao.com/1066016835#comment',
#  'https://place.map.kakao.com/24420227#comment',
#  '정보없음',
#  'https://place.map.kakao.com/12400128#comment',
#  'https://place.map.kakao.com/19157722#comment',
#  'https://place.map.kakao.com/1728777240#comment',
#  'https://place.map.kakao.com/7914554#comment',
#  'https://place.map.kakao.com/10882773#comment',
#  'https://place.map.kakao.com/8513147#comment',
#  'https://place.map.kakao.com/497053839#comment',
#  '정보없음',
#  'https://place.map.kakao.com/14794381#comment',
#  'https://place.map.kakao.com/7673211#comment',
#  'https://place.map.kakao.com/10801781#comment',
#  'https://place.map.kakao.com/8083623#comment',
#  'https://place.map.kakao.com/10706886#comment',
#  'https://place.map.kakao.com/11685945#comment',
#  'https://place.map.kakao.com/8064706#comment',
#  'https://place.map.kakao.com/1362294600#comment',
#  'https://place.map.kakao.com/22674204#comment',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/8183004#comment',
#  '정보없음',
#  'https://place.map.kakao.com/25382966#comment',
#  'https://place.map.kakao.com/13723476#comment',
#  'https://place.map.kakao.com/8168834#comment',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/12435114#comment',
#  'https://place.map.kakao.com/7916414#comment',
#  'https://place.map.kakao.com/11264776#comment',
#  'https://place.map.kakao.com/7876363#comment',
#  'https://place.map.kakao.com/9445759#comment',
#  'https://place.map.kakao.com/12706179#comment',
#  '정보없음',
#  'https://place.map.kakao.com/21811778#comment',
#  'https://place.map.kakao.com/11147485#comment',
#  'https://place.map.kakao.com/12889950#comment',
#  '정보없음',
#  'https://place.map.kakao.com/12736219#comment',
#  'https://place.map.kakao.com/7899031#comment',
#  'https://place.map.kakao.com/24372520#comment',
#  'https://place.map.kakao.com/1434952246#comment',
#  'https://place.map.kakao.com/1618613753#comment',
#  'https://place.map.kakao.com/7814429#comment',
#  'https://place.map.kakao.com/7849038#comment',
#  'https://place.map.kakao.com/1902052815#comment',
#  'https://place.map.kakao.com/24765993#comment',
#  'https://place.map.kakao.com/7868596#comment',
#  'https://place.map.kakao.com/12501790#comment',
#  'https://place.map.kakao.com/7865729#comment',
#  'https://place.map.kakao.com/9995571#comment',
#  'https://place.map.kakao.com/10352499#comment',
#  'https://place.map.kakao.com/619867634#comment',
#  'https://place.map.kakao.com/26616466#comment',
#  'https://place.map.kakao.com/1558998351#comment',
#  'https://place.map.kakao.com/237944347#comment',
#  'https://place.map.kakao.com/24120253#comment',
#  'https://place.map.kakao.com/8619771#comment',
#  'https://place.map.kakao.com/1255717436#comment',
#  'https://place.map.kakao.com/880279439#comment',
#  'https://place.map.kakao.com/8092604#comment',
#  'https://place.map.kakao.com/469138638#comment',
#  'https://place.map.kakao.com/10814650#comment',
#  '정보없음',
#  'https://place.map.kakao.com/1478852553#comment',
#  'https://place.map.kakao.com/8009713#comment',
#  'https://place.map.kakao.com/16261247#comment',
#  'https://place.map.kakao.com/8303282#comment',
#  '정보없음',
#  'https://place.map.kakao.com/13723757#comment',
#  'https://place.map.kakao.com/27168439#comment',
#  'https://place.map.kakao.com/1202044621#comment',
#  'https://place.map.kakao.com/26973747#comment',
#  'https://place.map.kakao.com/1388849862#comment',
#  'https://place.map.kakao.com/739107247#comment',
#  'https://place.map.kakao.com/27010336#comment',
#  'https://place.map.kakao.com/13723956#comment',
#  'https://place.map.kakao.com/370536784#comment',
#  'https://place.map.kakao.com/918268799#comment',
#  'https://place.map.kakao.com/27235768#comment',
#  'https://place.map.kakao.com/13725772#comment',
#  'https://place.map.kakao.com/9872734#comment',
#  'https://place.map.kakao.com/19175660#comment',
#  'https://place.map.kakao.com/1267549137#comment',
#  'https://place.map.kakao.com/675908857#comment',
#  'https://place.map.kakao.com/25335651#comment',
#  'https://place.map.kakao.com/27050803#comment',
#  'https://place.map.kakao.com/1548126710#comment',
#  'https://place.map.kakao.com/25199090#comment',
#  '정보없음',
#  'https://place.map.kakao.com/7956506#comment',
#  'https://place.map.kakao.com/10544645#comment',
#  'https://place.map.kakao.com/8477757#comment',
#  'https://place.map.kakao.com/25212873#comment',
#  'https://place.map.kakao.com/1335505471#comment',
#  'https://place.map.kakao.com/25036056#comment',
#  'https://place.map.kakao.com/13723665#comment',
#  'https://place.map.kakao.com/8016636#comment',
#  'https://place.map.kakao.com/796964695#comment',
#  'https://place.map.kakao.com/26647270#comment',
#  'https://place.map.kakao.com/8182461#comment',
#  'https://place.map.kakao.com/1105933662#comment',
#  'https://place.map.kakao.com/10812111#comment',
#  'https://place.map.kakao.com/1511661357#comment',
#  '정보없음',
#  'https://place.map.kakao.com/7916369#comment',
#  'https://place.map.kakao.com/25811890#comment',
#  'https://place.map.kakao.com/8316764#comment',
#  'https://place.map.kakao.com/17754603#comment',
#  'https://place.map.kakao.com/8676053#comment',
#  'https://place.map.kakao.com/1310137372#comment',
#  'https://place.map.kakao.com/8494697#comment',
#  'https://place.map.kakao.com/7953866#comment',
#  '정보없음',
#  'https://place.map.kakao.com/369704918#comment',
#  'https://place.map.kakao.com/26171941#comment',
#  'https://place.map.kakao.com/489015678#comment',
#  'https://place.map.kakao.com/486455035#comment',
#  'https://place.map.kakao.com/10647989#comment',
#  'https://place.map.kakao.com/1188644981#comment',
#  'https://place.map.kakao.com/24022946#comment',
#  'https://place.map.kakao.com/8191313#comment',
#  'https://place.map.kakao.com/12151918#comment',
#  'https://place.map.kakao.com/1213819298#comment',
#  'https://place.map.kakao.com/8129836#comment',
#  'https://place.map.kakao.com/13147665#comment',
#  'https://place.map.kakao.com/8033485#comment',
#  'https://place.map.kakao.com/24529884#comment',
#  'https://place.map.kakao.com/26917460#comment',
#  'https://place.map.kakao.com/26175298#comment',
#  'https://place.map.kakao.com/7910887#comment',
#  'https://place.map.kakao.com/7970247#comment',
#  'https://place.map.kakao.com/7924192#comment',
#  'https://place.map.kakao.com/12736264#comment',
#  'https://place.map.kakao.com/10987007#comment',
#  'https://place.map.kakao.com/7914554#comment',
#  'https://place.map.kakao.com/7862701#comment',
#  'https://place.map.kakao.com/2105646316#comment',
#  '정보없음',
#  'https://place.map.kakao.com/23275861#comment',
#  'https://place.map.kakao.com/10941032#comment',
#  'https://place.map.kakao.com/246058408#comment',
#  'https://place.map.kakao.com/13723890#comment',
#  'https://place.map.kakao.com/12705878#comment',
#  'https://place.map.kakao.com/1536381531#comment',
#  'https://place.map.kakao.com/12736220#comment',
#  'https://place.map.kakao.com/1258026507#comment',
#  'https://place.map.kakao.com/12501982#comment',
#  'https://place.map.kakao.com/1263853015#comment',
#  'https://place.map.kakao.com/10470582#comment',
#  'https://place.map.kakao.com/13723959#comment',
#  'https://place.map.kakao.com/13725892#comment',
#  'https://place.map.kakao.com/694068022#comment',
#  '정보없음',
#  'https://place.map.kakao.com/21204137#comment',
#  'https://place.map.kakao.com/7989355#comment',
#  'https://place.map.kakao.com/11209970#comment',
#  '정보없음',
#  'https://place.map.kakao.com/187348513#comment',
#  'https://place.map.kakao.com/13057106#comment',
#  'https://place.map.kakao.com/26916266#comment',
#  'https://place.map.kakao.com/25192955#comment',
#  'https://place.map.kakao.com/1309057733#comment',
#  'https://place.map.kakao.com/874961762#comment',
#  'https://place.map.kakao.com/8222476#comment',
#  'https://place.map.kakao.com/1661007896#comment',
#  'https://place.map.kakao.com/8086164#comment',
#  'https://place.map.kakao.com/285105927#comment',
#  'https://place.map.kakao.com/8019804#comment',
#  'https://place.map.kakao.com/1920808295#comment',
#  'https://place.map.kakao.com/17788831#comment',
#  'https://place.map.kakao.com/12728991#comment',
#  '정보없음',
#  'https://place.map.kakao.com/1864646661#comment',
#  'https://place.map.kakao.com/821864954#comment',
#  'https://place.map.kakao.com/10205578#comment',
#  'https://place.map.kakao.com/2139457773#comment',
#  'https://place.map.kakao.com/12890383#comment',
#  'https://place.map.kakao.com/8067359#comment',
#  'https://place.map.kakao.com/21204137#comment',
#  'https://place.map.kakao.com/12736195#comment',
#  'https://place.map.kakao.com/8004690#comment',
#  'https://place.map.kakao.com/9172408#comment',
#  'https://place.map.kakao.com/22651572#comment',
#  'https://place.map.kakao.com/13723493#comment',
#  'https://place.map.kakao.com/17600314#comment',
#  '정보없음',
#  'https://place.map.kakao.com/10795108#comment',
#  'https://place.map.kakao.com/26254227#comment',
#  'https://place.map.kakao.com/19157746#comment',
#  'https://place.map.kakao.com/26816311#comment',
#  'https://place.map.kakao.com/25491832#comment',
#  'https://place.map.kakao.com/600432495#comment',
#  'https://place.map.kakao.com/1337699238#comment',
#  'https://place.map.kakao.com/10620522#comment',
#  'https://place.map.kakao.com/8004025#comment',
#  'https://place.map.kakao.com/10303208#comment',
#  'https://place.map.kakao.com/19831486#comment',
#  'https://place.map.kakao.com/8132634#comment',
#  'https://place.map.kakao.com/21055845#comment',
#  'https://place.map.kakao.com/8624896#comment',
#  '정보없음',
#  'https://place.map.kakao.com/1811558348#comment',
#  'https://place.map.kakao.com/17582473#comment',
#  'https://place.map.kakao.com/11016572#comment',
#  '정보없음',
#  'https://place.map.kakao.com/236028555#comment',
#  'https://place.map.kakao.com/17809089#comment',
#  'https://place.map.kakao.com/7863117#comment',
#  'https://place.map.kakao.com/7860733#comment',
#  'https://place.map.kakao.com/20495355#comment',
#  'https://place.map.kakao.com/11264776#comment',
#  'https://place.map.kakao.com/8182461#comment',
#  'https://place.map.kakao.com/7951103#comment',
#  'https://place.map.kakao.com/14513668#comment',
#  'https://place.map.kakao.com/343721457#comment',
#  'https://place.map.kakao.com/13723638#comment',
#  '정보없음',
#  'https://place.map.kakao.com/8313570#comment',
#  'https://place.map.kakao.com/26974939#comment',
#  'https://place.map.kakao.com/1248004584#comment',
#  'https://place.map.kakao.com/8517825#comment',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/1734369391#comment',
#  'https://place.map.kakao.com/8175370#comment',
#  'https://place.map.kakao.com/1536554499#comment',
#  '정보없음',
#  'https://place.map.kakao.com/815138345#comment',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/12501795#comment',
#  'https://place.map.kakao.com/1897772289#comment',
#  'https://place.map.kakao.com/10808261#comment',
#  'https://place.map.kakao.com/327357092#comment',
#  'https://place.map.kakao.com/15270363#comment',
#  'https://place.map.kakao.com/941661099#comment',
#  'https://place.map.kakao.com/246072041#comment',
#  'https://place.map.kakao.com/19732375#comment',
#  'https://place.map.kakao.com/8903225#comment',
#  'https://place.map.kakao.com/2088939887#comment',
#  'https://place.map.kakao.com/11694885#comment',
#  '정보없음',
#  'https://place.map.kakao.com/11427241#comment',
#  'https://place.map.kakao.com/17630155#comment',
#  'https://place.map.kakao.com/1134213922#comment',
#  'https://place.map.kakao.com/13725882#comment',
#  'https://place.map.kakao.com/1659628316#comment',
#  'https://place.map.kakao.com/25206399#comment',
#  'https://place.map.kakao.com/12736193#comment',
#  'https://place.map.kakao.com/18502101#comment',
#  'https://place.map.kakao.com/17807528#comment',
#  '정보없음',
#  'https://place.map.kakao.com/15254007#comment',
#  'https://place.map.kakao.com/27182155#comment',
#  'https://place.map.kakao.com/8016361#comment',
#  'https://place.map.kakao.com/664283303#comment',
#  'https://place.map.kakao.com/25021723#comment',
#  'https://place.map.kakao.com/7934984#comment',
#  'https://place.map.kakao.com/8615054#comment',
#  'https://place.map.kakao.com/8312353#comment',
#  'https://place.map.kakao.com/879000770#comment',
#  'https://place.map.kakao.com/22924455#comment',
#  'https://place.map.kakao.com/13723868#comment',
#  '정보없음',
#  'https://place.map.kakao.com/26842880#comment',
#  'https://place.map.kakao.com/495587934#comment',
#  'https://place.map.kakao.com/7936290#comment',
#  'https://place.map.kakao.com/8318161#comment',
#  '정보없음',
#  'https://place.map.kakao.com/69791374#comment',
#  'https://place.map.kakao.com/422558471#comment',
#  'https://place.map.kakao.com/8001026#comment',
#  'https://place.map.kakao.com/1024533076#comment',
#  'https://place.map.kakao.com/11470870#comment',
#  'https://place.map.kakao.com/8553129#comment',
#  'https://place.map.kakao.com/7860400#comment',
#  'https://place.map.kakao.com/25865969#comment',
#  'https://place.map.kakao.com/1291843613#comment',
#  'https://place.map.kakao.com/11293995#comment',
#  'https://place.map.kakao.com/10590236#comment',
#  'https://place.map.kakao.com/820826091#comment',
#  'https://place.map.kakao.com/10417720#comment',
#  'https://place.map.kakao.com/502710690#comment',
#  'https://place.map.kakao.com/8214370#comment',
#  'https://place.map.kakao.com/1143443141#comment',
#  'https://place.map.kakao.com/8695575#comment',
#  'https://place.map.kakao.com/8136994#comment',
#  'https://place.map.kakao.com/247751530#comment',
#  'https://place.map.kakao.com/25262407#comment',
#  'https://place.map.kakao.com/12601986#comment',
#  'https://place.map.kakao.com/1758640947#comment',
#  'https://place.map.kakao.com/13725888#comment',
#  '정보없음',
#  'https://place.map.kakao.com/8192179#comment',
#  'https://place.map.kakao.com/639348916#comment',
#  'https://place.map.kakao.com/7832439#comment',
#  'https://place.map.kakao.com/7944328#comment',
#  'https://place.map.kakao.com/1419908012#comment',
#  'https://place.map.kakao.com/13625285#comment',
#  'https://place.map.kakao.com/11330871#comment',
#  'https://place.map.kakao.com/9440927#comment',
#  'https://place.map.kakao.com/11192276#comment',
#  'https://place.map.kakao.com/12887024#comment',
#  'https://place.map.kakao.com/8084305#comment',
#  'https://place.map.kakao.com/8591025#comment',
#  '정보없음',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/27223188#comment',
#  'https://place.map.kakao.com/12697401#comment',
#  'https://place.map.kakao.com/10251955#comment',
#  'https://place.map.kakao.com/852336814#comment',
#  'https://place.map.kakao.com/8066511#comment',
#  'https://place.map.kakao.com/17809080#comment',
#  'https://place.map.kakao.com/472921962#comment',
#  'https://place.map.kakao.com/8222825#comment',
#  '정보없음',
#  'https://place.map.kakao.com/17808879#comment',
#  'https://place.map.kakao.com/19157756#comment',
#  'https://place.map.kakao.com/19157724#comment',
#  '정보없음',
#  'https://place.map.kakao.com/305903187#comment',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/11405069#comment',
#  'https://place.map.kakao.com/7875147#comment',
#  'https://place.map.kakao.com/10503563#comment',
#  'https://place.map.kakao.com/7868485#comment',
#  'https://place.map.kakao.com/7938634#comment',
#  'https://place.map.kakao.com/23383045#comment',
#  'https://place.map.kakao.com/8277234#comment',
#  'https://place.map.kakao.com/1848413975#comment',
#  'https://place.map.kakao.com/25069292#comment',
#  '정보없음',
#  'https://place.map.kakao.com/17360759#comment',
#  '정보없음',
#  'https://place.map.kakao.com/93326428#comment',
#  'https://place.map.kakao.com/8069764#comment',
#  '정보없음',
#  'https://place.map.kakao.com/25284265#comment',
#  'https://place.map.kakao.com/1688963481#comment',
#  'https://place.map.kakao.com/9496187#comment',
#  'https://place.map.kakao.com/8640631#comment',
#  'https://place.map.kakao.com/17600314#comment',
#  'https://place.map.kakao.com/24126060#comment',
#  '정보없음',
#  'https://place.map.kakao.com/13723562#comment',
#  'https://place.map.kakao.com/25046666#comment',
#  '정보없음',
#  'https://place.map.kakao.com/1917059406#comment',
#  '정보없음',
#  'https://place.map.kakao.com/1272571027#comment',
#  'https://place.map.kakao.com/198029325#comment',
#  'https://place.map.kakao.com/26847782#comment',
#  'https://place.map.kakao.com/8057149#comment',
#  '정보없음',
#  'https://place.map.kakao.com/1498540367#comment',
#  'https://place.map.kakao.com/24022942#comment',
#  'https://place.map.kakao.com/663376648#comment',
#  'https://place.map.kakao.com/12269209#comment',
#  'https://place.map.kakao.com/13723673#comment',
#  'https://place.map.kakao.com/7896521#comment',
#  'https://place.map.kakao.com/8174706#comment',
#  'https://place.map.kakao.com/891104398#comment',
#  'https://place.map.kakao.com/8577982#comment',
#  'https://place.map.kakao.com/7873185#comment',
#  'https://place.map.kakao.com/710339793#comment',
#  'https://place.map.kakao.com/672529111#comment',
#  'https://place.map.kakao.com/1980040588#comment',
#  '정보없음',
#  'https://place.map.kakao.com/1191501173#comment',
#  'https://place.map.kakao.com/7904443#comment',
#  'https://place.map.kakao.com/12729538#comment',
#  'https://place.map.kakao.com/27583671#comment',
#  'https://place.map.kakao.com/8040871#comment',
#  'https://place.map.kakao.com/8096619#comment',
#  'https://place.map.kakao.com/10837593#comment',
#  'https://place.map.kakao.com/10839940#comment',
#  'https://place.map.kakao.com/18059921#comment',
#  'https://place.map.kakao.com/26865924#comment',
#  'https://place.map.kakao.com/10711279#comment',
#  '정보없음',
#  'https://place.map.kakao.com/303901411#comment',
#  'https://place.map.kakao.com/356142959#comment',
#  '정보없음',
#  'https://place.map.kakao.com/11320576#comment',
#  'https://place.map.kakao.com/1608663587#comment',
#  'https://place.map.kakao.com/20433579#comment',
#  'https://place.map.kakao.com/11426355#comment',
#  'https://place.map.kakao.com/603442453#comment',
#  'https://place.map.kakao.com/24726795#comment',
#  'https://place.map.kakao.com/23397740#comment',
#  'https://place.map.kakao.com/8067272#comment',
#  'https://place.map.kakao.com/27364022#comment',
#  'https://place.map.kakao.com/26796675#comment',
#  '정보없음',
#  'https://place.map.kakao.com/26875121#comment',
#  'https://place.map.kakao.com/1347437237#comment',
#  'https://place.map.kakao.com/775207906#comment',
#  'https://place.map.kakao.com/13723641#comment',
#  'https://place.map.kakao.com/271328524#comment',
#  'https://place.map.kakao.com/20056498#comment',
#  'https://place.map.kakao.com/25189061#comment',
#  'https://place.map.kakao.com/11255609#comment',
#  'https://place.map.kakao.com/7814429#comment',
#  'https://place.map.kakao.com/7923901#comment',
#  'https://place.map.kakao.com/11714326#comment',
#  'https://place.map.kakao.com/8313570#comment',
#  'https://place.map.kakao.com/7862701#comment',
#  'https://place.map.kakao.com/8316764#comment',
#  'https://place.map.kakao.com/7834786#comment',
#  'https://place.map.kakao.com/25303334#comment',
#  'https://place.map.kakao.com/10271092#comment',
#  'https://place.map.kakao.com/15106119#comment',
#  '정보없음',
#  'https://place.map.kakao.com/125774438#comment',
#  'https://place.map.kakao.com/8007088#comment',
#  '정보없음',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/760494494#comment',
#  'https://place.map.kakao.com/11158780#comment',
#  'https://place.map.kakao.com/12418108#comment',
#  'https://place.map.kakao.com/14819290#comment',
#  'https://place.map.kakao.com/369704918#comment',
#  'https://place.map.kakao.com/20673190#comment',
#  'https://place.map.kakao.com/18421685#comment',
#  'https://place.map.kakao.com/17600341#comment',
#  'https://place.map.kakao.com/11470870#comment',
#  'https://place.map.kakao.com/524112283#comment',
#  '정보없음',
#  'https://place.map.kakao.com/9381733#comment',
#  '정보없음',
#  'https://place.map.kakao.com/8173573#comment',
#  'https://place.map.kakao.com/17385210#comment',
#  'https://place.map.kakao.com/21500202#comment',
#  'https://place.map.kakao.com/1176884672#comment',
#  'https://place.map.kakao.com/26809802#comment',
#  'https://place.map.kakao.com/19304660#comment',
#  'https://place.map.kakao.com/11200482#comment',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/25342411#comment',
#  'https://place.map.kakao.com/17151058#comment',
#  'https://place.map.kakao.com/7834621#comment',
#  '정보없음',
#  'https://place.map.kakao.com/11023307#comment',
#  'https://place.map.kakao.com/12545248#comment',
#  '정보없음',
#  'https://place.map.kakao.com/2083466041#comment',
#  'https://place.map.kakao.com/13723963#comment',
#  'https://place.map.kakao.com/17382302#comment',
#  'https://place.map.kakao.com/1152843119#comment',
#  'https://place.map.kakao.com/1524439597#comment',
#  'https://place.map.kakao.com/17807455#comment',
#  'https://place.map.kakao.com/1174532899#comment',
#  'https://place.map.kakao.com/1862508988#comment',
#  'https://place.map.kakao.com/23972751#comment',
#  'https://place.map.kakao.com/10399499#comment',
#  '정보없음',
#  'https://place.map.kakao.com/7814429#comment',
#  'https://place.map.kakao.com/7832439#comment',
#  '정보없음',
#  'https://place.map.kakao.com/448661157#comment',
#  'https://place.map.kakao.com/1826826578#comment',
#  'https://place.map.kakao.com/13323388#comment',
#  'https://place.map.kakao.com/27600182#comment',
#  'https://place.map.kakao.com/8194422#comment',
#  'https://place.map.kakao.com/7814429#comment',
#  'https://place.map.kakao.com/1144766060#comment',
#  'https://place.map.kakao.com/12706219#comment',
#  'https://place.map.kakao.com/8107618#comment',
#  'https://place.map.kakao.com/10507362#comment',
#  'https://place.map.kakao.com/10880885#comment',
#  'https://place.map.kakao.com/25022153#comment',
#  'https://place.map.kakao.com/921324600#comment',
#  'https://place.map.kakao.com/25046666#comment',
#  'https://place.map.kakao.com/12979413#comment',
#  '정보없음',
#  'https://place.map.kakao.com/18647283#comment',
#  'https://place.map.kakao.com/18084841#comment',
#  'https://place.map.kakao.com/26904659#comment',
#  'https://place.map.kakao.com/7920396#comment',
#  'https://place.map.kakao.com/24066667#comment',
#  'https://place.map.kakao.com/24769484#comment',
#  'https://place.map.kakao.com/7970247#comment',
#  'https://place.map.kakao.com/194028176#comment',
#  'https://place.map.kakao.com/15385052#comment',
#  'https://place.map.kakao.com/27400232#comment',
#  'https://place.map.kakao.com/27253711#comment',
#  'https://place.map.kakao.com/11263573#comment',
#  'https://place.map.kakao.com/1833702535#comment',
#  'https://place.map.kakao.com/7912662#comment',
#  'https://place.map.kakao.com/747735691#comment',
#  'https://place.map.kakao.com/23326052#comment',
#  'https://place.map.kakao.com/7952882#comment',
#  'https://place.map.kakao.com/17574894#comment',
#  'https://place.map.kakao.com/966175465#comment',
#  'https://place.map.kakao.com/8169612#comment',
#  '정보없음',
#  'https://place.map.kakao.com/11053768#comment',
#  'https://place.map.kakao.com/7964223#comment',
#  'https://place.map.kakao.com/8069764#comment',
#  'https://place.map.kakao.com/1209632068#comment',
#  'https://place.map.kakao.com/10472331#comment',
#  'https://place.map.kakao.com/852041742#comment',
#  'https://place.map.kakao.com/15786539#comment',
#  'https://place.map.kakao.com/760387610#comment',
#  'https://place.map.kakao.com/1478954627#comment',
#  'https://place.map.kakao.com/27445592#comment',
#  'https://place.map.kakao.com/25610782#comment',
#  'https://place.map.kakao.com/8158565#comment',
#  'https://place.map.kakao.com/627270178#comment',
#  'https://place.map.kakao.com/10706382#comment',
#  'https://place.map.kakao.com/8085765#comment',
#  'https://place.map.kakao.com/11340501#comment',
#  'https://place.map.kakao.com/27314421#comment',
#  'https://place.map.kakao.com/17583646#comment',
#  'https://place.map.kakao.com/317349030#comment',
#  'https://place.map.kakao.com/8063566#comment',
#  'https://place.map.kakao.com/24894904#comment',
#  'https://place.map.kakao.com/25035440#comment',
#  '정보없음',
#  'https://place.map.kakao.com/7922396#comment',
#  '정보없음',
#  'https://place.map.kakao.com/1286381022#comment',
#  '정보없음',
#  'https://place.map.kakao.com/683714694#comment',
#  'https://place.map.kakao.com/25413887#comment',
#  'https://place.map.kakao.com/10303208#comment',
#  'https://place.map.kakao.com/12747497#comment',
#  'https://place.map.kakao.com/10329867#comment',
#  'https://place.map.kakao.com/23825742#comment',
#  'https://place.map.kakao.com/832267635#comment',
#  'https://place.map.kakao.com/25359013#comment',
#  'https://place.map.kakao.com/284694130#comment',
#  'https://place.map.kakao.com/7892575#comment',
#  'https://place.map.kakao.com/18355590#comment',
#  '정보없음',
#  'https://place.map.kakao.com/8385052#comment',
#  'https://place.map.kakao.com/26891646#comment',
#  'https://place.map.kakao.com/10773441#comment',
#  'https://place.map.kakao.com/26974762#comment',
#  'https://place.map.kakao.com/19157767#comment',
#  'https://place.map.kakao.com/775931695#comment',
#  'https://place.map.kakao.com/26809802#comment',
#  'https://place.map.kakao.com/1805672225#comment',
#  'https://place.map.kakao.com/9608595#comment',
#  'https://place.map.kakao.com/8671789#comment',
#  'https://place.map.kakao.com/8559375#comment',
#  'https://place.map.kakao.com/8177478#comment',
#  'https://place.map.kakao.com/19741107#comment',
#  'https://place.map.kakao.com/27424713#comment',
#  'https://place.map.kakao.com/26608807#comment',
#  'https://place.map.kakao.com/8095295#comment',
#  'https://place.map.kakao.com/1217580626#comment',
#  'https://place.map.kakao.com/10607235#comment',
#  'https://place.map.kakao.com/7973783#comment',
#  'https://place.map.kakao.com/819488120#comment',
#  'https://place.map.kakao.com/8428406#comment',
#  'https://place.map.kakao.com/21357958#comment',
#  'https://place.map.kakao.com/25280784#comment',
#  'https://place.map.kakao.com/12520358#comment',
#  'https://place.map.kakao.com/12729043#comment',
#  'https://place.map.kakao.com/17150892#comment',
#  'https://place.map.kakao.com/11889968#comment',
#  'https://place.map.kakao.com/688171010#comment',
#  'https://place.map.kakao.com/8520885#comment',
#  '정보없음',
#  'https://place.map.kakao.com/8375194#comment',
#  'https://place.map.kakao.com/27254363#comment',
#  'https://place.map.kakao.com/26142595#comment',
#  'https://place.map.kakao.com/26625268#comment',
#  'https://place.map.kakao.com/18574207#comment',
#  '정보없음',
#  'https://place.map.kakao.com/22761633#comment',
#  'https://place.map.kakao.com/14723339#comment',
#  'https://place.map.kakao.com/12747492#comment',
#  '정보없음',
#  'https://place.map.kakao.com/26631209#comment',
#  'https://place.map.kakao.com/7991509#comment',
#  'https://place.map.kakao.com/26388484#comment',
#  'https://place.map.kakao.com/11041974#comment',
#  '정보없음',
#  'https://place.map.kakao.com/12721319#comment',
#  '정보없음',
#  'https://place.map.kakao.com/7888119#comment',
#  'https://place.map.kakao.com/7854559#comment',
#  'https://place.map.kakao.com/10799994#comment',
#  'https://place.map.kakao.com/10387348#comment',
#  'https://place.map.kakao.com/26112410#comment',
#  'https://place.map.kakao.com/7938334#comment',
#  'https://place.map.kakao.com/1248845593#comment',
#  'https://place.map.kakao.com/27004813#comment',
#  'https://place.map.kakao.com/7964906#comment',
#  'https://place.map.kakao.com/11866230#comment',
#  'https://place.map.kakao.com/11309834#comment',
#  'https://place.map.kakao.com/11140788#comment',
#  '정보없음',
#  'https://place.map.kakao.com/2012644235#comment',
#  'https://place.map.kakao.com/26563993#comment',
#  'https://place.map.kakao.com/10837593#comment',
#  'https://place.map.kakao.com/11470870#comment',
#  'https://place.map.kakao.com/8171313#comment',
#  'https://place.map.kakao.com/21135119#comment',
#  'https://place.map.kakao.com/8267885#comment',
#  'https://place.map.kakao.com/11055702#comment',
#  'https://place.map.kakao.com/8067359#comment',
#  'https://place.map.kakao.com/13723499#comment',
#  'https://place.map.kakao.com/1870273669#comment',
#  '정보없음',
#  'https://place.map.kakao.com/27548967#comment',
#  'https://place.map.kakao.com/10803688#comment',
#  'https://place.map.kakao.com/8641860#comment',
#  'https://place.map.kakao.com/19265298#comment',
#  'https://place.map.kakao.com/8063566#comment',
#  'https://place.map.kakao.com/8161022#comment',
#  'https://place.map.kakao.com/9461977#comment',
#  '정보없음',
#  'https://place.map.kakao.com/559368803#comment',
#  'https://place.map.kakao.com/25461458#comment',
#  'https://place.map.kakao.com/25343635#comment',
#  'https://place.map.kakao.com/25206111#comment',
#  'https://place.map.kakao.com/581695647#comment',
#  'https://place.map.kakao.com/7952708#comment',
#  'https://place.map.kakao.com/852608524#comment',
#  'https://place.map.kakao.com/25294439#comment',
#  'https://place.map.kakao.com/25052666#comment',
#  'https://place.map.kakao.com/1575223685#comment',
#  'https://place.map.kakao.com/10805294#comment',
#  'https://place.map.kakao.com/63124696#comment',
#  'https://place.map.kakao.com/1214707005#comment',
#  'https://place.map.kakao.com/805903984#comment',
#  'https://place.map.kakao.com/27018526#comment',
#  'https://place.map.kakao.com/8523750#comment',
#  'https://place.map.kakao.com/15106119#comment',
#  'https://place.map.kakao.com/17580245#comment',
#  'https://place.map.kakao.com/11287687#comment',
#  'https://place.map.kakao.com/416160023#comment',
#  'https://place.map.kakao.com/10801589#comment',
#  'https://place.map.kakao.com/1714909766#comment',
#  'https://place.map.kakao.com/8433844#comment',
#  'https://place.map.kakao.com/336100555#comment',
#  'https://place.map.kakao.com/8448269#comment',
#  'https://place.map.kakao.com/12979413#comment',
#  'https://place.map.kakao.com/376678708#comment',
#  '정보없음',
#  'https://place.map.kakao.com/20303776#comment',
#  'https://place.map.kakao.com/8413659#comment',
#  'https://place.map.kakao.com/414336592#comment',
#  'https://place.map.kakao.com/10735984#comment',
#  'https://place.map.kakao.com/268385264#comment',
#  'https://place.map.kakao.com/26314642#comment',
#  'https://place.map.kakao.com/12528563#comment',
#  'https://place.map.kakao.com/236028555#comment',
#  'https://place.map.kakao.com/27168439#comment',
#  'https://place.map.kakao.com/1409692197#comment',
#  'https://place.map.kakao.com/8148451#comment',
#  'https://place.map.kakao.com/23705150#comment',
#  '정보없음',
#  'https://place.map.kakao.com/21777957#comment',
#  'https://place.map.kakao.com/8335690#comment',
#  'https://place.map.kakao.com/10375099#comment',
#  'https://place.map.kakao.com/13723603#comment',
#  'https://place.map.kakao.com/8045145#comment',
#  'https://place.map.kakao.com/21736745#comment',
#  'https://place.map.kakao.com/8552559#comment',
#  'https://place.map.kakao.com/8137083#comment',
#  'https://place.map.kakao.com/10808261#comment',
#  'https://place.map.kakao.com/8734404#comment',
#  'https://place.map.kakao.com/27012212#comment',
#  'https://place.map.kakao.com/17110921#comment',
#  'https://place.map.kakao.com/10599658#comment',
#  'https://place.map.kakao.com/26818966#comment',
#  'https://place.map.kakao.com/13570626#comment',
#  'https://place.map.kakao.com/11332661#comment',
#  'https://place.map.kakao.com/10574639#comment',
#  '정보없음',
#  'https://place.map.kakao.com/25036598#comment',
#  'https://place.map.kakao.com/25023085#comment',
#  'https://place.map.kakao.com/8511008#comment',
#  'https://place.map.kakao.com/25248461#comment',
#  'https://place.map.kakao.com/1868828759#comment',
#  'https://place.map.kakao.com/9941693#comment',
#  'https://place.map.kakao.com/8168650#comment',
#  'https://place.map.kakao.com/14521417#comment',
#  '정보없음',
#  'https://place.map.kakao.com/19388120#comment',
#  'https://place.map.kakao.com/1527411751#comment',
#  'https://place.map.kakao.com/23397740#comment',
#  'https://place.map.kakao.com/2083466041#comment',
#  'https://place.map.kakao.com/8037812#comment',
#  'https://place.map.kakao.com/8004227#comment',
#  'https://place.map.kakao.com/732571925#comment',
#  'https://place.map.kakao.com/19293737#comment',
#  'https://place.map.kakao.com/8067497#comment',
#  'https://place.map.kakao.com/1817788817#comment',
#  'https://place.map.kakao.com/19585161#comment',
#  'https://place.map.kakao.com/17600274#comment',
#  'https://place.map.kakao.com/8159415#comment',
#  'https://place.map.kakao.com/8008273#comment',
#  'https://place.map.kakao.com/1766125269#comment',
#  'https://place.map.kakao.com/1682547680#comment',
#  'https://place.map.kakao.com/19763694#comment',
#  'https://place.map.kakao.com/19306466#comment',
#  'https://place.map.kakao.com/11131088#comment',
#  'https://place.map.kakao.com/23231118#comment',
#  'https://place.map.kakao.com/13723680#comment',
#  'https://place.map.kakao.com/26564431#comment',
#  'https://place.map.kakao.com/8092604#comment',
#  'https://place.map.kakao.com/18539729#comment',
#  'https://place.map.kakao.com/1011859675#comment',
#  'https://place.map.kakao.com/25186462#comment',
#  'https://place.map.kakao.com/1563475113#comment',
#  'https://place.map.kakao.com/7918354#comment',
#  'https://place.map.kakao.com/942616668#comment',
#  'https://place.map.kakao.com/12137638#comment',
#  '정보없음',
#  'https://place.map.kakao.com/8386141#comment',
#  'https://place.map.kakao.com/7854561#comment',
#  '정보없음',
#  'https://place.map.kakao.com/23150855#comment',
#  'https://place.map.kakao.com/7962003#comment',
#  'https://place.map.kakao.com/17789153#comment',
#  '정보없음',
#  '정보없음',
#  'https://place.map.kakao.com/7940952#comment',
#  'https://place.map.kakao.com/9401924#comment',
#  'https://place.map.kakao.com/12501734#comment',
#  'https://place.map.kakao.com/25200772#comment',
#  'https://place.map.kakao.com/1447482986#comment',
#  'https://place.map.kakao.com/8064310#comment',
#  'https://place.map.kakao.com/13322621#comment',
#  'https://place.map.kakao.com/7813414#comment',
#  'https://place.map.kakao.com/19763694#comment',
#  'https://place.map.kakao.com/10706886#comment',
#  'https://place.map.kakao.com/25285071#comment',
#  'https://place.map.kakao.com/10626439#comment',
#  'https://place.map.kakao.com/7996060#comment',
#  'https://place.map.kakao.com/8379747#comment',
#  'https://place.map.kakao.com/14080134#comment',
#  'https://place.map.kakao.com/1143416302#comment',
#  'https://place.map.kakao.com/10717401#comment',
#  'https://place.map.kakao.com/26230962#comment',
#  'https://place.map.kakao.com/12501794#comment',
#  'https://place.map.kakao.com/7969402#comment',
#  'https://place.map.kakao.com/26523226#comment',
#  'https://place.map.kakao.com/26239274#comment',
#  ...]

# %%
len(all_page)
# Out:
# 1035

# %%
kakao['page'] = pd.Series(all_page)
kakao
# Out:
#                                                관련 태그 전체                콘텐츠 ID  \
# 0                                                 문화유적지  CNTS_000000000022884
# 1                                 포구,해변,문화유적지,맑음,아주 어려움  CNTS_000000000020982
# 2                                        포구,일몰,해변,걷기,커플  CNTS_000000000021407
# 3     반려동물,반려동물동반,반려동물전용,예스펫존,반려동물동반입장,혼저옵서개,강아지,반려동...  CNTS_200000000014290
# 4                               휴식/힐링,맑음,자연경관,공용주차장,화장실  CNTS_000000000019458
# ...                                                 ...                   ...
# 1030  부모,커플,혼자,친구,아이,맑음,액티비티,공용주차장,현금결제,카드결제,화장실,무료 ...  CONT_000000000500439
# 1031                           해변,경관/포토,커플,맑음,여름,아주 어려움  CONT_000000000500435
# 1032  일몰,일출,산,해변,걷기/등산,친구,커플,맑음,가을,자연경관,수국,공용주차장,화장실...  CONT_000000000500378
# 1033  걷기/등산,아이,흐림,여름,힐링,자연경관,어린이,수국,공용주차장,현금결제,카드결제,...  CONT_000000000500270
# 1034                                                수산리  CNTS_200000000010335
#
#           콘텐츠명                           주소  \
# 0     만벵듸 공동장지     제주특별자치도 제주시 한림읍 금악리 2754
# 1         신양포구         제주특별자치도 서귀포시 성산읍 고성리
# 2        옹포리포구          제주특별자치도 제주시 한림읍 옹포리
# 3        삐삐그루밍   제주특별자치도 서귀포시 대정읍 구억리 835-1
# 4          옹포천      제주특별자치도 제주시 한림읍 옹포리 404
# ...        ...                          ...
# 1030   제주에코승마장     제주특별자치도 제주시 조천읍 교래리 39-3
# 1031      엉알해안  제주특별자치도 제주시 한경면 고산리 3427-33
# 1032       송악산     제주특별자치도 서귀포시 대정읍 상모리 131
# 1033       비자림   제주특별자치도 제주시 구좌읍 평대리 3161-1
# 1034     물뫼힐링팜    제주특별자치도 제주시 애월읍 수산리 357-1
#
#                                        도로명주소  \
# 0                 제주특별자치도 제주시 한림읍 갯거리오름길 114
# 1                       제주특별자치도 서귀포시 성산읍 고성리
# 2                        제주특별자치도 제주시 한림읍 옹포리
# 3                제주특별자치도 서귀포시 대정읍 중산간서로 2269
# 4                    제주특별자치도 제주시 한림읍 한림로 563
# ...                                      ...
# 1030  제주특별자치도 제주시 조천읍 교래리 39-3번지 (비자림로 1065)
# 1031             제주특별자치도 제주시 한경면 고산리 3427-33
# 1032            제주특별자치도 서귀포시 대정읍 송악관광로 421-1
# 1033                 제주특별자치도 제주시 구좌읍 비자숲길 55
# 1034                  제주특별자치도 제주시 애월읍 예원로 51
#
#                                                태그  \
# 0                       문화유적지,자연경관,문화관광,역사유적,어트랙션
# 1                        포구,해변,문화유적지,맑음,자연경관,역사유적
# 2                             포구,일몰,해변,걷기,커플,자연경관
# 3        반려동물,반려동물동반입장,반려동물공간_기타,애견미용실,애견유치원,애견호텔
# 4                                   휴식/힐링,맑음,자연경관
# ...                                           ...
# 1030  부모,커플,혼자,친구,아이,맑음,액티비티,승마,체험,레저/체험,어린이,어트랙션
# 1031                  해변,경관/포토,커플,맑음,여름,자연경관,포토스팟
# 1032   일몰,일출,산,해변,걷기/등산,친구,커플,맑음,가을,자연경관,수국,무장애관광
# 1033          걷기/등산,아이,흐림,여름,힐링,자연경관,어린이,수국,무장애관광
# 1034                    수산리,자연경관,체험,마을관광,웰니스,어트랙션
#
#                                                    간단소개         위도  \
# 0               한림지서 예비검속 희생자 유족들이 61구의 시신을 수습하여 안장한 묘역  33.372234
# 1                             성산일충봉과 섭지코지가 한눈에 보이는 신양포구  33.444576
# 2                   제주올레 14코스에 위치한 일몰이 아름다우며 항아리를 닮은 포구  33.400580
# 3                     삐삐그루밍은 제주 영어교육도시 내에 위치한 반려견 놀이터다.  33.280630
# 4                                             서부지역의 상수원  33.407660
# ...                                                 ...        ...
# 1030  진정한 제주를 경험하길 원하신다면 제주에코승마파크\r\n친구, 연인, 가족, 남녀노...  33.427618
# 1031                                  해안절벽과 낙조가 아름다운 해안  33.299570
# 1032                             서남부의 절경을 선사하는 산방산의 이웃산  33.207714
# 1033  천년의 세월이 녹아든 신비로움 가득한 비자림은 500~800년생 비자나무들이 자생하...  33.491318
# 1034  물뫼힐링팜은 제주시 애월읍 수산리에 위치하며, 지역명인 수산(물 수, 뫼 산)에서 ...  33.464226
#
#               경도   우편번호           전화번호  썸네일 이미지경로  \
# 0     126.295900  63021             --        NaN
# 1     126.909500    NaN             --        NaN
# 2     126.255325    NaN             --        NaN
# 3     126.286213    NaN            NaN        NaN
# 4     126.257420  63012             --        NaN
# ...          ...    ...            ...        ...
# 1030  126.666580    NaN   064-747-2563        NaN
# 1031  126.167424    NaN   064-728-7973        NaN
# 1032  126.290990  63512             --        NaN
# 1033  126.811386  63351   064-710-7911        NaN
# 1034  126.396626    NaN  010-8703-2478        NaN
#
#                                                 page
# 0     https://place.map.kakao.com/1212658116#comment
# 1        https://place.map.kakao.com/7980017#comment
# 2       https://place.map.kakao.com/13723607#comment
# 3      https://place.map.kakao.com/468448037#comment
# 4       https://place.map.kakao.com/25728624#comment
# ...                                              ...
# 1030    https://place.map.kakao.com/24946711#comment
# 1031    https://place.map.kakao.com/20056455#comment
# 1032     https://place.map.kakao.com/7956367#comment
# 1033     https://place.map.kakao.com/7912085#comment
# 1034    https://place.map.kakao.com/21656625#comment
#
# [1035 rows x 13 columns]

# %%
kakao.to_csv('kakao_tourist_page.csv',index=False, encoding='cp949')

# %%
kakao = pd.read_csv('kakao_tourist_page.csv',encoding = 'cp949')
kakao.head()
# Out:
#                                             관련 태그 전체                콘텐츠 ID  \
# 0                                              문화유적지  CNTS_000000000022884
# 1                              포구,해변,문화유적지,맑음,아주 어려움  CNTS_000000000020982
# 2                                     포구,일몰,해변,걷기,커플  CNTS_000000000021407
# 3  반려동물,반려동물동반,반려동물전용,예스펫존,반려동물동반입장,혼저옵서개,강아지,반려동...  CNTS_200000000014290
# 4                            휴식/힐링,맑음,자연경관,공용주차장,화장실  CNTS_000000000019458
#
#        콘텐츠명                          주소                        도로명주소  \
# 0  만벵듸 공동장지    제주특별자치도 제주시 한림읍 금악리 2754   제주특별자치도 제주시 한림읍 갯거리오름길 114
# 1      신양포구        제주특별자치도 서귀포시 성산읍 고성리         제주특별자치도 서귀포시 성산읍 고성리
# 2     옹포리포구         제주특별자치도 제주시 한림읍 옹포리          제주특별자치도 제주시 한림읍 옹포리
# 3     삐삐그루밍  제주특별자치도 서귀포시 대정읍 구억리 835-1  제주특별자치도 서귀포시 대정읍 중산간서로 2269
# 4       옹포천     제주특별자치도 제주시 한림읍 옹포리 404      제주특별자치도 제주시 한림읍 한림로 563
#
#                                          태그  \
# 0                 문화유적지,자연경관,문화관광,역사유적,어트랙션
# 1                  포구,해변,문화유적지,맑음,자연경관,역사유적
# 2                       포구,일몰,해변,걷기,커플,자연경관
# 3  반려동물,반려동물동반입장,반려동물공간_기타,애견미용실,애견유치원,애견호텔
# 4                             휴식/힐링,맑음,자연경관
#
#                                       간단소개         위도          경도   우편번호 전화번호  \
# 0  한림지서 예비검속 희생자 유족들이 61구의 시신을 수습하여 안장한 묘역  33.372234  126.295900  63021   --
# 1                성산일충봉과 섭지코지가 한눈에 보이는 신양포구  33.444576  126.909500    NaN   --
# 2      제주올레 14코스에 위치한 일몰이 아름다우며 항아리를 닮은 포구  33.400580  126.255325    NaN   --
# 3        삐삐그루밍은 제주 영어교육도시 내에 위치한 반려견 놀이터다.  33.280630  126.286213    NaN  NaN
# 4                                서부지역의 상수원  33.407660  126.257420  63012   --
#
#    썸네일 이미지경로                                            page
# 0        NaN  https://place.map.kakao.com/1212658116#comment
# 1        NaN     https://place.map.kakao.com/7980017#comment
# 2        NaN    https://place.map.kakao.com/13723607#comment
# 3        NaN   https://place.map.kakao.com/468448037#comment
# 4        NaN    https://place.map.kakao.com/25728624#comment

# %%
all_page = kakao['page']
all_page.tail()
# Out:
# 1030    https://place.map.kakao.com/24946711#comment
# 1031    https://place.map.kakao.com/20056455#comment
# 1032     https://place.map.kakao.com/7956367#comment
# 1033     https://place.map.kakao.com/7912085#comment
# 1034    https://place.map.kakao.com/21656625#comment
# Name: page, dtype: object

# %%
base_options = Options()
base_options.add_experimental_option("detach", True)
base_service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=base_service, options=base_options)
# 가상의 크롬브라우저 실행

# %%
all_review_data = []

# %%
for com_num in range(len(all_page)):

    url2 = all_page[com_num]
    print(url2)
    if url2 == '':
        row_reiew_data = []
        row_reiew_data.append('')
        row_reiew_data.append('')
        row_reiew_data.append('카카오맵')
        row_reiew_data.append('')
        row_reiew_data.append('')
        row_reiew_data.append('')
        row_reiew_data.append('')
        row_reiew_data.append('')
        all_review_data.append(row_reiew_data)
    else:
        driver.get(url2)
        time.sleep(3)
        soup6=BeautifulSoup(driver.page_source,'html.parser')
        time.sleep(3)  

        com_name = soup6.find('h2', {"class" : "tit_location"}).text
        print(com_name)
        category2 = soup6.find(attrs = {'class' : 'txt_location'}).text
        if soup6.find(attrs = {'class' : 'color_b'})l
            com_score2 = soup6.find(attrs = {'class' : 'color_b'}).text
        else:
            com_score2 = ''
        
        if soup6.find(attrs = {'class' : 'link_homepage'}):
            hompage = soup6.find(attrs = {'class' : 'link_homepage'}).text
        else:
            hompage = ''
        
        com_addr = soup6.find('span', {"class" : "txt_address"}).text
            
        if soup6.find(attrs = {'class' : 'time_operation'}):
            open_close = soup6.find(attrs = {'class' : 'time_operation'}).text
        else:
            open_close = ''
        
        if soup6.find(attrs = {'class' : 'list_facility'}):
            tags5 = soup6.find_all('ul', {"class" : "list_facility"})
            etc_re=re.compile('ico_comm\sico_(.*)["][>]')
            etc=etc_re.findall(str(tags5))
            #print(etc)
        else:
            etc = ''        
        
        while True:
            time.sleep(1)
            soup6=BeautifulSoup(driver.page_source,'html.parser')
            time.sleep(1)

            if soup6.find(attrs = {'class' : 'cont_evaluation'}):
                if soup6.find(attrs = {'class' : 'link_more'}):
                    if soup6.find(attrs = {'class' : 'link_more'}).text == '후기 더보기':
                        time.sleep(1)
                        driver.find_element(By.CLASS_NAME, "link_more").send_keys(Keys.ENTER)
                        time.sleep(1)
                    else:
                        tags6 = soup6.find_all('div', {"class" : "cont_evaluation"})
                        
                        rent_name=re.compile('link_user.*#none["][>](.*)[<][/]a[>]\n')
                        writer_name=rent_name.findall(str(tags6))

                        rent_date=re.compile('time_write["][>]20(.*)[<][/]span[>]')
                        rent_date2=rent_date.findall(str(tags6))

                        rent_score=re.compile('style[=]["]width[:](.*)[%][;]["][>][<][/]span[>]')
                        rent_score2=rent_score.findall(str(tags6))

                        rent_coment=re.compile('<span>(.*)[<][/]span[>]')
                        rent_coment2=rent_coment.findall(str(tags6))
                        
                        for num in range(0,len(writer_name)):
                            row_reiew_data = []
                            row_reiew_data.append(writer_name[num])
                            row_reiew_data.append(rent_coment2[num])
                            row_reiew_data.append('카카오맵')
                            number_score = int(rent_score2[num])//20
                            row_reiew_data.append(number_score)
                            row_reiew_data.append(rent_date2[num])
                            row_reiew_data.append(open_close)
                            row_reiew_data.append(category2)
                            row_reiew_data.append(com_name)
                            row_reiew_data.append(com_addr)
                            row_reiew_data.append(com_score2)
                            row_reiew_data.append(hompage)
                            row_reiew_data.append(etc)
                            all_review_data.append(row_reiew_data)
                        break
                else:
                    tags6 = soup6.find_all('div', {"class" : "cont_evaluation"})

                    rent_name=re.compile('link_user.*#none["][>](.*)[<][/]a[>]\n')
                    writer_name=rent_name.findall(str(tags6))

                    rent_date=re.compile('time_write["][>]20(.*)[<][/]span[>]')
                    rent_date2=rent_date.findall(str(tags6))

                    rent_score=re.compile('style[=]["]width[:](.*)[%][;]["][>][<][/]span[>]')
                    rent_score2=rent_score.findall(str(tags6))

                    rent_coment=re.compile('<span>(.*)[<][/]span[>]')
                    rent_coment2=rent_coment.findall(str(tags6))

                    for num in range(0,len(writer_name)):
                        row_reiew_data = []
                        row_reiew_data.append(writer_name[num])
                        row_reiew_data.append(rent_coment2[num])
                        row_reiew_data.append('카카오맵')
                        number_score = int(rent_score2[num])//20
                        row_reiew_data.append(number_score)
                        row_reiew_data.append(rent_date2[num])
                        row_reiew_data.append(open_close)                        
                        row_reiew_data.append(category2)
                        row_reiew_data.append(com_name)
                        row_reiew_data.append(com_addr)
                        row_reiew_data.append(com_score2)
                        row_reiew_data.append(hompage)
                        row_reiew_data.append(etc)
                        all_review_data.append(row_reiew_data)
                    break
            else:
                break

all_review_data
# Out:
# https://place.map.kakao.com/1212658116#comment
# 만벵듸 공동장지
# https://place.map.kakao.com/7980017#comment
# 신양포구
# https://place.map.kakao.com/13723607#comment
# 옹포리포구
# https://place.map.kakao.com/468448037#comment
# 삐삐그루밍
# https://place.map.kakao.com/25728624#comment
# 옹포천
# https://place.map.kakao.com/1763197176#comment
# 러블리독스
# https://place.map.kakao.com/763641480#comment
# 도그앤캣
# https://place.map.kakao.com/1264588511#comment
# 안녕상이친구들
# https://place.map.kakao.com/27049080#comment
# 올레바당체험마을
# 정보없음
# https://place.map.kakao.com/40622413#comment
# 코기절미
# https://place.map.kakao.com/13723641#comment
# 모진이몽돌해변
# https://place.map.kakao.com/8034134#comment
# 원동교차로
# https://place.map.kakao.com/1858329827#comment
# 디어펫
# https://place.map.kakao.com/13723624#comment
# 묵리마을
# https://place.map.kakao.com/25450213#comment
# 연대포구
# https://place.map.kakao.com/1756539039#comment
# 댕댕놀이터
# https://place.map.kakao.com/17811623#comment
# 제주카약올레
# https://place.map.kakao.com/1679065853#comment
# 예술공간 이아
# https://place.map.kakao.com/1746893521#comment
# 세화항
# https://place.map.kakao.com/7894206#comment
# 별도연대
# https://place.map.kakao.com/1649727732#comment
# 오래물
# https://place.map.kakao.com/12736194#comment
# 온평환해장성 제1지점
# 정보없음
# https://place.map.kakao.com/8513650#comment
# 제원한의원
# https://place.map.kakao.com/7915927#comment
# 사계항
# https://place.map.kakao.com/10356367#comment
# 마오름
# https://place.map.kakao.com/25224758#comment
# 라신동
# 정보없음
# https://place.map.kakao.com/25190845#comment
# 까끄래기오름
# https://place.map.kakao.com/8212572#comment
# 궁대악
# https://place.map.kakao.com/12561125#comment
# 송악카트체험장
# https://place.map.kakao.com/10442378#comment
# 삼사석생구이촌
# 정보없음
# 정보없음
# https://place.map.kakao.com/7822217#comment
# 대수포구
# https://place.map.kakao.com/1729023455#comment
# 금성포구
# https://place.map.kakao.com/51635726#comment
# 놀자개
# https://place.map.kakao.com/1322848311#comment
# 요기개
# https://place.map.kakao.com/131787039#comment
# 놀멍쉬멍고르멍
# 정보없음
# https://place.map.kakao.com/625512156#comment
# 고포잇다이브 스쿠버다이빙
# https://place.map.kakao.com/770561720#comment
# 브레이브독스 전기차충전소
# https://place.map.kakao.com/74254170#comment
# 제주다
# https://place.map.kakao.com/1832447276#comment
# 앙데팡당
# https://place.map.kakao.com/21656625#comment
# 물뫼힐링팜
# https://place.map.kakao.com/956522271#comment
# 쿠키네
# https://place.map.kakao.com/357983849#comment
# 곱닥한개
# https://place.map.kakao.com/27418655#comment
# 제주오름승마랜드
# https://place.map.kakao.com/23972934#comment
# 스위트호텔 아로마샵
# https://place.map.kakao.com/13723442#comment
# 돈대산
# https://place.map.kakao.com/1249437757#comment
# 잃어버린 마을 종남마을
# https://place.map.kakao.com/21500494#comment
# 자리왓
# https://place.map.kakao.com/8640631#comment
# 표선해수욕장
# 정보없음
# https://place.map.kakao.com/12528563#comment
# 낙천아홉굿마을
# 정보없음
# https://place.map.kakao.com/11141566#comment
# 서귀포농업기술센터
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5116\1023813194.py in <module>
#      23         print(com_name)
#      24         category2 = soup6.find(attrs = {'class' : 'txt_location'}).text
# ---> 25         com_score2 = soup6.find(attrs = {'class' : 'color_b'}).text
#      26
#      27         if soup6.find(attrs = {'class' : 'link_homepage'}):
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
column_name = ['WRITER','CONTENT','TYPE','SCORE','CREATED_AT','OPEN_CLOSE_TIME','CATEGORY','STORE_NAME','STORE_ADDR','STORE_SCORE','HOMPAGE','ECT']
df2 = pd.DataFrame(
    all_review_data, columns = [column_name])
df2

# %%
df2.shape

# %%
driver.close()

# %%
df2.to_csv('kakao_tourist_review.csv',index=False, encoding='cp949')
