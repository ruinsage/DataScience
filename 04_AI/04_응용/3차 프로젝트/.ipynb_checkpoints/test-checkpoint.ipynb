# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import codecs
import pickle
from konlpy.tag import Okt # Okt : 널리사용되는 형태소 분석기
from gensim.models import word2vec 
import pandas as pd
import csv

# %%
df = pd.read_csv('kakao_tourist_review_pre.csv', encoding='utf-8')
df.head()
# Out:
#    Unnamed: 0                    ID WRITER  \
# 0        3761  CONT_000000000500703   눈누난나
# 1        3932  CONT_000000000500703   눈누난나
# 2        3843  CONT_000000000500703      깜
# 3        3924  CONT_000000000500703   모코보코
# 4        4014  CONT_000000000500703      깜
#
#                                              CONTENT   TYPE  SCORE CREATED_AT  \
# 0  만평이어서인지 볼거리가 많습니다 종유동굴만 보다 용암동굴을 보니 재밌었고 각각의 테...  kakao    5.0  23.01.31.
# 1  만평이어서인지 볼거리가 많습니다 종유동굴만 보다 용암동굴을 보니 재밌었고 각각의 테...  kakao    5.0  23.01.31.
# 2  제주에 여러번 오고서도 왜 이곳을 진작 와보지 않았을까 정말 정말 넓고 볼거리가 다...  kakao    5.0  21.04.24.
# 3  전 제주도에서 여기가 제일 만족스러워요 전 휴애리보다 좋았어요 사진을 찍는 그런곳은...  kakao    5.0  18.03.16.
# 4  제주에 여러번 오고서도 왜 이곳을 진작 와보지 않았을까 정말 정말 넓고 볼거리가 다...  kakao    5.0  21.04.24.
#
#    len_content
# 0          311
# 1          311
# 2          240
# 3          240
# 4          240
